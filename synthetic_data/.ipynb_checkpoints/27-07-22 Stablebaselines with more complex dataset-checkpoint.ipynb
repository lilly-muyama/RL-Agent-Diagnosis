# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import os
import tensorflow
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Data with random zeros

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tensorflow.set_random_seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)

# %% [markdown]
# #### The Data

# %%
df = pd.read_csv('data/anemia_synth_dataset.csv')
df = df.fillna(0)
classes = list(df.label.unique())
nums = [i for i in range(len(classes))]
class_dict = dict(zip(classes, nums))
df['label'] = df['label'].replace(class_dict)
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=SEED)
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((19877, 8), (8519, 8), (19877,), (8519,))

# %%
class_dict
# Out:
# {'Hemolytic anemia': 0,
#  'Anemia of chronic disease': 1,
#  'Aplastic anemia': 2,
#  'Iron deficiency anemia': 3,
#  'Vitamin B12/Folate deficiency anemia': 4,
#  'Thalassemia': 5}

# %%
action_list = list(class_dict.keys()) + [col  for col in df.columns if col!='label']
len(action_list)
# Out:
# 14

# %%
action_list
# Out:
# ['Hemolytic anemia',
#  'Anemia of chronic disease',
#  'Aplastic anemia',
#  'Iron deficiency anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Thalassemia',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'iron',
#  'tibc',
#  'rbc',
#  'mcv',
#  'mentzer_index']

# %%
X_train[:2], X_test[:2]
# Out:
# (array([[0.00000000e+00, 3.70171123e-02, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00, 4.77428854e+00, 9.29984862e+01, 1.94790251e+01],
#         [6.47971733e+00, 0.00000000e+00, 0.00000000e+00, 7.37002960e+01,
#          2.11225568e+02, 3.32556904e+00, 7.61342353e+01, 2.28935963e+01]]),
#  array([[ 0.        ,  5.4846097 ,  0.        ,  0.        ,  0.        ,
#           2.98604601, 89.78437763, 30.06798199],
#         [ 0.        ,  2.41768907,  0.        ,  0.        ,  0.        ,
#           2.64180998, 82.20700343, 31.11768219]]))

# %% [markdown]
# #### The Environment

# %%
import copy
from gym import Env
from gym.spaces import Discrete, Box

# %%
class SyntheticEnv(Env):
    def __init__(self, X, Y, random=True):
        super(SyntheticEnv, self).__init__()
        self.action_space = Discrete(14)
        self.observation_space = Box(0, 1.5, (8,))
        self.actions = list(class_dict.keys()) + [col  for col in df.columns if col!='label']
        self.max_steps = 10
        self.X = X
        self.Y = Y
        self.sample_num = len(X)
        self.idx = -1
        self.x = np.zeros((8,), dtype=np.float32)
        self.y = np.nan
        self.state = np.zeros((8,), dtype=np.float32)
        self.num_classes = 6
        self.episode_length = 0
        self.trajectory = []
        self.total_reward = 0
        self.random = random
        
    
    def step(self, action):
#         print('A step in the environment')
#         print(f'State: {self.state}')
#         print(f'action: {action}')
        self.episode_length += 1
        reward = 0
        if self.episode_length == self.max_steps: # episode too long
            #print('Reached max steps')
            reward -=1
            self.total_reward -=1
            terminated = True
            done = True
            y_actual = self.y
            y_pred = np.nan
            is_success = False
        elif action < self.num_classes: #diagnosis (terminal action)
            #print('Terminal action')
            if action == self.y:
                reward +=1
                self.total_reward += 1
                is_success = True
            else:
                reward -= 1
                self.total_reward -= 1
                is_success = False
            terminated = False
            done = True
            y_actual = self.y
            y_pred = action
        elif self.actions[action] in self.trajectory: #action already picked 
            #print('Repeated action')
            terminated = False
            reward -= 1
            self.total_reward -= 1
            done = False
            y_actual = np.nan
            y_pred = np.nan
            is_success = None
        else: #new feature being acquired
            #print('Acquiring new feature')
            terminated = False
            reward += 1
            self.total_reward += 1
            done = False
            self.state = self.get_next_state(action-self.num_classes)
            y_actual = np.nan
            y_pred = np.nan
            is_success = None
        self.trajectory.append(self.actions[action])
        info = {'index': self.idx, 'episode_length':self.episode_length, 'reward': self.total_reward, 'y_pred': y_pred, 
                'y_actual': y_actual, 'trajectory':self.trajectory, 'terminated':terminated, 'is_success': is_success}
#         print(f'next state:{self.state}')
#         print(f'reward: {reward}')
#         print(f'done: {done}')
#         print(f'info: {info}')
        return self.state, reward, done, info
            
    
    def render(self):
        print(f'STEP {self.episode_length} for index {self.idx}')
        #print(f'x: {self.x}')
        #print(f'y: {self.y}')
        print(f'Current state: {self.state}')
        print(f'Total reward: {self.total_reward}')
        print(f'Trajectory: {self.trajectory}')
        
            
    
    def reset(self):
        #print('RESETTING THE ENVIRONMENT')
        if self.random:
            self.idx = random.randint(0, self.sample_num-1)
        else:
            self.idx += 1
            if self.idx == len(self.X):
                raise StopIteration()
        #print(f'New index: {self.idx}')
        #print(f'New idx: {self.idx}')
        self.x, self.y = self.X[self.idx], self.Y[self.idx]
        #print(f'New x: {self.x}')
        #print(f'New y: {self.y}')
        self.state = np.zeros((8,), dtype=np.float32)
        #print(f'New state: {self.state}')
        self.trajectory = []
        #print(f'New trajectory: {self.trajectory}')
        self.episode_length = 0
        #print(f'New episode length: {self.episode_length}')
        self.total_reward = 0
        #print(f'New total reward: {self.total_reward}')
        return self.state
        
    
    def get_next_state(self, feature_idx):
        self.x = self.x.reshape(-1, 8)
        x_value = self.x[0, feature_idx]
        next_state = copy.deepcopy(self.state)
        next_state[feature_idx] = x_value
        return next_state

# %%
training_env = SyntheticEnv(X_train, y_train)

# %% [markdown]
# #### The Agent

# %%
from stable_baselines.common.env_checker import check_env
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
from stable_baselines import DQN
from stable_baselines import bench, logger
# Out:
# C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
def stable_dqn():
    env = SyntheticEnv(X_train, y_train)
    env = bench.Monitor(env, logger.get_dir())
    model = DQN('MlpPolicy', training_env, verbose=1, seed=SEED, n_cpu_tf_sess=1)
    model.learn(total_timesteps=int(1.8e6), log_interval=10000)
    #model.learn(total_timesteps=int(1.2e5), log_interval=10000)
    model.save('models/synthetic_stable_dqn_1.8.pkl')
    env.close()
    return model

dqn_model = stable_dqn()
# Out:
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\stable_baselines\deepq\policies.py:109: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 10000    |
# | mean 100 episode reward | 0.3      |
# | steps                   | 24881    |
# | success rate            | 0.16     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 70       |
# | episodes                | 20000    |
# | mean 100 episode reward | 0.5      |
# | steps                   | 54190    |
# | success rate            | 0.18     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 50       |
# | episodes                | 30000    |
# | mean 100 episode reward | -0.2     |
# | steps                   | 90785    |
# | success rate            | 0.17     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 22       |
# | episodes                | 40000    |
# | mean 100 episode reward | -2.2     |
# | steps                   | 141543   |
# | success rate            | 0.19     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 50000    |
# | mean 100 episode reward | 2.8      |
# | steps                   | 197719   |
# | success rate            | 0.4      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 60000    |
# | mean 100 episode reward | 2.6      |
# | steps                   | 240686   |
# | success rate            | 0.52     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 70000    |
# | mean 100 episode reward | 3.2      |
# | steps                   | 287164   |
# | success rate            | 0.64     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 80000    |
# | mean 100 episode reward | 3.3      |
# | steps                   | 335466   |
# | success rate            | 0.72     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 90000    |
# | mean 100 episode reward | 3.4      |
# | steps                   | 385748   |
# | success rate            | 0.8      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 100000   |
# | mean 100 episode reward | 3.2      |
# | steps                   | 436486   |
# | success rate            | 0.78     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 110000   |
# | mean 100 episode reward | 3.6      |
# | steps                   | 487251   |
# | success rate            | 0.81     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 120000   |
# | mean 100 episode reward | 4        |
# | steps                   | 537183   |
# | success rate            | 0.86     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 130000   |
# | mean 100 episode reward | 3.9      |
# | steps                   | 587362   |
# | success rate            | 0.79     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 140000   |
# | mean 100 episode reward | 3.9      |
# | steps                   | 637968   |
# | success rate            | 0.82     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 150000   |
# | mean 100 episode reward | 4.3      |
# | steps                   | 688102   |
# | success rate            | 0.87     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 160000   |
# | mean 100 episode reward | 3.8      |
# | steps                   | 738088   |
# | success rate            | 0.87     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 170000   |
# | mean 100 episode reward | 3.8      |
# | steps                   | 787912   |
# | success rate            | 0.89     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 180000   |
# | mean 100 episode reward | 4.2      |
# | steps                   | 837556   |
# | success rate            | 0.89     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 190000   |
# | mean 100 episode reward | 4.3      |
# | steps                   | 887568   |
# | success rate            | 0.91     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 200000   |
# | mean 100 episode reward | 4.1      |
# | steps                   | 937121   |
# | success rate            | 0.87     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 210000   |
# | mean 100 episode reward | 3.2      |
# | steps                   | 986855   |
# | success rate            | 0.79     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 220000   |
# | mean 100 episode reward | 3.9      |
# | steps                   | 1036368  |
# | success rate            | 0.88     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 230000   |
# | mean 100 episode reward | 4.4      |
# | steps                   | 1085658  |
# | success rate            | 0.9      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 240000   |
# | mean 100 episode reward | 4        |
# | steps                   | 1134941  |
# | success rate            | 0.85     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 250000   |
# | mean 100 episode reward | 3.4      |
# | steps                   | 1184189  |
# | success rate            | 0.83     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 260000   |
# | mean 100 episode reward | 4        |
# | steps                   | 1233596  |
# | success rate            | 0.88     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 270000   |
# | mean 100 episode reward | 4.3      |
# | steps                   | 1282734  |
# | success rate            | 0.94     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 280000   |
# | mean 100 episode reward | 4.4      |
# | steps                   | 1332090  |
# | success rate            | 0.92     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 290000   |
# | mean 100 episode reward | 4.3      |
# | steps                   | 1381448  |
# | success rate            | 0.92     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300000   |
# | mean 100 episode reward | 3.9      |
# | steps                   | 1430991  |
# | success rate            | 0.84     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 310000   |
# | mean 100 episode reward | 4.1      |
# | steps                   | 1480415  |
# | success rate            | 0.9      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 320000   |
# | mean 100 episode reward | 4.4      |
# | steps                   | 1529742  |
# | success rate            | 0.93     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 330000   |
# | mean 100 episode reward | 4        |
# | steps                   | 1578863  |
# | success rate            | 0.85     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 340000   |
# | mean 100 episode reward | 4.3      |
# | steps                   | 1628143  |
# | success rate            | 0.94     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 350000   |
# | mean 100 episode reward | 4.3      |
# | steps                   | 1677431  |
# | success rate            | 0.92     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 360000   |
# | mean 100 episode reward | 4.2      |
# | steps                   | 1726639  |
# | success rate            | 0.91     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 370000   |
# | mean 100 episode reward | 4.1      |
# | steps                   | 1776075  |
# | success rate            | 0.91     |
# --------------------------------------

# %% [markdown]
# #### Performance Evaluation

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, auc, roc_curve

# %%
def multiclass(actual_class, pred_class, average = 'macro'):

    unique_class = set(actual_class)
    roc_auc_dict = {}
    for per_class in unique_class:
        other_class = [x for x in unique_class if x != per_class]
        new_actual_class = [0 if x in other_class else 1 for x in actual_class]
        new_pred_class = [0 if x in other_class else 1 for x in pred_class]
        roc_auc = roc_auc_score(new_actual_class, new_pred_class, average = average)
        roc_auc_dict[per_class] = roc_auc
    avg = sum(roc_auc_dict.values()) / len(roc_auc_dict)
    return avg

# %%
def test(ytest, ypred):
    acc = accuracy_score(ytest, ypred)
    f1 = f1_score(ytest, ypred, average ='macro', labels=np.unique(ytest))
    try:
        roc_auc = multiclass(ytest, ypred)
    except:
        roc_auc = None
    return acc, f1, roc_auc

# %%
def get_avg_length_reward(df):
    length = np.mean(df.episode_length)
    reward = np.mean(df.reward)
    return length, reward

# %%
def synthetic_dqn_eval(dqn_model):
    attempts, correct = 0,0
    test_df = pd.DataFrame()

    env = SyntheticEnv(X_test, y_test, random=False)
    count=0

    try:
        while True:
            count+=1
            if count%5000==0:
                print(f'Count: {count}')
            obs, done = env.reset(), False
            while not done:
                action, _states = dqn_model.predict(obs, deterministic=True)
                obs, rew, done,info = env.step(action)
                #if (done==True) & (np.isfinite(info['y_pred'])):
                if done == True:
                    test_df = test_df.append(info, ignore_index=True)
                #print('....................TEST DF ....................')
                #if len(test_df) != 0:
                #    print(test_df.head())

    except StopIteration:
        print('Testing done.....')
    return test_df

test_df = synthetic_dqn_eval(dqn_model)
# Out:
# Count: 5000
# Testing done.....

# %%
len(X_test), len(test_df)
# Out:
# (8519, 8519)

# %%
y_pred_df = test_df[test_df['y_pred'].notna()]
success_df = y_pred_df[y_pred_df['y_pred']== y_pred_df['y_actual']]
len(success_df)
# Out:
# 8180

# %%
test_df.to_csv('test_dfs/test_df_1.8e6.csv', index=False)
y_pred_df.to_csv('test_dfs/y_pred_df_1.8e6.csv', index=False)
success_df.to_csv('test_dfs/success_df_1.8e6.csv', index=False)

# %%
y_pred_df.y_pred.unique()
# Out:
# array([0., 2., 3., 4., 1.])

# %%
y_pred_df.y_pred.value_counts()
# Out:
# 0.0    4267
# 2.0    2738
# 1.0     462
# 4.0     460
# 3.0     331
# Name: y_pred, dtype: int64

# %%
y_pred_df.y_actual.value_counts()
# Out:
# 0.0    4212
# 2.0    2798
# 4.0     462
# 1.0     450
# 3.0     333
# 5.0       3
# Name: y_actual, dtype: int64

# %%
success_rate = len(success_df)/len(test_df)*100
success_rate
# Out:
# 96.02065970184293

# %%
#avg length and return 
avg_length, avg_return = get_avg_length_reward(test_df)
avg_length, avg_return
# Out:
# (4.868529170090386, 4.4234065031106935)

# %%
acc, f1, roc_auc = test(y_pred_df['y_actual'], y_pred_df['y_pred'])
acc, f1, roc_auc
# Out:
# (0.9905546137079196, 0.8268733117642993, 0.9122946939775459)

# %% [markdown]
# #### Confusion Matrix and Classification Report

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
def plot_confusion_matrix(cm, save=False, filename=False):
    cm_df = pd.DataFrame(cm, index = [0, 1, 2, 3, 4, 5], columns = [0, 1, 2, 3, 4, 5])
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_df, annot=True)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Anemia')
    plt.xlabel('Predicted Anemia')
    plt.tight_layout()
    if save:
        plt.savefig(filename)
    plt.show()
    plt.close()

# %%
plot_confusion_matrix(confusion_matrix(y_pred_df['y_actual'], y_pred_df['y_pred']))

# %%
def cm2inch(*tupl):
    inch = 2.54
    if type(tupl[0]) == tuple:
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)

# %%
def show_values(pc, fmt="%.2f", **kw):    
    pc.update_scalarmappable()
    ax = pc.axes
    for p, color, value in zip(pc.get_paths(), pc.get_facecolors(), pc.get_array()):
        x, y = p.vertices[:-2, :].mean(0)
        if np.all(color[:3] > 0.5):
            color = (0.0, 0.0, 0.0)
        else:
            color = (1.0, 1.0, 1.0)
        ax.text(x, y, fmt % value, ha="center", va="center", color=color, **kw)

# %%
def heatmap(AUC, title, xlabel, ylabel, xticklabels, yticklabels, figure_width=40, figure_height=20, correct_orientation=False, cmap='RdBu'):
    fig, ax = plt.subplots()    
    c = ax.pcolor(AUC, edgecolors='k', linestyle= 'dashed', linewidths=0.2, cmap=cmap)
    ax.set_yticks(np.arange(AUC.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(AUC.shape[1]) + 0.5, minor=False)
    ax.set_xticklabels(xticklabels, minor=False)
    ax.set_yticklabels(yticklabels, minor=False)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)      

    # Remove last blank column
    plt.xlim( (0, AUC.shape[1]) )

    # Turn off all the ticks
    ax = plt.gca()    
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False

    # Add color bar
    plt.colorbar(c)

    # Add text in each cell 
    show_values(c)

    # Proper orientation (origin at the top left instead of bottom left)
    if correct_orientation:
        ax.invert_yaxis()
        ax.xaxis.tick_top()       

    # resize 
    fig = plt.gcf()
    fig.set_size_inches(cm2inch(figure_width, figure_height))

# %%
def plot_classification_report(classification_report, save=False, filename=False, cmap='RdBu'):
    lines = classification_report.split('\n')
    class_names = list(class_dict.keys())
    plotMat = []
    support = []
    #class_names = []
    #count = 0
    for line in lines[2 : (len(lines) - 5)]:
        t = line.strip().split()
        if len(t) < 2: continue
        v = [float(x) for x in t[1: len(t) - 1]]
        support.append(int(t[-1]))
        plotMat.append(v)

    xlabel = 'Metrics'
    ylabel = 'Classes'
    xticklabels = ['Precision', 'Recall', 'F1-score']
    ytick_labels = [f'{class_names[i]}({sup})' for i, sup in enumerate(support) ]
    
    #print(len(support))
    yticklabels = ['{0} ({1})'.format(class_names[idx], sup) for idx, sup  in enumerate(support)]
    figure_width = 25
    figure_height = len(class_names) + 7
    correct_orientation = False
    heatmap(np.array(plotMat), 'classification report', xlabel, ylabel, xticklabels, yticklabels, figure_width, figure_height, correct_orientation, cmap=cmap)
    #plt.tight_layout()
    if save:
        plt.savefig(filename, bbox_inches = 'tight')
    plt.show()
    plt.close()

# %%
cr = classification_report(y_pred_df['y_actual'], y_pred_df['y_pred'])
plot_classification_report(cr)
# Out:
# C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\Anaconda3\envs\tf_v1_env\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test[2734]
# Out:
# 0

# %%
len(y_pred_df)
# Out:
# 8258

# %%
#episodes that are misdiagnosed
non_success_df = y_pred_df[y_pred_df['y_pred']!= y_pred_df['y_actual']]
non_success_df
# Out:
#       episode_length   index  is_success  reward  terminated  \
# 33               5.0    33.0         0.0     3.0         0.0
# 253              5.0   253.0         0.0     3.0         0.0
# 601              5.0   601.0         0.0     3.0         0.0
# 798              5.0   798.0         0.0     3.0         0.0
# 1174             5.0  1174.0         0.0     3.0         0.0
# 1275             5.0  1275.0         0.0     3.0         0.0
# 1344             5.0  1344.0         0.0     3.0         0.0
# 1368             2.0  1368.0         0.0     0.0         0.0
# 1486             5.0  1486.0         0.0     3.0         0.0
# 1545             5.0  1545.0         0.0     3.0         0.0
# 1555             5.0  1555.0         0.0     3.0         0.0
# 1558             5.0  1558.0         0.0     3.0         0.0
# 1621             5.0  1621.0         0.0     3.0         0.0
# 1732             5.0  1732.0         0.0     3.0         0.0
# 1770             5.0  1770.0         0.0     3.0         0.0
# 1805             5.0  1805.0         0.0     3.0         0.0
# 1885             5.0  1885.0         0.0     3.0         0.0
# 1972             5.0  1972.0         0.0     3.0         0.0
# 2132             5.0  2132.0         0.0     3.0         0.0
# 2255             5.0  2255.0         0.0     3.0         0.0
# 2406             4.0  2406.0         0.0     2.0         0.0
# 2508             5.0  2508.0         0.0     3.0         0.0
# 2708             5.0  2708.0         0.0     3.0         0.0
# 2775             5.0  2775.0         0.0     3.0         0.0
# 2785             6.0  2785.0         0.0     4.0         0.0
# 2814             5.0  2814.0         0.0     3.0         0.0
# 2845             5.0  2845.0         0.0     3.0         0.0
# 2927             5.0  2927.0         0.0     3.0         0.0
# 2980             4.0  2980.0         0.0     2.0         0.0
# 2981             5.0  2981.0         0.0     3.0         0.0
# ...              ...     ...         ...     ...         ...
# 4737             5.0  4737.0         0.0     3.0         0.0
# 4759             5.0  4759.0         0.0     3.0         0.0
# 4853             5.0  4853.0         0.0     3.0         0.0
# 4902             5.0  4902.0         0.0     3.0         0.0
# 5078             6.0  5078.0         0.0     4.0         0.0
# 5484             5.0  5484.0         0.0     3.0         0.0
# 5663             5.0  5663.0         0.0     3.0         0.0
# 5881             5.0  5881.0         0.0     3.0         0.0
# 5941             5.0  5941.0         0.0     3.0         0.0
# 5987             3.0  5987.0         0.0     1.0         0.0
# 6045             5.0  6045.0         0.0     3.0         0.0
# 6069             5.0  6069.0         0.0     3.0         0.0
# 6210             2.0  6210.0         0.0     0.0         0.0
# 6294             5.0  6294.0         0.0     3.0         0.0
# 6317             5.0  6317.0         0.0     3.0         0.0
# 6353             5.0  6353.0         0.0     3.0         0.0
# 6383             5.0  6383.0         0.0     3.0         0.0
# 6503             5.0  6503.0         0.0     3.0         0.0
# 6523             7.0  6523.0         0.0     5.0         0.0
# 6614             5.0  6614.0         0.0     3.0         0.0
# 6620             5.0  6620.0         0.0     3.0         0.0
# 6627             4.0  6627.0         0.0     2.0         0.0
# 6641             5.0  6641.0         0.0     3.0         0.0
# 6665             5.0  6665.0         0.0     3.0         0.0
# 6666             5.0  6666.0         0.0     3.0         0.0
# 6762             5.0  6762.0         0.0     3.0         0.0
# 6774             5.0  6774.0         0.0     3.0         0.0
# 7989             6.0  7989.0         0.0     4.0         0.0
# 8114             5.0  8114.0         0.0     3.0         0.0
# 8434             5.0  8434.0         0.0     3.0         0.0
#
#                                              trajectory  y_actual  y_pred
# 33    [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 253   [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 601   [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 798   [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1174  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1275  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1344  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1368         [mentzer_index, Anemia of chronic disease]       0.0     1.0
# 1486  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1545  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1555  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1558  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1621  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1732  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1770  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1805  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1885  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 1972  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2132  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2255  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2406   [mentzer_index, rbc, ret_count, Aplastic anemia]       0.0     2.0
# 2508  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2708  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2775  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2785  [mentzer_index, rbc, iron, mcv, ferritin, Anem...       5.0     1.0
# 2814  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2845  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2927  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 2980  [mentzer_index, rbc, iron, Anemia of chronic d...       3.0     1.0
# 2981  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# ...                                                 ...       ...     ...
# 4737  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 4759  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 4853  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 4902  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 5078  [mentzer_index, rbc, iron, mcv, ferritin, Anem...       5.0     1.0
# 5484  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 5663  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 5881  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 5941  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 5987    [mentzer_index, rbc, Anemia of chronic disease]       0.0     1.0
# 6045  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6069  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6210         [mentzer_index, Anemia of chronic disease]       0.0     1.0
# 6294  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6317  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6353  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6383  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6503  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6523  [mentzer_index, rbc, iron, mcv, ferritin, tibc...       3.0     1.0
# 6614  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6620  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6627  [mentzer_index, rbc, segmented_neutrophils, Ap...       4.0     2.0
# 6641  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6665  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6666  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6762  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 6774  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 7989  [mentzer_index, rbc, iron, mcv, ferritin, Anem...       5.0     1.0
# 8114  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
# 8434  [mentzer_index, rbc, ret_count, mcv, Hemolytic...       2.0     0.0
#
# [78 rows x 8 columns]

# %%
non_success_df.index
# Out:
# Int64Index([  33,  253,  601,  798, 1174, 1275, 1344, 1368, 1486, 1545, 1555,
#             1558, 1621, 1732, 1770, 1805, 1885, 1972, 2132, 2255, 2406, 2508,
#             2708, 2775, 2785, 2814, 2845, 2927, 2980, 2981, 3055, 3130, 3156,
#             3275, 3466, 3544, 3596, 3613, 3684, 3905, 4082, 4307, 4412, 4517,
#             4547, 4565, 4590, 4613, 4737, 4759, 4853, 4902, 5078, 5484, 5663,
#             5881, 5941, 5987, 6045, 6069, 6210, 6294, 6317, 6353, 6383, 6503,
#             6523, 6614, 6620, 6627, 6641, 6665, 6666, 6762, 6774, 7989, 8114,
#             8434],
#            dtype='int64')

# %%
b_non_succ_df = non_success_df[non_success_df.y_pred==1]
b_non_succ_df
# Out:
#       episode_length   index  is_success  reward  terminated  \
# 1368             2.0  1368.0         0.0     0.0         0.0
# 2785             6.0  2785.0         0.0     4.0         0.0
# 2980             4.0  2980.0         0.0     2.0         0.0
# 3613             3.0  3613.0         0.0     1.0         0.0
# 4412             3.0  4412.0         0.0     1.0         0.0
# 4565             3.0  4565.0         0.0     1.0         0.0
# 4613             3.0  4613.0         0.0     1.0         0.0
# 5078             6.0  5078.0         0.0     4.0         0.0
# 5987             3.0  5987.0         0.0     1.0         0.0
# 6210             2.0  6210.0         0.0     0.0         0.0
# 6523             7.0  6523.0         0.0     5.0         0.0
# 7989             6.0  7989.0         0.0     4.0         0.0
#
#                                              trajectory  y_actual  y_pred
# 1368         [mentzer_index, Anemia of chronic disease]       0.0     1.0
# 2785  [mentzer_index, rbc, iron, mcv, ferritin, Anem...       5.0     1.0
# 2980  [mentzer_index, rbc, iron, Anemia of chronic d...       3.0     1.0
# 3613    [mentzer_index, rbc, Anemia of chronic disease]       2.0     1.0
# 4412    [mentzer_index, rbc, Anemia of chronic disease]       0.0     1.0
# 4565    [mentzer_index, rbc, Anemia of chronic disease]       0.0     1.0
# 4613    [mentzer_index, rbc, Anemia of chronic disease]       2.0     1.0
# 5078  [mentzer_index, rbc, iron, mcv, ferritin, Anem...       5.0     1.0
# 5987    [mentzer_index, rbc, Anemia of chronic disease]       0.0     1.0
# 6210         [mentzer_index, Anemia of chronic disease]       0.0     1.0
# 6523  [mentzer_index, rbc, iron, mcv, ferritin, tibc...       3.0     1.0
# 7989  [mentzer_index, rbc, iron, mcv, ferritin, Anem...       5.0     1.0

# %%
c_non_succ_df = non_success_df[non_success_df.y_pred==2]
c_non_succ_df
# Out:
#       episode_length   index  is_success  reward  terminated  \
# 2406             4.0  2406.0         0.0     2.0         0.0
# 4307             4.0  4307.0         0.0     2.0         0.0
# 4590             4.0  4590.0         0.0     2.0         0.0
# 6627             4.0  6627.0         0.0     2.0         0.0
#
#                                              trajectory  y_actual  y_pred
# 2406   [mentzer_index, rbc, ret_count, Aplastic anemia]       0.0     2.0
# 4307   [mentzer_index, rbc, ret_count, Aplastic anemia]       0.0     2.0
# 4590  [mentzer_index, rbc, segmented_neutrophils, Ap...       4.0     2.0
# 6627  [mentzer_index, rbc, segmented_neutrophils, Ap...       4.0     2.0
