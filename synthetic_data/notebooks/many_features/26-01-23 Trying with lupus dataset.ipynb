# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import os
from datetime import datetime
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %%
train_df = pd.read_csv('../../lupus_trial/data/anemia/train_set_basic.csv')
train_df = train_df.fillna(-1)
train_df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    9.007012   -1.000000  -1.000000               3.519565  440.499323
# 1    8.760976   -1.000000   0.491469              -1.000000  259.895852
# 2    7.490324   70.812609  -1.000000               1.495604  482.109919
# 3    8.113370  499.313483   3.507612               0.000000  195.351883
# 4   13.935301  349.569415   5.190725               6.894195  489.595939
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0  103.442762   59.017997  2.612173       1    0.650757  114.794964
# 1  103.885481   -1.000000  2.529991       0    0.728641   74.824352
# 2   79.543391   -1.000000  2.824995       0   -1.000000   -1.000000
# 3  100.545858  203.895756  2.420797       1    0.860863    9.120947
# 4  102.234294  150.085853  4.089225       1    0.216907   20.344863
#
#        copper    ethanol     folate     glucose  hematocrit        tsat  label
# 0  112.308159  25.612786   5.969710  116.026042   27.021037   13.397977      1
# 1   -1.000000  -1.000000  -1.000000   -1.000000   26.282929   -1.000000      7
# 2   -1.000000  -1.000000  -1.000000   -1.000000   22.470972   -1.000000      4
# 3   41.131511   1.843890  18.845473  106.199806   24.340111  104.373581      2
# 4   92.547095  19.815123  29.543875   98.388710   41.805903   30.655044      0

# %%
action_list = list(constants.CLASS_DICT.keys()) + [col  for col in train_df.columns if col!='label']
action_list
# Out:
# ['No anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Unspecified anemia',
#  'Anemia of chronic disease',
#  'Iron deficiency anemia',
#  'Hemolytic anemia',
#  'Aplastic anemia',
#  'Inconclusive diagnosis',
#  'hemoglobin',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'tibc',
#  'mcv',
#  'serum_iron',
#  'rbc',
#  'gender',
#  'creatinine',
#  'cholestrol',
#  'copper',
#  'ethanol',
#  'folate',
#  'glucose',
#  'hematocrit',
#  'tsat']

# %%
train_df.isna().sum()
# Out:
# hemoglobin               0
# ferritin                 0
# ret_count                0
# segmented_neutrophils    0
# tibc                     0
# mcv                      0
# serum_iron               0
# rbc                      0
# gender                   0
# creatinine               0
# cholestrol               0
# copper                   0
# ethanol                  0
# folate                   0
# glucose                  0
# hematocrit               0
# tsat                     0
# label                    0
# dtype: int64

# %%
X_train = train_df.iloc[:, 0:-1]
y_train = train_df.iloc[:, -1]

X_train, y_train = np.array(X_train), np.array(y_train)
X_train.shape, y_train.shape
# Out:
# ((56000, 17), (56000,))

# %% [markdown]
# #### training

# %%
for steps in [int(5.5e6)]:
    dqn_model = utils.stable_dqn3(X_train, y_train, steps, True, 
                                  f'../../lupus_trial/models/anemia/model_{steps}')
# Out:
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93     |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.457    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 3631     |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 314432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.15     |
# |    n_updates        | 66107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 2986     |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 688868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.39     |
# |    n_updates        | 159716   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.07     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 2903     |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 1070011  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.24     |
# |    n_updates        | 255002   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 2810     |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 1517056  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.067    |
# |    n_updates        | 366763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94     |
# |    ep_rew_mean      | -0.28    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.37     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 2326     |
# |    time_elapsed     | 835      |
# |    total_timesteps  | 1944309  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0988   |
# |    n_updates        | 473577   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17     |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.46     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 2106     |
# |    time_elapsed     | 1121     |
# |    total_timesteps  | 2362875  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0978   |
# |    n_updates        | 578218   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.67     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.66     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 2089     |
# |    time_elapsed     | 1332     |
# |    total_timesteps  | 2785244  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0589   |
# |    n_updates        | 683810   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.4      |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.7      |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 2093     |
# |    time_elapsed     | 1547     |
# |    total_timesteps  | 3239886  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0757   |
# |    n_updates        | 797471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.73     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 2112     |
# |    time_elapsed     | 1750     |
# |    total_timesteps  | 3696056  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.082    |
# |    n_updates        | 911513   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.73     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 2119     |
# |    time_elapsed     | 1958     |
# |    total_timesteps  | 4150255  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0802   |
# |    n_updates        | 1025063  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.51     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 2133     |
# |    time_elapsed     | 2166     |
# |    total_timesteps  | 4620816  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0513   |
# |    n_updates        | 1142703  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 2143     |
# |    time_elapsed     | 2375     |
# |    total_timesteps  | 5090769  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 1260192  |
# ----------------------------------
