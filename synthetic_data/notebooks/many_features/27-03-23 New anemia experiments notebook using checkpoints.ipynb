# %%
import pandas as pd
import numpy as np
import random
import os
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %% [markdown]
# #### The training data

# %%
# train_df = pd.read_csv('../../final/data/new_experiments/train_set_basic.csv')
#train_df = pd.read_csv('../../final/data/train_set_noisy_6_missing_3.csv')
train_df = pd.read_csv('../../final/data/train_set_basic.csv')
train_df = train_df.fillna(-1)
train_df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    9.007012   -1.000000  -1.000000               3.519565  440.499323
# 1    8.760976   -1.000000   0.491469              -1.000000  259.895852
# 2    7.490324   70.812609  -1.000000               1.495604  482.109919
# 3    8.113370  499.313483   3.507612               0.000000  195.351883
# 4   13.935301  349.569415   5.190725               6.894195  489.595939
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0  103.442762   59.017997  2.612173       1    0.650757  114.794964
# 1  103.885481   -1.000000  2.529991       0    0.728641   74.824352
# 2   79.543391   -1.000000  2.824995       0   -1.000000   -1.000000
# 3  100.545858  203.895756  2.420797       1    0.860863    9.120947
# 4  102.234294  150.085853  4.089225       1    0.216907   20.344863
#
#        copper    ethanol     folate     glucose  hematocrit        tsat  label
# 0  112.308159  25.612786   5.969710  116.026042   27.021037   13.397977      1
# 1   -1.000000  -1.000000  -1.000000   -1.000000   26.282929   -1.000000      7
# 2   -1.000000  -1.000000  -1.000000   -1.000000   22.470972   -1.000000      4
# 3   41.131511   1.843890  18.845473  106.199806   24.340111  104.373581      2
# 4   92.547095  19.815123  29.543875   98.388710   41.805903   30.655044      0

# %%
len(train_df)
# Out:
# 56000

# %%
train_df.isna().sum()
# Out:
# hemoglobin               0
# ferritin                 0
# ret_count                0
# segmented_neutrophils    0
# tibc                     0
# mcv                      0
# serum_iron               0
# rbc                      0
# gender                   0
# creatinine               0
# cholestrol               0
# copper                   0
# ethanol                  0
# folate                   0
# glucose                  0
# hematocrit               0
# tsat                     0
# label                    0
# dtype: int64

# %%
X_train = train_df.iloc[:, 0:-1]
y_train = train_df.iloc[:, -1]
X_train, y_train = np.array(X_train), np.array(y_train)
X_train.shape, y_train.shape
# Out:
# ((56000, 17), (56000,))

# %%
action_list = list(constants.CLASS_DICT.keys()) + [col  for col in train_df.columns if col!='label']
action_list
# Out:
# ['No anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Unspecified anemia',
#  'Anemia of chronic disease',
#  'Iron deficiency anemia',
#  'Hemolytic anemia',
#  'Aplastic anemia',
#  'Inconclusive diagnosis',
#  'hemoglobin',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'tibc',
#  'mcv',
#  'serum_iron',
#  'rbc',
#  'gender',
#  'creatinine',
#  'cholestrol',
#  'copper',
#  'ethanol',
#  'folate',
#  'glucose',
#  'hematocrit',
#  'tsat']

# %% [markdown]
# #### The Model

# %%
from stable_baselines3 import DQN

# %%
training_env = utils.create_env(X_train, y_train)
model = DQN('MlpPolicy', training_env, verbose=1, seed=constants.SEED)
checkpoint_callback = CheckpointCallback(save_freq=500000, 
                                         save_path='../../final/models/new_experiments/logs/trial_3',
                                         name_prefix='dqn_basic')
model.learn(total_timesteps=50000000, log_interval=500000, callback=checkpoint_callback)
model.save('../../final/models/new_experiments/dqn_basic_anemia_diagnosis_trial_3')
training_env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.729    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 2996     |
# |    time_elapsed     | 476      |
# |    total_timesteps  | 1426906  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.54e+06 |
# |    n_updates        | 344226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.88     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.457    |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 2826     |
# |    time_elapsed     | 1011     |
# |    total_timesteps  | 2860196  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.06e+06 |
# |    n_updates        | 702548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.189    |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 2704     |
# |    time_elapsed     | 1578     |
# |    total_timesteps  | 4268736  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39e+06 |
# |    n_updates        | 1054683  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 2608     |
# |    time_elapsed     | 2147     |
# |    total_timesteps  | 5603311  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.42e+05 |
# |    n_updates        | 1388327  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.88     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 2524     |
# |    time_elapsed     | 2751     |
# |    total_timesteps  | 6945999  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.55     |
# |    n_updates        | 1723999  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.51     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 3000000  |
# |    fps              | 2418     |
# |    time_elapsed     | 3484     |
# |    total_timesteps  | 8427540  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.313    |
# |    n_updates        | 2094384  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 3500000  |
# |    fps              | 2287     |
# |    time_elapsed     | 4125     |
# |    total_timesteps  | 9437581  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0894   |
# |    n_updates        | 2346895  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 4000000  |
# |    fps              | 2222     |
# |    time_elapsed     | 4505     |
# |    total_timesteps  | 10010978 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.215    |
# |    n_updates        | 2490244  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 4500000  |
# |    fps              | 2155     |
# |    time_elapsed     | 4886     |
# |    total_timesteps  | 10532834 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 2620708  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 5000000  |
# |    fps              | 2079     |
# |    time_elapsed     | 5316     |
# |    total_timesteps  | 11055858 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0955   |
# |    n_updates        | 2751464  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 5500000  |
# |    fps              | 2002     |
# |    time_elapsed     | 5781     |
# |    total_timesteps  | 11577358 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.262    |
# |    n_updates        | 2881839  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 6000000  |
# |    fps              | 1944     |
# |    time_elapsed     | 6222     |
# |    total_timesteps  | 12101539 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 3012884  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 6500000  |
# |    fps              | 1897     |
# |    time_elapsed     | 6654     |
# |    total_timesteps  | 12623814 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 3143453  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 7000000  |
# |    fps              | 1861     |
# |    time_elapsed     | 7063     |
# |    total_timesteps  | 13146899 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 3274224  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 7500000  |
# |    fps              | 1827     |
# |    time_elapsed     | 7482     |
# |    total_timesteps  | 13670762 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 3405190  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 8000000  |
# |    fps              | 1804     |
# |    time_elapsed     | 7867     |
# |    total_timesteps  | 14192573 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 3535643  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 8500000  |
# |    fps              | 1775     |
# |    time_elapsed     | 8289     |
# |    total_timesteps  | 14716302 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 3666575  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 9000000  |
# |    fps              | 1748     |
# |    time_elapsed     | 8717     |
# |    total_timesteps  | 15238450 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 3797112  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 9500000  |
# |    fps              | 1726     |
# |    time_elapsed     | 9128     |
# |    total_timesteps  | 15763512 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 3928377  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 10000000 |
# |    fps              | 1706     |
# |    time_elapsed     | 9542     |
# |    total_timesteps  | 16283238 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 4058309  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 10500000 |
# |    fps              | 1685     |
# |    time_elapsed     | 9970     |
# |    total_timesteps  | 16808245 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0957   |
# |    n_updates        | 4189561  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 11000000 |
# |    fps              | 1667     |
# |    time_elapsed     | 10394    |
# |    total_timesteps  | 17328556 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 4319638  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 11500000 |
# |    fps              | 1649     |
# |    time_elapsed     | 10823    |
# |    total_timesteps  | 17853623 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 4450905  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 12000000 |
# |    fps              | 1633     |
# |    time_elapsed     | 11246    |
# |    total_timesteps  | 18373902 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 4580975  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 12500000 |
# |    fps              | 1619     |
# |    time_elapsed     | 11671    |
# |    total_timesteps  | 18898538 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.343    |
# |    n_updates        | 4712134  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 13000000 |
# |    fps              | 1606     |
# |    time_elapsed     | 12086    |
# |    total_timesteps  | 19418910 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 4842227  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 13500000 |
# |    fps              | 1595     |
# |    time_elapsed     | 12502    |
# |    total_timesteps  | 19944328 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 4973581  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 14000000 |
# |    fps              | 1582     |
# |    time_elapsed     | 12930    |
# |    total_timesteps  | 20464772 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 5103692  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 14500000 |
# |    fps              | 1571     |
# |    time_elapsed     | 13357    |
# |    total_timesteps  | 20988552 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 5234637  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 15000000 |
# |    fps              | 1560     |
# |    time_elapsed     | 13783    |
# |    total_timesteps  | 21510364 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 5365090  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 15500000 |
# |    fps              | 1551     |
# |    time_elapsed     | 14205    |
# |    total_timesteps  | 22034199 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 5496049  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 16000000 |
# |    fps              | 1543     |
# |    time_elapsed     | 14613    |
# |    total_timesteps  | 22555290 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 5626322  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 16500000 |
# |    fps              | 1535     |
# |    time_elapsed     | 15027    |
# |    total_timesteps  | 23078425 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 5757106  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 17000000 |
# |    fps              | 1527     |
# |    time_elapsed     | 15451    |
# |    total_timesteps  | 23600113 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.097    |
# |    n_updates        | 5887528  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 17500000 |
# |    fps              | 1519     |
# |    time_elapsed     | 15877    |
# |    total_timesteps  | 24125835 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0964   |
# |    n_updates        | 6018958  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 18000000 |
# |    fps              | 1511     |
# |    time_elapsed     | 16301    |
# |    total_timesteps  | 24645133 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0964   |
# |    n_updates        | 6148783  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 18500000 |
# |    fps              | 1505     |
# |    time_elapsed     | 16722    |
# |    total_timesteps  | 25172450 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 6280612  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 19000000 |
# |    fps              | 1500     |
# |    time_elapsed     | 17129    |
# |    total_timesteps  | 25694944 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 6411235  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 19500000 |
# |    fps              | 1493     |
# |    time_elapsed     | 17556    |
# |    total_timesteps  | 26219498 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 6542374  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 20000000 |
# |    fps              | 1487     |
# |    time_elapsed     | 17981    |
# |    total_timesteps  | 26739372 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.259    |
# |    n_updates        | 6672342  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 20500000 |
# |    fps              | 1480     |
# |    time_elapsed     | 18411    |
# |    total_timesteps  | 27265041 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 6803760  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 21000000 |
# |    fps              | 1470     |
# |    time_elapsed     | 18894    |
# |    total_timesteps  | 27785607 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0955   |
# |    n_updates        | 6933901  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 21500000 |
# |    fps              | 1465     |
# |    time_elapsed     | 19313    |
# |    total_timesteps  | 28309313 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 7064828  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 22000000 |
# |    fps              | 1470     |
# |    time_elapsed     | 19606    |
# |    total_timesteps  | 28829685 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 7194921  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 22500000 |
# |    fps              | 1475     |
# |    time_elapsed     | 19894    |
# |    total_timesteps  | 29354461 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 7326115  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 23000000 |
# |    fps              | 1479     |
# |    time_elapsed     | 20194    |
# |    total_timesteps  | 29876156 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 7456538  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 23500000 |
# |    fps              | 1473     |
# |    time_elapsed     | 20630    |
# |    total_timesteps  | 30400547 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 7587636  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 24000000 |
# |    fps              | 1471     |
# |    time_elapsed     | 21008    |
# |    total_timesteps  | 30921753 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.384    |
# |    n_updates        | 7717938  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 24500000 |
# |    fps              | 1468     |
# |    time_elapsed     | 21409    |
# |    total_timesteps  | 31444921 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 7848730  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 25000000 |
# |    fps              | 1470     |
# |    time_elapsed     | 21735    |
# |    total_timesteps  | 31969299 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.262    |
# |    n_updates        | 7979824  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 25500000 |
# |    fps              | 1472     |
# |    time_elapsed     | 22062    |
# |    total_timesteps  | 32491577 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 8110394  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 26000000 |
# |    fps              | 1469     |
# |    time_elapsed     | 22465    |
# |    total_timesteps  | 33016283 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0542   |
# |    n_updates        | 8241570  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 26500000 |
# |    fps              | 1461     |
# |    time_elapsed     | 22947    |
# |    total_timesteps  | 33537079 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 8371769  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 27000000 |
# |    fps              | 1449     |
# |    time_elapsed     | 23491    |
# |    total_timesteps  | 34060362 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 8502590  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 27500000 |
# |    fps              | 1436     |
# |    time_elapsed     | 24070    |
# |    total_timesteps  | 34580278 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 8632569  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 28000000 |
# |    fps              | 1429     |
# |    time_elapsed     | 24561    |
# |    total_timesteps  | 35106305 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0538   |
# |    n_updates        | 8764076  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.8     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 28500000 |
# |    fps              | 1423     |
# |    time_elapsed     | 25035    |
# |    total_timesteps  | 35626166 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 8894041  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 29000000 |
# |    fps              | 1416     |
# |    time_elapsed     | 25526    |
# |    total_timesteps  | 36150884 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 9025220  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 29500000 |
# |    fps              | 1409     |
# |    time_elapsed     | 26017    |
# |    total_timesteps  | 36671839 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.384    |
# |    n_updates        | 9155459  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 30000000 |
# |    fps              | 1408     |
# |    time_elapsed     | 26409    |
# |    total_timesteps  | 37195538 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 9286384  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 30500000 |
# |    fps              | 1410     |
# |    time_elapsed     | 26743    |
# |    total_timesteps  | 37716459 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 9416614  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 31000000 |
# |    fps              | 1414     |
# |    time_elapsed     | 27025    |
# |    total_timesteps  | 38239698 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 9547424  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 31500000 |
# |    fps              | 1419     |
# |    time_elapsed     | 27303    |
# |    total_timesteps  | 38762715 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 9678178  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 32000000 |
# |    fps              | 1424     |
# |    time_elapsed     | 27583    |
# |    total_timesteps  | 39285231 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 9808807  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 32500000 |
# |    fps              | 1428     |
# |    time_elapsed     | 27866    |
# |    total_timesteps  | 39808254 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 9939563  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 33000000 |
# |    fps              | 1433     |
# |    time_elapsed     | 28143    |
# |    total_timesteps  | 40331951 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0962   |
# |    n_updates        | 10070487 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 33500000 |
# |    fps              | 1437     |
# |    time_elapsed     | 28420    |
# |    total_timesteps  | 40853475 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 10200868 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 34000000 |
# |    fps              | 1441     |
# |    time_elapsed     | 28699    |
# |    total_timesteps  | 41376011 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 10331502 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 34500000 |
# |    fps              | 1443     |
# |    time_elapsed     | 29030    |
# |    total_timesteps  | 41897670 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.302    |
# |    n_updates        | 10461917 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 35000000 |
# |    fps              | 1443     |
# |    time_elapsed     | 29391    |
# |    total_timesteps  | 42420495 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 10592623 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 35500000 |
# |    fps              | 1444     |
# |    time_elapsed     | 29726    |
# |    total_timesteps  | 42941699 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 10722924 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.8     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 36000000 |
# |    fps              | 1446     |
# |    time_elapsed     | 30052    |
# |    total_timesteps  | 43464491 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 10853622 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 36500000 |
# |    fps              | 1448     |
# |    time_elapsed     | 30376    |
# |    total_timesteps  | 43986864 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0537   |
# |    n_updates        | 10984215 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 37000000 |
# |    fps              | 1449     |
# |    time_elapsed     | 30702    |
# |    total_timesteps  | 44509663 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 11114915 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 37500000 |
# |    fps              | 1451     |
# |    time_elapsed     | 31026    |
# |    total_timesteps  | 45031866 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 11245466 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 38000000 |
# |    fps              | 1453     |
# |    time_elapsed     | 31352    |
# |    total_timesteps  | 45555924 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 11376480 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 38500000 |
# |    fps              | 1454     |
# |    time_elapsed     | 31674    |
# |    total_timesteps  | 46078096 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0945   |
# |    n_updates        | 11507023 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 39000000 |
# |    fps              | 1456     |
# |    time_elapsed     | 32001    |
# |    total_timesteps  | 46599590 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 11637397 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 39500000 |
# |    fps              | 1457     |
# |    time_elapsed     | 32322    |
# |    total_timesteps  | 47121721 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 11767930 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 40000000 |
# |    fps              | 1454     |
# |    time_elapsed     | 32766    |
# |    total_timesteps  | 47644394 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 11898598 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 40500000 |
# |    fps              | 1453     |
# |    time_elapsed     | 33139    |
# |    total_timesteps  | 48167309 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0957   |
# |    n_updates        | 12029327 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 41000000 |
# |    fps              | 1454     |
# |    time_elapsed     | 33467    |
# |    total_timesteps  | 48691103 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.18     |
# |    n_updates        | 12160275 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 41500000 |
# |    fps              | 1455     |
# |    time_elapsed     | 33814    |
# |    total_timesteps  | 49212808 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 12290701 |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 42000000 |
# |    fps              | 1457     |
# |    time_elapsed     | 34118    |
# |    total_timesteps  | 49736426 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.219    |
# |    n_updates        | 12421606 |
# ----------------------------------

# %% [markdown]
# #### Original trial

# %%
# from stable_baselines3 import DQN
from stable_baselines import DQN
# from stable_baselines3 import bench, logger
from modules.many_features.env import SyntheticEnv
from stable_baselines.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines.common.callbacks import CheckpointCallback

# %%
training_env = SyntheticEnv(X_train, y_train)
training_env = DummyVecEnv([lambda: training_env])
# training_env = VecNormalize(training_env, norm_obs=True, norm_reward=False, clip_obs=10.)

# Define and train the DQN agent
model = DQN('MlpPolicy', training_env, verbose=1, seed = constants.SEED)
checkpoint_callback = CheckpointCallback(save_freq=100000, 
                                         save_path='../../final/models/new_experiments/logs/basic_sb',
                                         name_prefix='dqn_sb_basic')

model.learn(total_timesteps=20000000, log_interval=100000, callback=checkpoint_callback)

# Save the trained DQN agent
model.save('../../final/models/new_experiments/dqn_basic_anemia_diagnosis_sb')
training_env.close()
