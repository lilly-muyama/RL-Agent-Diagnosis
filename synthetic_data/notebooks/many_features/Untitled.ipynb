# %%
import pandas as pd
import numpy as np
import random
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('../../final/data/train_set_noisy_2.csv')
df = df.fillna(-1)
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    8.839534  485.156879   2.994892               0.000000  453.705337
# 1   10.306951   -1.000000  -1.000000               3.269642  361.637557
# 2    6.488013   80.274764   4.562126               4.233714  116.337191
# 3   14.955260  485.921046   0.617386              -1.000000  289.623796
# 4    7.098801   -1.000000  -1.000000               3.218910  495.647437
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0  102.432354   -1.000000  2.588889       1    1.452379  115.041719
# 1  101.949912  213.802158  3.032946       0    1.983531    3.371683
# 2   77.768892   -1.000000  2.502805       0    1.047531   74.749421
# 3  104.128070   -1.000000  4.308711       1   -1.000000   -1.000000
# 4  101.448129   -1.000000  2.099241       0    0.395440  123.077820
#
#        copper    ethanol     folate    glucose  hematocrit       tsat  label
# ...
