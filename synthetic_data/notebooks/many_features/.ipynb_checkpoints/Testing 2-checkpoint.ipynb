# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random
import os
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %% [markdown]
# #### The Data

# %%
#df = pd.read_csv('../../data/anemia_synth_dataset_some_nans_unspecified_more_feats.csv')
#df = pd.read_csv('../../data/more_feats_0.2.csv')
#df= pd.read_csv('../../data/more_features/more_feats_new_labels_0.1.csv')
#df =pd.read_csv('../../data/more_features/more_feats_new_labels_0.1_noisy_0.6.csv')
df = pd.read_csv('../../data/more_features//more_feats_correlated_noisy_4.csv')
#df = utils.balance_dataset(df, 8000)
df = df.fillna(-1)
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    8.725667   -1.000000   2.344526              -1.000000   -1.000000
# 1   12.430232  231.691743   5.143660               5.339158  484.590922
# 2    6.737760  360.843434  -1.000000               5.481140  421.177091
# 3   12.313034   -1.000000   2.765581               0.000000   -1.000000
# 4    6.758140   -1.000000   1.696525               5.648115   -1.000000
#
#          mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0  96.678418   -1.000000  2.707637       1   -1.000000   -1.000000
# 1  87.353532   -1.000000  4.268940       0   -1.000000   -1.000000
# 2  75.086568   82.986344  2.691997       0    0.458698   19.596767
# 3  99.494524   -1.000000  3.712677       1   -1.000000   -1.000000
# 4  86.643128  199.741346  2.339992       0    0.887158   80.614718
#
#        copper    ethanol     folate    glucose  hematocrit       tsat  \
# 0   -1.000000  -1.000000  -1.000000  -1.000000   26.177001  -1.000000
# 1   -1.000000   8.718062  -1.000000  -1.000000   37.290695  -1.000000
# 2   69.527433  -1.000000  23.027617  -1.000000   20.213279  19.703433
# 3   -1.000000  -1.000000  -1.000000  -1.000000   36.939103  -1.000000
# 4  109.197814  18.770122   7.668335  63.159054   20.274421  -1.000000
#
#                        label
# 0           Hemolytic anemia
# 1                  No anemia
# 2  Anemia of chronic disease
# 3         Unspecified anemia
# 4            Aplastic anemia

# %%
df.isna().sum()
# Out:
# hemoglobin               0
# ferritin                 0
# ret_count                0
# segmented_neutrophils    0
# tibc                     0
# mcv                      0
# serum_iron               0
# rbc                      0
# gender                   0
# creatinine               0
# cholestrol               0
# copper                   0
# ethanol                  0
# folate                   0
# glucose                  0
# hematocrit               0
# tsat                     0
# label                    0
# dtype: int64

# %%
utils.get_dt_performance(df)
# Out:
# (0.7016428571428571,
#  0.7005761070620158,
#  0.8266962007922731,
#  datetime.timedelta(microseconds=4772))

# %%
df.label.value_counts()
# Out:
# No anemia                               16000
# Anemia of chronic disease                8816
# Iron deficiency anemia                   8309
# Aplastic anemia                          8157
# Unspecified anemia                       8132
# Vitamin B12/Folate deficiency anemia     8124
# Hemolytic anemia                         8057
# Inconclusive diagnosis                   4405
# Name: label, dtype: int64

# %%
class_dict = constants.CLASS_DICT
df['label'] = df['label'].replace(class_dict)
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((56000, 17), (14000, 17), (56000,), (14000,))

# %%
action_list = list(class_dict.keys()) + [col  for col in df.columns if col!='label']
action_list
# Out:
# ['No anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Unspecified anemia',
#  'Anemia of chronic disease',
#  'Iron deficiency anemia',
#  'Hemolytic anemia',
#  'Aplastic anemia',
#  'Inconclusive diagnosis',
#  'hemoglobin',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'tibc',
#  'mcv',
#  'serum_iron',
#  'rbc',
#  'gender',
#  'creatinine',
#  'cholestrol',
#  'copper',
#  'ethanol',
#  'folate',
#  'glucose',
#  'hematocrit',
#  'tsat']

# %%
len(action_list)
# Out:
# 25

# %%
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    8.725667   -1.000000   2.344526              -1.000000   -1.000000
# 1   12.430232  231.691743   5.143660               5.339158  484.590922
# 2    6.737760  360.843434  -1.000000               5.481140  421.177091
# 3   12.313034   -1.000000   2.765581               0.000000   -1.000000
# 4    6.758140   -1.000000   1.696525               5.648115   -1.000000
#
#          mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0  96.678418   -1.000000  2.707637       1   -1.000000   -1.000000
# 1  87.353532   -1.000000  4.268940       0   -1.000000   -1.000000
# 2  75.086568   82.986344  2.691997       0    0.458698   19.596767
# 3  99.494524   -1.000000  3.712677       1   -1.000000   -1.000000
# 4  86.643128  199.741346  2.339992       0    0.887158   80.614718
#
#        copper    ethanol     folate    glucose  hematocrit       tsat  label
# 0   -1.000000  -1.000000  -1.000000  -1.000000   26.177001  -1.000000      5
# 1   -1.000000   8.718062  -1.000000  -1.000000   37.290695  -1.000000      0
# 2   69.527433  -1.000000  23.027617  -1.000000   20.213279  19.703433      3
# 3   -1.000000  -1.000000  -1.000000  -1.000000   36.939103  -1.000000      2
# 4  109.197814  18.770122   7.668335  63.159054   20.274421  -1.000000      6

# %% [markdown]
# #### Training

# %%
# %%time
# timesteps = int(2e6)
# dqn_model = utils.stable_dqn3(X_train, y_train, timesteps, True, f'../../models/many_features/stable_dqn3_{timesteps}')
# test_df = utils.evaluate_dqn(dqn_model, X_test, y_test)
# test_df.head()

# %%
#for steps in [int(6e6), int(6.5e6), int(7e6), int(7.5e6), int(8e6), int(8.5e6), int(9e6)]:
for steps in [int(9.5e6), int(10.5e6), int(11.5e6), int(12.5e6), int(13.5e6)]:
    #start_time = datetime.now()
    dqn_model = utils.stable_dqn3(X_train, y_train, steps, True, 
                                  f'../../models/many_features/0.1/with_correlated_fts/dqn3_by_type_noisy_4_{steps}')
    #end_time = datetime.now()
    #print(f'The duration for {steps} steps is {end_time-start_time}')
# Out:
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.705    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 623      |
# |    time_elapsed     | 473      |
# |    total_timesteps  | 295184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.22     |
# |    n_updates        | 61295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.346    |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 555      |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 653509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.4     |
# |    n_updates        | 150877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 519      |
# |    time_elapsed     | 1929     |
# |    total_timesteps  | 1001786  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14.2     |
# |    n_updates        | 237946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.38     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 512      |
# |    time_elapsed     | 2747     |
# |    total_timesteps  | 1409101  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 339775   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.49     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 533      |
# |    time_elapsed     | 3494     |
# |    total_timesteps  | 1863798  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 453449   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7      |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 544      |
# |    time_elapsed     | 4237     |
# |    total_timesteps  | 2308555  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0507   |
# |    n_updates        | 564638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.35     |
# |    ep_rew_mean      | -0.38    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.32     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 551      |
# |    time_elapsed     | 5009     |
# |    total_timesteps  | 2764137  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0681   |
# |    n_updates        | 678534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.37     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 555      |
# |    time_elapsed     | 5762     |
# |    total_timesteps  | 3204019  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0774   |
# |    n_updates        | 788504   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 559      |
# |    time_elapsed     | 6470     |
# |    total_timesteps  | 3617782  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 891945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | -0.14    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.44     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 561      |
# |    time_elapsed     | 7199     |
# |    total_timesteps  | 4044519  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0975   |
# |    n_updates        | 998629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.7      |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.42     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 564      |
# |    time_elapsed     | 7941     |
# |    total_timesteps  | 4479233  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 1107308  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 565      |
# |    time_elapsed     | 8677     |
# |    total_timesteps  | 4910122  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 1215030  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | -0.28    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.38     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 567      |
# |    time_elapsed     | 9400     |
# |    total_timesteps  | 5333330  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0635   |
# |    n_updates        | 1320832  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.56     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.41     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 568      |
# |    time_elapsed     | 10134    |
# |    total_timesteps  | 5762875  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 1428218  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 569      |
# |    time_elapsed     | 10860    |
# |    total_timesteps  | 6188340  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.211    |
# |    n_updates        | 1534584  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42     |
# |    ep_rew_mean      | -0.22    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 570      |
# |    time_elapsed     | 11588    |
# |    total_timesteps  | 6613768  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 1640941  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 571      |
# |    time_elapsed     | 12306    |
# |    total_timesteps  | 7032294  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 1745573  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.51     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 571      |
# |    time_elapsed     | 13040    |
# |    total_timesteps  | 7455878  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0935   |
# |    n_updates        | 1851469  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | -0.02    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.54     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 572      |
# |    time_elapsed     | 13834    |
# |    total_timesteps  | 7919172  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 1967292  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.57     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.69     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 572      |
# |    time_elapsed     | 14592    |
# |    total_timesteps  | 8360799  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 2077699  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.75     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 573      |
# |    time_elapsed     | 15322    |
# |    total_timesteps  | 8786864  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.133    |
# |    n_updates        | 2184215  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 573      |
# |    time_elapsed     | 16051    |
# |    total_timesteps  | 9208901  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0961   |
# |    n_updates        | 2289725  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.735    |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 906      |
# |    time_elapsed     | 322      |
# |    total_timesteps  | 292417   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14.5     |
# |    n_updates        | 60604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.419    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 789      |
# |    time_elapsed     | 813      |
# |    total_timesteps  | 642619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.3     |
# |    n_updates        | 148154   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.0944   |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 732      |
# |    time_elapsed     | 1367     |
# |    total_timesteps  | 1000917  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 26.6     |
# |    n_updates        | 237729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 694      |
# |    time_elapsed     | 1981     |
# |    total_timesteps  | 1376503  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 331625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.25     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 670      |
# |    time_elapsed     | 2789     |
# |    total_timesteps  | 1871532  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0974   |
# |    n_updates        | 455382   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.63     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 657      |
# |    time_elapsed     | 3551     |
# |    total_timesteps  | 2333445  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0591   |
# |    n_updates        | 570861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27     |
# |    ep_rew_mean      | -0.4     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 646      |
# |    time_elapsed     | 4277     |
# |    total_timesteps  | 2766878  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0699   |
# |    n_updates        | 679219   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.59     |
# |    ep_rew_mean      | -0.36    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.37     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 638      |
# |    time_elapsed     | 4993     |
# |    total_timesteps  | 3190042  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0608   |
# |    n_updates        | 785010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | -0.48    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.28     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 632      |
# |    time_elapsed     | 5730     |
# |    total_timesteps  | 3622152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 893037   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 623      |
# |    time_elapsed     | 6476     |
# |    total_timesteps  | 4037795  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.192    |
# |    n_updates        | 996948   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91     |
# |    ep_rew_mean      | -0.1     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.46     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 604      |
# |    time_elapsed     | 7365     |
# |    total_timesteps  | 4449271  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.15     |
# |    n_updates        | 1099817  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | -0.18    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 567      |
# |    time_elapsed     | 8535     |
# |    total_timesteps  | 4846287  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 1199071  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | -0.12    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.44     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 538      |
# |    time_elapsed     | 9739     |
# |    total_timesteps  | 5249145  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0944   |
# |    n_updates        | 1299786  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 513      |
# |    time_elapsed     | 10991    |
# |    total_timesteps  | 5648799  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 1399699  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 500      |
# |    time_elapsed     | 12104    |
# |    total_timesteps  | 6052399  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 1500599  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04     |
# |    ep_rew_mean      | -0.36    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 490      |
# |    time_elapsed     | 13156    |
# |    total_timesteps  | 6449584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 1599895  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.51     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 491      |
# |    time_elapsed     | 13923    |
# |    total_timesteps  | 6848791  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 1699697  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8      |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 492      |
# |    time_elapsed     | 14706    |
# |    total_timesteps  | 7247192  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0654   |
# |    n_updates        | 1799297  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.49     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 494      |
# |    time_elapsed     | 15452    |
# |    total_timesteps  | 7647989  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 1899497  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.52     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 495      |
# |    time_elapsed     | 16238    |
# |    total_timesteps  | 8054032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 2001007  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.61     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 498      |
# |    time_elapsed     | 16981    |
# |    total_timesteps  | 8457817  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0366   |
# |    n_updates        | 2101954  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88     |
# |    ep_rew_mean      | -0.14    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.49     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 499      |
# |    time_elapsed     | 17738    |
# |    total_timesteps  | 8866752  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 2204187  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 502      |
# |    time_elapsed     | 18472    |
# |    total_timesteps  | 9284452  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 2308612  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.56     |
# | time/               |          |
# |    episodes         | 2400000  |
# |    fps              | 504      |
# |    time_elapsed     | 19256    |
# |    total_timesteps  | 9716273  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.159    |
# |    n_updates        | 2416568  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 505      |
# |    time_elapsed     | 20060    |
# |    total_timesteps  | 10133800 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 2520949  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.81     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.761    |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 881      |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 288954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.35     |
# |    n_updates        | 59738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.477    |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 652      |
# |    time_elapsed     | 970      |
# |    total_timesteps  | 633345   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 23.4     |
# |    n_updates        | 145836   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.173    |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 573      |
# |    time_elapsed     | 1745     |
# |    total_timesteps  | 1001317  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 19.2     |
# |    n_updates        | 237829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 542      |
# |    time_elapsed     | 2493     |
# |    total_timesteps  | 1352933  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.32     |
# |    n_updates        | 325733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.18     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 522      |
# |    time_elapsed     | 3456     |
# |    total_timesteps  | 1805756  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0974   |
# |    n_updates        | 438938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.63     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 508      |
# |    time_elapsed     | 4501     |
# |    total_timesteps  | 2290352  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0832   |
# |    n_updates        | 560087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 495      |
# |    time_elapsed     | 5476     |
# |    total_timesteps  | 2712091  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0805   |
# |    n_updates        | 665522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.51     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.39     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 499      |
# |    time_elapsed     | 6245     |
# |    total_timesteps  | 3122467  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0553   |
# |    n_updates        | 768116   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.79     |
# |    ep_rew_mean      | -0.5     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.29     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 501      |
# |    time_elapsed     | 6979     |
# |    total_timesteps  | 3501960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 862989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 501      |
# |    time_elapsed     | 7785     |
# |    total_timesteps  | 3902257  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 963064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.67     |
# |    ep_rew_mean      | -0.32    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 501      |
# |    time_elapsed     | 8592     |
# |    total_timesteps  | 4312878  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 1065719  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | -0.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.5      |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 503      |
# |    time_elapsed     | 9379     |
# |    total_timesteps  | 4724654  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 1168663  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.5      |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 503      |
# |    time_elapsed     | 10194    |
# |    total_timesteps  | 5133197  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 1270799  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25     |
# |    ep_rew_mean      | -0.1     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.49     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 505      |
# |    time_elapsed     | 10972    |
# |    total_timesteps  | 5543620  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 1373404  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 509      |
# |    time_elapsed     | 11689    |
# |    total_timesteps  | 5952444  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0817   |
# |    n_updates        | 1475610  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.57     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 513      |
# |    time_elapsed     | 12381    |
# |    total_timesteps  | 6361167  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.081    |
# |    n_updates        | 1577791  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.68     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 520      |
# |    time_elapsed     | 13024    |
# |    total_timesteps  | 6777814  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.069    |
# |    n_updates        | 1681953  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 526      |
# |    time_elapsed     | 13670    |
# |    total_timesteps  | 7195219  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 1786304  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 531      |
# |    time_elapsed     | 14318    |
# |    total_timesteps  | 7615094  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 1891273  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.41     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.69     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 536      |
# |    time_elapsed     | 14961    |
# |    total_timesteps  | 8029248  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0888   |
# |    n_updates        | 1994811  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.68     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 541      |
# |    time_elapsed     | 15609    |
# |    total_timesteps  | 8447269  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 2099317  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.63     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 545      |
# |    time_elapsed     | 16269    |
# |    total_timesteps  | 8872228  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 2205556  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 549      |
# |    time_elapsed     | 16928    |
# |    total_timesteps  | 9295765  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0741   |
# |    n_updates        | 2311441  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.71     |
# | time/               |          |
# |    episodes         | 2400000  |
# |    fps              | 552      |
# |    time_elapsed     | 17585    |
# |    total_timesteps  | 9719266  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 2417316  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.71     |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 555      |
# |    time_elapsed     | 18249    |
# |    total_timesteps  | 10145534 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.186    |
# |    n_updates        | 2523883  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 2600000  |
# |    fps              | 559      |
# |    time_elapsed     | 18911    |
# |    total_timesteps  | 10572583 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0864   |
# |    n_updates        | 2630645  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 2700000  |
# |    fps              | 561      |
# |    time_elapsed     | 19575    |
# |    total_timesteps  | 10996874 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 2736718  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07     |
# |    ep_rew_mean      | -0.02    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.53     |
# | time/               |          |
# |    episodes         | 2800000  |
# |    fps              | 564      |
# |    time_elapsed     | 20247    |
# |    total_timesteps  | 11424710 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0999   |
# |    n_updates        | 2843677  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.781    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1018     |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 287631   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.3      |
# |    n_updates        | 59407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.524    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 885      |
# |    time_elapsed     | 707      |
# |    total_timesteps  | 626231   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 20.3     |
# |    n_updates        | 144057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.242    |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 824      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 996811   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.9     |
# |    n_updates        | 236702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 782      |
# |    time_elapsed     | 1720     |
# |    total_timesteps  | 1345213  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.7     |
# |    n_updates        | 323803   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.81     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 752      |
# |    time_elapsed     | 2335     |
# |    total_timesteps  | 1758539  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.494    |
# |    n_updates        | 427134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.25     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 732      |
# |    time_elapsed     | 3031     |
# |    total_timesteps  | 2220581  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0516   |
# |    n_updates        | 542645   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 718      |
# |    time_elapsed     | 3652     |
# |    total_timesteps  | 2625819  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 643954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | -0.4     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.38     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 709      |
# |    time_elapsed     | 4292     |
# |    total_timesteps  | 3045229  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0872   |
# |    n_updates        | 748807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 701      |
# |    time_elapsed     | 4918     |
# |    total_timesteps  | 3451287  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.07     |
# |    n_updates        | 850321   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | -0.38    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.33     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 695      |
# |    time_elapsed     | 5562     |
# |    total_timesteps  | 3869307  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0547   |
# |    n_updates        | 1505525  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.44     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 673      |
# |    time_elapsed     | 9673     |
# |    total_timesteps  | 6515052  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0697   |
# |    n_updates        | 1616262  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.51     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 671      |
# |    time_elapsed     | 10370    |
# |    total_timesteps  | 6962796  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0677   |
# |    n_updates        | 1728198  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.64     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.58     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 669      |
# |    time_elapsed     | 11074    |
# |    total_timesteps  | 7416692  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0969   |
# |    n_updates        | 1841672  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.66     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 667      |
# |    time_elapsed     | 11790    |
# |    total_timesteps  | 7874170  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0949   |
# |    n_updates        | 1956042  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.75     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.61     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 666      |
# |    time_elapsed     | 12508    |
# |    total_timesteps  | 8336678  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 2071669  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.73     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 664      |
# |    time_elapsed     | 13233    |
# |    total_timesteps  | 8799822  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0904   |
# |    n_updates        | 2187455  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.58     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.58     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 663      |
# |    time_elapsed     | 13955    |
# |    total_timesteps  | 9261197  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 2302799  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.92     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 662      |
# |    time_elapsed     | 14673    |
# |    total_timesteps  | 9721893  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 2417973  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.7      |
# | time/               |          |
# |    episodes         | 2400000  |
# |    fps              | 661      |
# |    time_elapsed     | 15390    |
# |    total_timesteps  | 10182572 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0399   |
# |    n_updates        | 2533142  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.57     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 660      |
# |    time_elapsed     | 16117    |
# |    total_timesteps  | 10646851 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0517   |
# |    n_updates        | 2649212  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.65     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.63     |
# | time/               |          |
# |    episodes         | 2600000  |
# |    fps              | 659      |
# |    time_elapsed     | 16834    |
# |    total_timesteps  | 11107861 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.131    |
# |    n_updates        | 2764465  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.67     |
# |    ep_rew_mean      | -0.1     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.5      |
# | time/               |          |
# |    episodes         | 2700000  |
# |    fps              | 659      |
# |    time_elapsed     | 17553    |
# |    total_timesteps  | 11569816 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0452   |
# |    n_updates        | 2879953  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.4      |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 2800000  |
# |    fps              | 658      |
# |    time_elapsed     | 18273    |
# |    total_timesteps  | 12031738 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0597   |
# |    n_updates        | 2995434  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.57     |
# | time/               |          |
# |    episodes         | 2900000  |
# |    fps              | 657      |
# |    time_elapsed     | 18993    |
# |    total_timesteps  | 12495767 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 3111441  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.9      |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.798    |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1027     |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 286563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.99     |
# |    n_updates        | 59140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.567    |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 902      |
# |    time_elapsed     | 681      |
# |    total_timesteps  | 615197   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 57.6     |
# |    n_updates        | 141299   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26     |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.296    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 837      |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 1000772  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.4     |
# |    n_updates        | 237692   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.0561   |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 797      |
# |    time_elapsed     | 1682     |
# |    total_timesteps  | 1341390  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38.5     |
# |    n_updates        | 322847   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 765      |
# |    time_elapsed     | 2287     |
# |    total_timesteps  | 1751315  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17     |
# |    n_updates        | 425328   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39     |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 745      |
# |    time_elapsed     | 2951     |
# |    total_timesteps  | 2199858  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 537464   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 730      |
# |    time_elapsed     | 3583     |
# |    total_timesteps  | 2618884  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 642220   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86     |
# |    ep_rew_mean      | -0.34    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 722      |
# |    time_elapsed     | 4215     |
# |    total_timesteps  | 3044267  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0407   |
# |    n_updates        | 748566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.48     |
# |    ep_rew_mean      | -0.38    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.33     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 713      |
# |    time_elapsed     | 4902     |
# |    total_timesteps  | 3498932  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0709   |
# |    n_updates        | 862232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.75     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 707      |
# |    time_elapsed     | 5550     |
# |    total_timesteps  | 3926869  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0998   |
# |    n_updates        | 969217   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32     |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.42     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 699      |
# |    time_elapsed     | 6242     |
# |    total_timesteps  | 4364665  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 1078666  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.75     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.44     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 674      |
# |    time_elapsed     | 7095     |
# |    total_timesteps  | 4787521  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0966   |
# |    n_updates        | 1184380  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6      |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 628      |
# |    time_elapsed     | 8286     |
# |    total_timesteps  | 5204424  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 1288605  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | -0.36    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.36     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 598      |
# |    time_elapsed     | 9395     |
# |    total_timesteps  | 5618590  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0958   |
# |    n_updates        | 1392147  |
# ----------------------------------

# %% [markdown]
# #### Testing

# %%
# training_env = utils.create_env(X_train, y_train)
# dqn_model = utils.load_dqn3('../../models/many_features/0.1/with_correlated_fts/dqn3_by_type_noisy_4_15000000', training_env)
# test_df = utils.evaluate_dqn(dqn_model, X_test, y_test)
# test_df.head()
# Out:
# Using stable baselines 3
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Count: 2800
# Count: 5600
# Count: 8400
# Count: 11200
# Count: 14000
# Testing done.....
#    episode_length  index  is_success  reward  terminated  \
# 0             6.0    0.0         1.0     1.0         0.0
# 1             5.0    1.0         1.0     1.0         0.0
# 2             5.0    2.0         1.0     1.0         0.0
# 3             6.0    3.0         1.0     1.0         0.0
# 4             4.0    4.0         0.0    -1.0         0.0
#
#                                           trajectory  y_actual  y_pred
# 0  [hemoglobin, rbc, mcv, tibc, gender, Iron defi...       4.0     4.0
# 1  [hemoglobin, rbc, mcv, tibc, Anemia of chronic...       3.0     3.0
# 2  [hemoglobin, rbc, mcv, tibc, Anemia of chronic...       3.0     3.0
# 3  [hemoglobin, gender, rbc, mcv, tibc, Iron defi...       4.0     4.0
# 4     [hemoglobin, rbc, ret_count, Hemolytic anemia]       2.0     5.0

# %%
success_rate, success_df = utils.success_rate(test_df)
success_rate
# Out:
# 79.11428571428571

# %%
avg_length, avg_return = utils.get_avg_length_reward(test_df)
avg_length, avg_return
# Out:
# (4.2282142857142855, 0.45685714285714285)

# %%
acc, f1, roc_auc = utils.test(test_df['y_actual'], test_df['y_pred'])
acc, f1, roc_auc
# Out:
# (0.7911428571428571, 0.7914943705040569, 0.8979100156731731)

# %%
test_df.y_pred.unique()
# Out:
# array([4., 3., 5., 1., 0., 6., 7., 2.])

# %%
test_df[test_df.y_pred==4]
# Out:
#        episode_length    index  is_success  reward  terminated  \
# 0                 4.0      0.0         1.0     1.0         0.0
# 1                 4.0      1.0         0.0    -1.0         0.0
# 8                 5.0      8.0         1.0     1.0         0.0
# 11                4.0     11.0         1.0     1.0         0.0
# 36                4.0     36.0         0.0    -1.0         0.0
# ...               ...      ...         ...     ...         ...
# 13966             4.0  13966.0         1.0     1.0         0.0
# 13970             4.0  13970.0         0.0    -1.0         0.0
# 13976             4.0  13976.0         1.0     1.0         0.0
# 13983             5.0  13983.0         1.0     1.0         0.0
# 13990             4.0  13990.0         0.0    -1.0         0.0
#
#                                               trajectory  y_actual  y_pred
# 0      [hemoglobin, rbc, ferritin, Iron deficiency an...       4.0     4.0
# 1      [hemoglobin, rbc, ferritin, Iron deficiency an...       3.0     4.0
# 8      [hemoglobin, gender, rbc, ferritin, Iron defic...       4.0     4.0
# 11     [hemoglobin, rbc, ferritin, Iron deficiency an...       4.0     4.0
# 36     [hemoglobin, rbc, ferritin, Iron deficiency an...       3.0     4.0
# ...                                                  ...       ...     ...
# 13966  [hemoglobin, rbc, ferritin, Iron deficiency an...       4.0     4.0
# 13970  [hemoglobin, rbc, ferritin, Iron deficiency an...       7.0     4.0
# 13976  [hemoglobin, rbc, ferritin, Iron deficiency an...       4.0     4.0
# 13983  [hemoglobin, gender, rbc, ferritin, Iron defic...       4.0     4.0
# 13990  [hemoglobin, rbc, ferritin, Iron deficiency an...       3.0     4.0
#
# [2024 rows x 8 columns]

# %% [markdown]
# #### Saving files

# %%
# test_df.to_csv(f'../../test_dfs/many_features/0.1/correlated/test_df3_9000000.csv', index=False)
# success_df.to_csv(f'../../test_dfs/many_features/0.1/correlated/success_df3_9000000.csv', index=False)

# %% [markdown]
# #### Confusion matrix and classification report

# %%
test_df = pd.read_csv('../../test_dfs/many_features/0.1/test_df3_6500000.csv')
test_df.head()

# %%
utils.plot_classification_report(test_df['y_actual'], test_df['y_pred'])

# %%
# def plot_confusion_matrix(y_actual, y_pred, save=False, filename=False):
#     from sklearn.metrics import confusion_matrix
#     cm = confusion_matrix(y_actual, y_pred)
#     cm_df = pd.DataFrame(cm, index = [0, 1, 2, 3, 4, 5, 6], columns = [0, 1, 2, 3, 4, 5, 6], dtype='object')
#     #cm_df = pd.DataFrame(cm, index = constants.CLASS_DICT.keys(), columns = constants.CLASS_DICT.keys())
#     plt.figure(figsize=(8, 6))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Anemia')
#     plt.xlabel('Predicted Anemia')
#     plt.tight_layout()
#     if save:
#         plt.savefig(filename)
#     plt.show()
#     plt.close()

# %%
utils.plot_confusion_matrix(test_df['y_actual'], test_df['y_pred'])
