# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
noisiness = [0, 1, 2, 3]
success_rate = {'random agent': [11.807, 11.807, 11.807, 11.807], 'dt agent': [100, 86.029, 73.664, 61.971], 'dqn agent': [95.250, 82.014, 69.107, 57.750]}
episode_length = {'random agent': [1.540, 1.540, 1.540, 1.540], 'dt agent': [4.007, 3.916, 3.832, 3.737], 'dqn agent': [5.260, 3.851, 3.725, 3.982]}
episode_reward = {'random agent': [-0.771, -0.771, -0.771, -0.771,], 'dt agent': [1, 0.721, 0.473, 0.239], 'dqn agent': [0.765, 0.500, 0.243, 0.015]}
acc = {'random agent': [0.118, 0.118, 0.118, 0.118], 'dt agent': [1, 0.860, 0.737, 0.620], 'dqn agent': [0.953, 0.820, 0.691, 0.578]}
f1 = {'random agent': [0.118, 0.118, 0.118, 0.118], 'dt agent': [1, 0.864, 0.767, 0.669], 'dqn agent': [0.948, 0.831, 0.727, 0.628]}
roc_auc = {'random agent': [0.498, 0.498, 0.498, 0.498],  'dt agent': [1, 0.924, 0.856, 0.793], 'dqn agent': [0.975, 0.902, 0.832, 0.770]}
metrics_dict = {'success_rate':success_rate, 'episode_length':episode_length, 'episode_reward':episode_reward, 'acc':acc, 'f1':f1, 'roc_auc':roc_auc}

# %% [markdown]
# #### Plotting success rate

# %%
metric ='success_rate'
df = pd.DataFrame()
df['missingness'] = [0, 1, 2, 3]
df['random agent'] = success_rate['random agent']
df['dt agent'] = success_rate['dt agent']
df['dqn agent'] = success_rate['dqn agent']
df.head()
# Out:
#    missingness  random agent  dt agent  dqn agent
# 0            0        11.807   100.000     95.250
# 1            1        11.807    86.029     82.014
# 2            2        11.807    73.664     69.107
# 3            3        11.807    61.971     57.750

# %%
data = pd.melt(df, ['missingness'])
data
# Out:
#     missingness      variable    value
# 0             0  random agent   11.807
# 1             1  random agent   11.807
# 2             2  random agent   11.807
# 3             3  random agent   11.807
# 4             0      dt agent  100.000
# 5             1      dt agent   86.029
# 6             2      dt agent   73.664
# 7             3      dt agent   61.971
# 8             0     dqn agent   95.250
# 9             1     dqn agent   82.014
# 10            2     dqn agent   69.107
# 11            3     dqn agent   57.750

# %%
data.dtypes
# Out:
# missingness      int64
# variable        object
# value          float64
# dtype: object

# %%
sns.lineplot(x='missingness', y = 'value', hue='variable', data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-19259cb41f82> in <module>
# ----> 1 sns.lineplot(x='missingness', y = 'value', hue='variable', data=data)
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     322             val = sanitize_array(
# --> 323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#     325
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1459                 value = ensure_str(value)
#    1460
# -> 1461         subarr = np.empty(length, dtype=dtype)
#    1462         subarr.fill(value)
#    1463
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
def plot_noisiness_performance(metric):
    metric_dict = metrics_dict[metric]
    df= pd.DataFrame()
    df['missingness'] = [0, 1, 2, 3]
    df['random agent'] = metric_dict['random agent']
    df['dt agent'] = metric_dict['dt agent']
    df['dqn agent'] = metric_dict['dqn agent']
    
    plt.title(metric)
    plt.ylabel(metric)
    sns.lineplot(x='missingness', y='value', hue='variable', 
             data=pd.melt(df, ['missingness']))

# %% [markdown]
# #### Success Rate

# %%
plot_noisiness_performance('success_rate')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6a8791d784c6> in <module>
# ----> 1 plot_noisiness_performance('success_rate')
#
# <ipython-input-4-d37ba87bb321> in plot_noisiness_performance(metric)
#      10     plt.ylabel(metric)
#      11     sns.lineplot(x='noise level', y='value', hue='variable',
# ---> 12              data=pd.melt(df, ['noise level']))
#      13
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1076         dashes=dashes, markers=markers, style_order=style_order,
#    1077         units=units, estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1078         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1079     )
#    1080
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     322             val = sanitize_array(
# --> 323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#     325
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1459                 value = ensure_str(value)
#    1460
# -> 1461         subarr = np.empty(length, dtype=dtype)
#    1462         subarr.fill(value)
#    1463
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# #### Episode length

# %%
plot_noisiness_performance('episode_length')

# %% [markdown]
# #### Episode reward

# %%
plot_noisiness_performance('episode_reward')

# %% [markdown]
# #### Accuracy

# %%
plot_noisiness_performance('acc')

# %% [markdown]
# #### F1

# %%
plot_noisiness_performance('f1')

# %% [markdown]
# #### ROC-AUC

# %%
plot_noisiness_performance('roc_auc')
