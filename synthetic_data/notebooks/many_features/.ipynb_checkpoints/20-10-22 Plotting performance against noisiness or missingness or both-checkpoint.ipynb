# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_performance(metric, analysis_type, has_random=True): #analysis_type = missingness or noisiness
    metric_dict = metrics_dict[metric]
    df= pd.DataFrame()
    if analysis_type == 'noisiness':
         df[analysis_type] = [0, 0.2, 0.4, 0.6]
    elif analysis_type == 'missingness':
        df[analysis_type] = [0, 0.1, 0.2, 0.3]
    else:
        print('Unknown analysis type')
        return
    if has_random:
        df['random agent'] = metric_dict['random agent']
    #df['dt agent'] = metric_dict['dt agent']
    df['DQN'] = metric_dict['dqn agent']
    df['RF'] = metric_dict['random forest']
    df['SVM'] = metric_dict['SVM']
    df['XGBoost'] = metric_dict['XGBoost']
    df['DT'] = metric_dict['decision tree']
    #if metric not in ['episode_length', 'episode_reward']:
    #    df['decision tree'] = metric_dict['decision tree']
    
    plt.title(metric)
    plt.ylabel(metric)
    sns.lineplot(x=analysis_type, y='value', hue='variable', 
             data=pd.melt(df, [analysis_type]))

# %%
def pretty_plot_performance(analysis_type, success_dict, filename, has_random=True):
    if analysis_type == 'Noisiness':
        xticks = [0.0, 0.2, 0.4, 0.6]
    else:
        xticks = [0.0, 0.1, 0.2, 0.3]
    df = pd.DataFrame()
    df['DQN'] = success_dict['dqn agent']
    df['RF'] = success_dict['random forest']
    df['SVM'] = success_dict['SVM']
    df['XGBoost'] = success_dict['XGBoost']
    df['DT'] = success_dict['decision tree']
    plt.figure(figsize=(8, 5))
    ax = sns.lineplot(data=df, linewidth=2.5)
    ax.set_xticks(range(len(df))) # <--- set the ticks first
    ax.set_xticklabels(xticks)
    ax.set(xlabel=analysis_type, ylabel='Success Rate', title='Model Performance')
    ax.legend(title='Models', title_fontsize = 13)
    plt.savefig(f'../../final/images/{filename}.png')
    plt.show()

# %% [markdown]
# ### Noisiness

# %%
noisiness_dict = {'decision tree': [99.943, 85.264, 82.900, 79.900], 
                  'dqn agent': [95.000, 96.243, 97.269, 96.621], 
                  'random forest': [99.907, 98.757, 96.736, 94.986], 
                  'SVM':[83.771, 75.207, 73.157, 72.157], 
                  'XGBoost':[99.986, 98.607, 96.728, 95.086]}

# %%
pretty_plot_performance('Noisiness', noisiness_dict, 'plot_noisiness', False)

# %% [markdown]
# ### Missingness

# %%
missingness_dict = {'decision tree': [99.943, 95.386, 93.893, 93.221], 
                    'dqn agent': [95.000, 96.714, 94.150, 94.357], 
                    'random forest': [99.907, 97.186, 93.193, 91.200], 
                    'SVM':[83.771, 63.721, 54.007, 51.314], 
                    'XGBoost':[99.986, 97.829, 93.821, 91.521]}

# %%
pretty_plot_performance('Missingness', missingness_dict, 'plot_missingness', False)

# %% [markdown]
# #### Both noisiness and missingness

# %%
noisiness_missingness_dict = {'decision tree': [99.943, 81.250, 79.129, 77.036], 
                              'dqn agent': [95.000, 94.529, 92.064, 91.000], # This 91 is a placeholder
                              'random forest': [99.907, 95.029, 92.379, 90.736], 
                              'SVM':[83.771, 57.664, 48.671, 46.185], 
                              'XGBoost':[99.986, 95.286, 92.507, 90.679]}

# %%
pretty_plot_performance('Missingness', noisiness_missingness_dict, 'plot_noisiness_missingness', False)

# %% [markdown]
# #### Variable training sizes

# %%
sizes = [1, 0.5, 0.1, 0.05, 0.1]
variable_success_rates_6m = [95.000, 90.942, 93.829, 91.550, 79.350]
variable_df = pd.DataFrame()
#variable_df['training set size'] = sizes
variable_df['Success Rate'] = variable_success_rates_6m

# %%
plt.figure(figsize=(8, 5))
ax = sns.lineplot(data=variable_df, linewidth=2.5)
ax.set_xticks(range(len(variable_df))) # <--- set the ticks first
ax.set_xticklabels(sizes)
ax.set(xlabel='Training Size', ylabel='Success Rate', title='Variable Training Sizes')
#ax.legend(title='Models', title_fontsize = 13)
plt.savefig(f'../../final/images/varied_training_size_6m.png')
plt.show()

# %%
#sizes = [1, 0.5, 0.1, 0.05, 0.01]
sizes = [0.01, 0.05, 0.1, 0.5, 1]
#variable_success_rates_opt = [95.000, 94.900, 96.807, 97.014, 95.029]
variable_success_rates_opt = [95.029, 97.014, 96.807, 94.900, 95.000]
variable_opt_df = pd.DataFrame()
#variable_df['training set size'] = sizes
variable_opt_df['Success Rate'] = variable_success_rates_opt
plt.figure(figsize=(8, 5))
ax = sns.lineplot(data=variable_opt_df, linewidth=2.5)
ax.set_xticks(range(len(variable_df))) # <--- set the ticks first
ax.set_xticklabels(sizes)
ax.set(xlabel='Training Size', ylabel='Success Rate', title='Variable Training Sizes')
#ax.legend(title='Models', title_fontsize = 13)
plt.savefig(f'../../final/images/varied_training_size_opt.png')
plt.show()

# %% [markdown]
# ### To delete

# %% [markdown]
# #### Noisiness

# %%
success_rate = {'decision tree': [99.964, 89.414, 88.200, 86.650], 'dqn agent': [95.250, 96.050, 96.364, 94.379]}
acc = {'decision tree': [0.9996, 0.894, 0.882, 0.867], 'dqn agent': [0.953, 0.961, 0.964, 0.944]}
f1 = {'decision tree': [0.9996, 0.904, 0.892, 0.876], 'dqn agent': [0.948, 0.956, 0.958, 0.937]}
roc_auc = {'decision tree': [0.9998, 0.937, 0.930, 0.922], 'dqn agent': [0.975, 0.979, 0.980, 0.969]}
metrics_dict = {'success_rate':success_rate, 'acc':acc, 'f1':f1, 'roc_auc':roc_auc}

# %%
plot_noisiness_performance('acc', 'noisiness', has_random=False)

# %%
plot_noisiness_performance('f1', 'noisiness', has_random=False)

# %%
plot_noisiness_performance('roc_auc', 'noisiness', has_random=False)

# %% [markdown]
# #### Noisiness without inconclusive diagnosis

# %%
#noisiness_sans_inconc = [0, 2, 4, 6]
success_rate = {'decision tree': [99.977, 89.852, 88.670, 87.022],  'dqn agent': [97.645, 98.259, 99.003, 97.803]}
metrics_dict = {'success_rate':success_rate}

# %%
# #noisiness_sans_inconc = [0, 2, 4, 6]
# success_rate = {'plain_dt': [99.969, 75.893, 71.156, 66.946], 'dt agent': [100, 82.532, 74.411, 67.633], 'dqn agent': [94.965, 78.930, 71.469, 64.123]}
# episode_length = {'dt agent': [3.981, 3.981, 3.985, 3.976], 'dqn agent': [5.191, 4.437, 4.425, 4.140]}
# episode_reward = {'dt agent': [1, 0.651, 0.488, 0.353], 'dqn agent': [0.899, 0.579, 0.429, 0.282]}
# metrics_dict = {'success_rate':success_rate, 'episode_length':episode_length, 'episode_reward':episode_reward}

# %%
plot_noisiness_performance('success_rate', 'noisiness', False)

# %%
plot_noisiness_performance('episode_length', 'noisiness', False)

# %%
plot_noisiness_performance('episode_reward', 'noisiness', False)

# %% [markdown]
# #### Missingness

# %%
#missingness = [0, 1, 2, 3]
success_rate = {'decision tree': [99.964, 96.436, 95.850, 95.057], 'dqn agent': [95.250, 96.436, 95.557, 95.300]}
acc = {'decision tree':[0.9996, 0.964, 0.959, 0.951], 'dqn agent': [0.953, 0.964, 0.956, 0.953]}
f1 = {'decision tree':[0.9996, 0.964, 0.929, 0.913], 'dqn agent': [0.948, 0.964, 0.951, 0.947]}
roc_auc = {'decision tree': [0.9996, 0.981, 0.961, 0.953], 'dqn agent': [0.975, 0.981, 0.975, 0.974]}
metrics_dict = {'success_rate':success_rate, 'acc':acc, 'f1':f1, 'roc_auc':roc_auc}

# %%
# #missingness = [0, 1, 2, 3]
# success_rate = {'random agent': [11.807, 11.807, 11.807, 11.807], 'plain_dt': [99.964, 90.721, 84.114, 77.707], 'dt agent': [100, 86.029, 73.664, 61.971], 'dqn agent': [95.250, 82.014, 69.107, 57.750]}
# episode_length = {'random agent': [1.540, 1.540, 1.540, 1.540], 'dt agent': [4.007, 3.916, 3.832, 3.737], 'dqn agent': [5.260, 3.851, 3.725, 3.982]}
# episode_reward = {'random agent': [-0.771, -0.771, -0.771, -0.771,], 'dt agent': [1, 0.721, 0.473, 0.239], 'dqn agent': [0.765, 0.500, 0.243, 0.015]}
# acc = {'random agent': [0.118, 0.118, 0.118, 0.118], 'plain_dt':[0.9996, 0.907, 0.841, 0.777], 'dt agent': [1, 0.860, 0.737, 0.620], 'dqn agent': [0.953, 0.820, 0.691, 0.578]}
# f1 = {'random agent': [0.118, 0.118, 0.118, 0.118], 'plain_dt':[0.9996, 0.885, 0.812, 0.746], 'dt agent': [1, 0.864, 0.767, 0.669], 'dqn agent': [0.948, 0.831, 0.727, 0.628]}
# roc_auc = {'random agent': [0.498, 0.498, 0.498, 0.498], 'plain_dt': [0.9996, 0.936, 0.894, 0.857], 'dt agent': [1, 0.924, 0.856, 0.793], 'dqn agent': [0.975, 0.902, 0.832, 0.770]}
# metrics_dict = {'success_rate':success_rate, 'plain_dt': [0.9998], 'episode_length':episode_length, 'episode_reward':episode_reward, 'acc':acc, 'f1':f1, 'roc_auc':roc_auc}

# %%
plot_noisiness_performance('success_rate', 'missingness', False)

# %%
# plot_noisiness_performance('episode_length', 'missingness', False)

# %%
# plot_noisiness_performance('episode_reward', 'missingness', False)

# %%
plot_noisiness_performance('acc', 'missingness', False)

# %%
plot_noisiness_performance('f1', 'missingness', False)

# %%
plot_noisiness_performance('roc_auc', 'missingness', False)

# %% [markdown]
# #### Missingness without inconclusive diagnosis

# %%
#missingness_sans_inconc = [0, 1, 2, 3]
success_rate = {'decision tree': [99.977, 99.954, 99.946, 99.823], 'dqn agent': [97.645, 98.645, 97.763, 97.687]}
metrics_dict = {'success_rate':success_rate}

# %%
# #missingness_sans_inconc = [0, 1, 2, 3]
# success_rate = {'plain_dt': [99.969, 93.444, 87.686, 81.460], 'dt agent': [100, 84.965, 71.660, 59.078], 'dqn agent': [94.965, 80.730, 66.887, 54.619]}
# episode_length = {'dt agent': [3.981, 3.893, 3.811, 3.719], 'dqn agent': [5.191, 3.835, 3.709, 3.969]}
# episode_reward = {'dt agent': [1, 0.699, 0.433, 0.182], 'dqn agent': [0.899, 0.615, 0.338, 0.092]}
# metrics_dict = {'success_rate':success_rate, 'episode_length':episode_length, 'episode_reward':episode_reward}

# %%
plot_noisiness_performance('success_rate', 'missingness', False)

# %%
# plot_noisiness_performance('episode_length', 'missingness', False)

# %%
# plot_noisiness_performance('episode_reward', 'missingness', False)

# %% [markdown]
# #### Missingness and noisiness

# %%
#performance is in order [acc, f1, roc_auc]
dt_perf = [0.858, 0.858, 0.911]
dqn_perf = [0.962, 0.957, 0.979]

#performance is in order [with_inconc, without_inconc]
dt_success = [85.814, 87.655]
dqn_success = [96.200, 98.416]

# %%
barWidth = 0.25
fig = plt.subplots(figsize =(8, 6))
br1 = np.arange(len(dt_perf))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

plt.bar(br1, dt_perf, width = barWidth, label ='decision tree')
plt.bar(br2, dqn_perf, width = barWidth, label ='dqn agent')

plt.xlabel('Metric', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(dt_perf))], ['accuracy', 'f1', 'roc_auc'])
plt.legend()
plt.show()

# %%
barWidth = 0.25
fig = plt.subplots(figsize =(8, 6))
br1 = np.arange(len(dt_success))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

plt.bar(br1, dt_success, width = barWidth, label ='decision tree')
plt.bar(br2, dqn_success, width = barWidth, label ='dqn agent')

plt.title('Success rate')
plt.xlabel('Metric', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(dt_success))], ['with inconclusive diagnosis', 'without inconclusive diagnosis'])
plt.legend()
plt.show()

# %% [markdown]
# #### Missingness and noisiness without inconcluisve diagnosis

# %%
#missingness_sans_inconc = [0, 1, 2, 3]
success_rate = {'decision tree': [99.977, 99.954, 99.946, 99.823], 'dqn agent': [97.645, 98.645, 97.763, 97.687]}
metrics_dict = {'success_rate':success_rate}

# %% [markdown]
# #### Plotting success rate

# %%
# metric ='success_rate'
# df = pd.DataFrame()
# df['missingness'] = [0, 1, 2, 3]
# df['random agent'] = success_rate['random agent']
# df['dt agent'] = success_rate['dt agent']
# df['dqn agent'] = success_rate['dqn agent']
# df.head()

# %% [markdown]
# #### Success Rate

# %%
plot_noisiness_performance('success_rate')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6a8791d784c6> in <module>
# ----> 1 plot_noisiness_performance('success_rate')
#
# TypeError: plot_noisiness_performance() missing 1 required positional argument: 'analysis_type'

# %% [markdown]
# #### Episode length

# %%
plot_noisiness_performance('episode_length')

# %% [markdown]
# #### Episode reward

# %%
plot_noisiness_performance('episode_reward')

# %% [markdown]
# #### Accuracy

# %%
plot_noisiness_performance('acc')

# %% [markdown]
# #### F1

# %%
plot_noisiness_performance('f1')

# %% [markdown]
# #### ROC-AUC

# %%
plot_noisiness_performance('roc_auc')
