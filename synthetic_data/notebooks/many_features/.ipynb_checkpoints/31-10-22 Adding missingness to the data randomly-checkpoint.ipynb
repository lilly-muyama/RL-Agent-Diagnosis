# %%
import pandas as pd
import numpy as np
import random
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:284: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:862: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1101: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1127: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1362: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1602: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1738: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:29: DeprecationWarning:
#
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
all_df= pd.read_csv('../../final/data/dataset_with_inconclusive.csv')
#df = df.fillna(-1)
all_df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0   11.875670  161.104070   3.981397                    NaN  358.191297
# 1    9.296779  457.149834   1.874231               5.544915         NaN
# 2    9.780377  483.216550   4.041312               5.515052  304.155693
# 3    9.131688   57.578776   5.778568               1.976049  207.684776
# 4   11.395680         NaN        NaN               1.320481  318.250045
#
#           mcv  serum_iron       rbc        age  gender  indirect_bilirubin  \
# 0   77.370085         NaN  6.918734  74.271409       0                 NaN
# 1   78.717345         NaN  3.999210  70.112738       0                 NaN
# 2  100.750651  118.428782  6.273777  87.682835       1            2.705387
# 3   96.855220         NaN  3.773108  39.425050       0                 NaN
# 4  102.206351         NaN       NaN        NaN       0                 NaN
#
#    transferrin  creatinine  cholestrol     copper    ethanol     folate  \
# 0   441.651953    0.508604   86.888802        NaN        NaN        NaN
# 1   414.333999    0.784442   37.659905        NaN        NaN        NaN
# 2   350.319553    1.129411  140.917968  47.714319  62.722981  20.039071
# 3   353.517996    1.569724   26.393979        NaN        NaN        NaN
# 4          NaN         NaN         NaN        NaN        NaN        NaN
#
#      glucose                                 label
# 0        NaN             Anemia of chronic disease
# 1        NaN             Anemia of chronic disease
# 2  46.973234  Vitamin B12/Folate deficiency anemia
# 3        NaN                      Hemolytic anemia
# 4        NaN  Vitamin B12/Folate deficiency anemia

# %%
len(all_df)
# Out:
# 70000

# %%
class_dict = constants.CLASS_DICT
all_df['label'] = all_df['label'].replace(class_dict)
X = all_df.iloc[:, 0:-1]
y = all_df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train_df = pd.concat([X_train, y_train], axis=1)
X_test_df = pd.concat([X_test, y_test], axis=1)
X_test_df = X_test_df.reset_index(drop=True)
X_test_df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0   11.783006  112.011007        NaN               3.308648  348.014906
# 1   12.609666  104.475099   5.445972                    NaN         NaN
# 2    7.940172    4.925400   3.255130               5.766738  209.031102
# 3    7.785840  103.757096   2.874384               3.839597         NaN
# 4   12.359715   51.274141   0.178269               1.233844  474.589534
#
#          mcv  serum_iron       rbc        age  gender  indirect_bilirubin  \
# 0  86.577465         NaN  6.372841  40.066492       0                 NaN
# 1  75.082198         NaN  6.124198  80.235998       1            0.584755
# 2  75.254082         NaN       NaN  31.093070       1                 NaN
# 3  81.873581   39.638010  3.443422  72.829677       1                 NaN
# 4  76.469181   49.839768  2.956350  29.240909       1                 NaN
#
#    transferrin  creatinine  cholestrol     copper    ethanol     folate  \
# 0   433.374720    1.617594  131.868365        NaN        NaN        NaN
# 1   415.497280    0.334722   97.568987  83.161880        NaN   7.147270
# 2          NaN    1.649478    2.082970        NaN        NaN        NaN
# 3   268.338920    0.637843  127.412065  38.534760  51.437387  28.150784
# 4   319.299656    0.621034  137.433107  55.314614  47.302738   3.808612
#
#      glucose  label
# 0        NaN      7
# 1        NaN      3
# 2        NaN      4
# 3  73.296289      5
# 4  60.076211      4

# %%
def insert_nans(df, col, frac):
    non_null_indices = df[df[col].notna()].index.tolist() #getting not null indices
    to_change_indices = random.sample(non_null_indices, int(frac*len(non_null_indices)))
    df.loc[to_change_indices, col] = np.nan
    return df

# %%
frac = 0.5

# %%
for column in X_train_df.columns:
    if column not in ['hemoglobin', 'gender', 'label']:
        X_train_df = insert_nans(X_train_df, column, frac)
X_train_df.isna().sum()
# Out:
# hemoglobin                   0
# ferritin                 39442
# ret_count                35815
# segmented_neutrophils    35125
# tibc                     39011
# mcv                      30011
# serum_iron               43381
# rbc                      38289
# age                      33523
# gender                       0
# indirect_bilirubin       48404
# transferrin              38289
# creatinine               35773
# cholestrol               35773
# copper                   45874
# ethanol                  43381
# folate                   45874
# glucose                  43381
# label                        0
# dtype: int64

# %%
X_train_df.shape
# Out:
# (56000, 19)

# %%
utils.get_dt_performance(X_train_df, 'numeric')
# Out:
# (0.5758035714285714,
#  0.5510117475841989,
#  0.7449751027739672,
#  datetime.timedelta(microseconds=1001))

# %%
X_train_df.to_csv('../../final/data/train_set_missing_5.csv', index=False)
