# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random
import os
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %% [markdown]
# #### The Data

# %%
#df = pd.read_csv('../../data/anemia_synth_dataset_some_nans_unspecified_more_feats.csv')
#df = pd.read_csv('../../data/more_feats_0.2.csv')
#df= pd.read_csv('../../data/more_features/more_feats_new_labels_0.1.csv')
df =pd.read_csv('../../data/more_features/more_feats_new_labels_0.1_noisy_0.2.csv')
#df = pd.read_csv('../../data/more_features/more_feats_0.3.csv')
#df = utils.balance_dataset(df, 8000)
#df = df.fillna(-1)
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0   12.190830  163.097819   3.084127               5.923027  232.339305
# 1    9.944819  187.086684   5.096256              -1.000000   -1.000000
# 2   13.703345   -1.000000  -1.000000              -1.000000   -1.000000
# 3    7.346123   87.205849  -1.000000              -1.000000  428.089083
# 4   12.295548  225.097199   3.827717               0.000000   -1.000000
#
#           mcv  serum_iron       rbc        age  gender  indirect_bilirubin  \
# 0   79.550470   -1.000000  3.748689  -1.000000       1           -1.000000
# 1  100.121185   -1.000000  5.857746  72.837294       0            1.146823
# 2   -1.000000   80.372015  5.684361  45.702318       0            1.789854
# 3   77.375356   95.912445  6.469686  52.594562       0            0.222080
# 4  102.137453   -1.000000 -1.000000  -1.000000       1           -1.000000
#
#    transferrin  creatinine  cholestrol     copper    ethanol     folate  \
# 0    -1.000000   -1.000000   -1.000000  -1.000000  -1.000000  -1.000000
# 1    -1.000000   -1.000000   -1.000000  -1.000000  20.943783  -1.000000
# 2   206.817706    1.551467   90.217875  76.009442  22.651663  12.551513
# 3   297.319109    1.265341  126.999491  46.998397  77.183582   8.518821
# 4    -1.000000   -1.000000   -1.000000  -1.000000  -1.000000  -1.000000
#
#       glucose                      label
# 0   -1.000000  Anemia of chronic disease
# 1   -1.000000         Unspecified anemia
# 2   -1.000000                  No anemia
# 3  119.113878  Anemia of chronic disease
# 4   -1.000000         Unspecified anemia

# %%
df.isna().sum()
# Out:
# hemoglobin               0
# ferritin                 0
# ret_count                0
# segmented_neutrophils    0
# tibc                     0
# mcv                      0
# serum_iron               0
# rbc                      0
# age                      0
# gender                   0
# indirect_bilirubin       0
# transferrin              0
# creatinine               0
# cholestrol               0
# copper                   0
# ethanol                  0
# folate                   0
# glucose                  0
# label                    0
# dtype: int64

# %%
utils.get_dt_performance(df)
# Out:
# (0.9753571428571428,
#  0.9690191313104524,
#  0.9827599860420327,
#  datetime.timedelta(microseconds=7538))

# %%
df.label.value_counts()
# Out:
# No anemia                               10000
# Anemia of chronic disease                9756
# Iron deficiency anemia                   9267
# Unspecified anemia                       9033
# Aplastic anemia                          9020
# Vitamin B12/Folate deficiency anemia     9000
# Hemolytic anemia                         8976
# Inconclusive diagnosis                   4948
# Name: label, dtype: int64

# %%
class_dict = constants.CLASS_DICT
df['label'] = df['label'].replace(class_dict)
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((56000, 18), (14000, 18), (56000,), (14000,))

# %%
X_test[0]
# Out:
# array([ 10.34995981,  -1.        ,   0.99855381,  -1.        ,
#         -1.        ,  86.411147  , 111.70748795,   4.94433984,
#         27.50298959,   0.        ,   0.27929003, 157.7912435 ,
#          0.72896824,  19.37271239,  51.43928931,  43.59894376,
#          7.55852452,  64.72339742])

# %%
action_list = list(class_dict.keys()) + [col  for col in df.columns if col!='label']
action_list
# Out:
# ['No anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Unspecified anemia',
#  'Anemia of chronic disease',
#  'Iron deficiency anemia',
#  'Hemolytic anemia',
#  'Aplastic anemia',
#  'Inconclusive diagnosis',
#  'hemoglobin',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'tibc',
#  'mcv',
#  'serum_iron',
#  'rbc',
#  'age',
#  'gender',
#  'indirect_bilirubin',
#  'transferrin',
#  'creatinine',
#  'cholestrol',
#  'copper',
#  'ethanol',
#  'folate',
#  'glucose']

# %%
len(action_list)
# Out:
# 26

# %%
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0   12.190830  163.097819   3.084127               5.923027  232.339305
# 1    9.944819  187.086684   5.096256              -1.000000   -1.000000
# 2   13.703345   -1.000000  -1.000000              -1.000000   -1.000000
# 3    7.346123   87.205849  -1.000000              -1.000000  428.089083
# 4   12.295548  225.097199   3.827717               0.000000   -1.000000
#
#           mcv  serum_iron       rbc        age  gender  indirect_bilirubin  \
# 0   79.550470   -1.000000  3.748689  -1.000000       1           -1.000000
# 1  100.121185   -1.000000  5.857746  72.837294       0            1.146823
# 2   -1.000000   80.372015  5.684361  45.702318       0            1.789854
# 3   77.375356   95.912445  6.469686  52.594562       0            0.222080
# 4  102.137453   -1.000000 -1.000000  -1.000000       1           -1.000000
#
#    transferrin  creatinine  cholestrol     copper    ethanol     folate  \
# 0    -1.000000   -1.000000   -1.000000  -1.000000  -1.000000  -1.000000
# 1    -1.000000   -1.000000   -1.000000  -1.000000  20.943783  -1.000000
# 2   206.817706    1.551467   90.217875  76.009442  22.651663  12.551513
# 3   297.319109    1.265341  126.999491  46.998397  77.183582   8.518821
# 4    -1.000000   -1.000000   -1.000000  -1.000000  -1.000000  -1.000000
#
#       glucose  label
# 0   -1.000000      3
# 1   -1.000000      2
# 2   -1.000000      0
# 3  119.113878      3
# 4   -1.000000      2

# %% [markdown]
# #### Training

# %%
# %%time
# timesteps = int(2e6)
# dqn_model = utils.stable_dqn3(X_train, y_train, timesteps, True, f'../../models/many_features/stable_dqn3_{timesteps}')
# test_df = utils.evaluate_dqn(dqn_model, X_test, y_test)
# test_df.head()

# %%
for steps in [int(7.3e6), int(7.8e6), int(9e6)]:
#for steps in [int(2e3)]:
    #start_time = datetime.now()
    dqn_model = utils.stable_dqn3(X_train, y_train, steps, True, 
                                  f'../../models/many_features/0.1/dqn3_by_type_new_labels_noisy_2_{steps}')
    #end_time = datetime.now()
    #print(f'The duration for {steps} steps is {end_time-start_time}')
# Out:
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.589    |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1714     |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 315966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.68     |
# |    n_updates        | 66491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.0958   |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1461     |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 694828   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.85     |
# |    n_updates        | 161206   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.55     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.04     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1353     |
# |    time_elapsed     | 787      |
# |    total_timesteps  | 1065900  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.63     |
# |    n_updates        | 253974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1297     |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 1507309  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 364327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23     |
# |    ep_rew_mean      | -0.36    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1211     |
# |    time_elapsed     | 1514     |
# |    total_timesteps  | 1833636  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0584   |
# |    n_updates        | 445908   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49     |
# |    ep_rew_mean      | -0.22    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.46     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 856      |
# |    time_elapsed     | 2563     |
# |    total_timesteps  | 2195151  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0592   |
# |    n_updates        | 536287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.52     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 701      |
# |    time_elapsed     | 3652     |
# |    total_timesteps  | 2563516  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0872   |
# |    n_updates        | 628378   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.5      |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 615      |
# |    time_elapsed     | 4775     |
# |    total_timesteps  | 2941245  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.097    |
# |    n_updates        | 722811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45     |
# |    ep_rew_mean      | -0.12    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 580      |
# |    time_elapsed     | 5712     |
# |    total_timesteps  | 3315575  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 816393   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.58     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 610      |
# |    time_elapsed     | 6020     |
# |    total_timesteps  | 3677163  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.126    |
# |    n_updates        | 906790   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.52     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 638      |
# |    time_elapsed     | 6333     |
# |    total_timesteps  | 4041200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.166    |
# |    n_updates        | 997799   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 662      |
# |    time_elapsed     | 6648     |
# |    total_timesteps  | 4405901  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0474   |
# |    n_updates        | 1088975  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5      |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.55     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 684      |
# |    time_elapsed     | 6967     |
# |    total_timesteps  | 4771359  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 1180339  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.61     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 705      |
# |    time_elapsed     | 7284     |
# |    total_timesteps  | 5136783  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 1271695  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 723      |
# |    time_elapsed     | 7613     |
# |    total_timesteps  | 5512350  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.16     |
# |    n_updates        | 1365587  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.7      |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 742      |
# |    time_elapsed     | 7950     |
# |    total_timesteps  | 5900244  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0739   |
# |    n_updates        | 1462560  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.68     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 758      |
# |    time_elapsed     | 8289     |
# |    total_timesteps  | 6289896  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0982   |
# |    n_updates        | 1559973  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.71     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 771      |
# |    time_elapsed     | 8660     |
# |    total_timesteps  | 6679640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 1657409  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 753      |
# |    time_elapsed     | 9390     |
# |    total_timesteps  | 7079025  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 1757256  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.622    |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1656     |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 310616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.02     |
# |    n_updates        | 65153    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.156    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1444     |
# |    time_elapsed     | 479      |
# |    total_timesteps  | 692949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.95     |
# |    n_updates        | 160737   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1337     |
# |    time_elapsed     | 788      |
# |    total_timesteps  | 1054330  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01     |
# |    n_updates        | 251082   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1295     |
# |    time_elapsed     | 1144     |
# |    total_timesteps  | 1482491  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 358122   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6      |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1267     |
# |    time_elapsed     | 1415     |
# |    total_timesteps  | 1794995  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0387   |
# |    n_updates        | 436248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91     |
# |    ep_rew_mean      | -0.34    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.42     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1249     |
# |    time_elapsed     | 1677     |
# |    total_timesteps  | 2096302  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0856   |
# |    n_updates        | 511575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52     |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.46     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1221     |
# |    time_elapsed     | 1949     |
# |    total_timesteps  | 2380575  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0671   |
# |    n_updates        | 582643   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.63     |
# |    ep_rew_mean      | -0.14    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1193     |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 2652286  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 650571   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.69     |
# |    ep_rew_mean      | -0.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1185     |
# |    time_elapsed     | 2469     |
# |    total_timesteps  | 2926896  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 719223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.57     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1176     |
# |    time_elapsed     | 2724     |
# |    total_timesteps  | 3206965  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.217    |
# |    n_updates        | 789241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.81     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1160     |
# |    time_elapsed     | 3008     |
# |    total_timesteps  | 3491156  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.166    |
# |    n_updates        | 860288   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.63     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1149     |
# |    time_elapsed     | 3291     |
# |    total_timesteps  | 3784972  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.196    |
# |    n_updates        | 933742   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1144     |
# |    time_elapsed     | 3570     |
# |    total_timesteps  | 4086116  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.155    |
# |    n_updates        | 1009028  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.95     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.68     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1139     |
# |    time_elapsed     | 3850     |
# |    total_timesteps  | 4387944  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.207    |
# |    n_updates        | 1084485  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 1132     |
# |    time_elapsed     | 4143     |
# |    total_timesteps  | 4690664  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 1160165  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.72     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 1114     |
# |    time_elapsed     | 4479     |
# |    total_timesteps  | 4993951  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.174    |
# |    n_updates        | 1235987  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.96     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.72     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 1099     |
# |    time_elapsed     | 4818     |
# |    total_timesteps  | 5296941  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.06     |
# |    n_updates        | 1311735  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 1090     |
# |    time_elapsed     | 5138     |
# |    total_timesteps  | 5600751  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0921   |
# |    n_updates        | 1387687  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 1081     |
# |    time_elapsed     | 5457     |
# |    total_timesteps  | 5903957  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0877   |
# |    n_updates        | 1463489  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 1071     |
# |    time_elapsed     | 5796     |
# |    total_timesteps  | 6209844  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 1539960  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 1065     |
# |    time_elapsed     | 6117     |
# |    total_timesteps  | 6516942  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.154    |
# |    n_updates        | 1616735  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 1060     |
# |    time_elapsed     | 6436     |
# |    total_timesteps  | 6825943  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0991   |
# |    n_updates        | 1693985  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.66     |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 1054     |
# |    time_elapsed     | 6766     |
# |    total_timesteps  | 7137598  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 1771899  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 2400000  |
# |    fps              | 1053     |
# |    time_elapsed     | 7071     |
# |    total_timesteps  | 7450451  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0924   |
# |    n_updates        | 1850112  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 992      |
# |    time_elapsed     | 7823     |
# |    total_timesteps  | 7762771  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 1928192  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.679    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 586      |
# |    time_elapsed     | 518      |
# |    total_timesteps  | 304025   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.71     |
# |    n_updates        | 63506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8      |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.289    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 515      |
# |    time_elapsed     | 1306     |
# |    total_timesteps  | 673985   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.11     |
# |    n_updates        | 155996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 486      |
# |    time_elapsed     | 2118     |
# |    total_timesteps  | 1029968  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.6      |
# |    n_updates        | 244991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 464      |
# |    time_elapsed     | 3159     |
# |    total_timesteps  | 1467358  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 354339   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 441      |
# |    time_elapsed     | 4149     |
# |    total_timesteps  | 1830809  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 445202   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 425      |
# |    time_elapsed     | 5035     |
# |    total_timesteps  | 2141118  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0464   |
# |    n_updates        | 522779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | -0.22    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.46     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 432      |
# |    time_elapsed     | 5759     |
# |    total_timesteps  | 2490241  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.18     |
# |    n_updates        | 610060   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.49     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 470      |
# |    time_elapsed     | 6102     |
# |    total_timesteps  | 2873634  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0794   |
# |    n_updates        | 705908   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.51     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 504      |
# |    time_elapsed     | 6448     |
# |    total_timesteps  | 3255224  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.181    |
# |    n_updates        | 801305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.58     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 534      |
# |    time_elapsed     | 6794     |
# |    total_timesteps  | 3630683  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.154    |
# |    n_updates        | 895170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 560      |
# |    time_elapsed     | 7151     |
# |    total_timesteps  | 4011776  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 990443   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5      |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.57     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 584      |
# |    time_elapsed     | 7502     |
# |    total_timesteps  | 4386784  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.15     |
# |    n_updates        | 1084195  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.55     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 605      |
# |    time_elapsed     | 7853     |
# |    total_timesteps  | 4759454  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.084    |
# |    n_updates        | 1177363  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 624      |
# |    time_elapsed     | 8218     |
# |    total_timesteps  | 5135881  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0657   |
# |    n_updates        | 1271470  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 642      |
# |    time_elapsed     | 8597     |
# |    total_timesteps  | 5524289  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.169    |
# |    n_updates        | 1368572  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4        |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 657      |
# |    time_elapsed     | 9017     |
# |    total_timesteps  | 5932764  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 1470690  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 669      |
# |    time_elapsed     | 9479     |
# |    total_timesteps  | 6342469  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0888   |
# |    n_updates        | 1573117  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 679      |
# |    time_elapsed     | 9934     |
# |    total_timesteps  | 6748350  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0693   |
# |    n_updates        | 1674587  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 691      |
# |    time_elapsed     | 10342    |
# |    total_timesteps  | 7155886  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 1776471  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 703      |
# |    time_elapsed     | 10758    |
# |    total_timesteps  | 7564334  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0929   |
# |    n_updates        | 1878583  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9      |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 713      |
# |    time_elapsed     | 11175    |
# |    total_timesteps  | 7972481  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0462   |
# |    n_updates        | 1980620  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 723      |
# |    time_elapsed     | 11584    |
# |    total_timesteps  | 8381520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0833   |
# |    n_updates        | 2082879  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 733      |
# |    time_elapsed     | 11980    |
# |    total_timesteps  | 8787212  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0488   |
# |    n_updates        | 2184302  |
# ----------------------------------

# %% [markdown]
# #### Testing

# %%
# training_env = utils.create_env(X_train, y_train)
# dqn_model = utils.load_dqn3('../../models/many_features/0.1/dqn3_by_type_new_labels_noisy_2_9000000', training_env)
# test_df = utils.evaluate_dqn(dqn_model, X_test, y_test)
# test_df.head()
# Out:
# Using stable baselines 3
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Count: 2800
# Count: 5600
# Count: 8400
# Count: 11200
# Count: 14000
# Testing done.....
#    episode_length  index  is_success  reward  terminated  \
# 0             4.0    0.0         1.0     1.0         0.0
# 1             5.0    1.0         1.0     1.0         0.0
# 2             5.0    2.0         1.0     1.0         0.0
# 3             4.0    3.0         1.0     1.0         0.0
# 4             4.0    4.0         1.0     1.0         0.0
#
#                                           trajectory  y_actual  y_pred
# 0      [hemoglobin, mcv, ret_count, Aplastic anemia]       6.0     6.0
# 1  [hemoglobin, gender, mcv, segmented_neutrophil...       2.0     2.0
# 2  [hemoglobin, mcv, segmented_neutrophils, gende...       2.0     2.0
# 3     [hemoglobin, mcv, ret_count, Hemolytic anemia]       5.0     5.0
# 4     [hemoglobin, mcv, ret_count, Hemolytic anemia]       5.0     5.0

# %%
test_df.y_pred.value_counts()
# Out:
# 7.0    2283
# 0.0    2035
# 6.0    1777
# 5.0    1725
# 3.0    1594
# 1.0    1557
# 2.0    1530
# 4.0    1499
# Name: y_pred, dtype: int64

# %%
success_rate, success_df = utils.success_rate(test_df)
success_rate
# Out:
# 84.75714285714285

# %%
avg_length, avg_return = utils.get_avg_length_reward(test_df)
avg_length, avg_return
# Out:
# (4.367142857142857, 0.5565714285714286)

# %%
acc, f1, roc_auc = utils.test(test_df['y_actual'], test_df['y_pred'])
acc, f1, roc_auc
# Out:
# (0.8475714285714285, 0.8433911467107766, 0.9167035050409944)

# %%
test_df.y_pred.unique()
# Out:
# array([6., 2., 5., 0., 3., 7., 4., 1.])

# %%
test_df[test_df.y_pred==4]
# Out:
#        episode_length    index  is_success  reward  terminated  \
# 23                5.0     23.0         1.0     1.0         0.0
# 31                5.0     31.0         1.0     1.0         0.0
# 41                5.0     41.0         1.0     1.0         0.0
# 44                5.0     44.0         1.0     1.0         0.0
# 45                5.0     45.0         1.0     1.0         0.0
# ...               ...      ...         ...     ...         ...
# 13965             5.0  13965.0         1.0     1.0         0.0
# 13968             5.0  13968.0         1.0     1.0         0.0
# 13989             5.0  13989.0         1.0     1.0         0.0
# 13996             5.0  13996.0         1.0     1.0         0.0
# 13999             4.0  13999.0         1.0     1.0         0.0
#
#                                               trajectory  y_actual  y_pred
# 23     [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 31     [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 41     [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 44     [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 45     [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# ...                                                  ...       ...     ...
# 13965  [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 13968  [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 13989  [hemoglobin, gender, mcv, tibc, Iron deficienc...       4.0     4.0
# 13996  [hemoglobin, mcv, tibc, gender, Iron deficienc...       4.0     4.0
# 13999    [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
#
# [1499 rows x 8 columns]

# %% [markdown]
# #### Saving files

# %%
# test_df.to_csv(f'../../test_dfs/many_features/0.1/test_df3_6500000.csv', index=False)
# success_df.to_csv(f'../../test_dfs/many_features/0.1/success_df3_6500000.csv', index=False)

# %% [markdown]
# #### Confusion matrix and classification report

# %%
test_df = pd.read_csv('../../test_dfs/many_features/0.1/test_df3_6500000.csv')
test_df.head()
# Out:
#    episode_length  index  is_success  reward  terminated  \
# 0             4.0    0.0         1.0     1.0         0.0
# 1             4.0    1.0         1.0     1.0         0.0
# 2             4.0    2.0         1.0     1.0         0.0
# 3             4.0    3.0         0.0    -1.0         1.0
# 4             4.0    4.0         1.0     1.0         0.0
#
#                                           trajectory  y_actual  y_pred
# 0  ['hemoglobin', 'mcv', 'ret_count', 'Aplastic a...       6.0     6.0
# 1  ['hemoglobin', 'mcv', 'segmented_neutrophils',...       2.0     2.0
# 2  ['hemoglobin', 'mcv', 'segmented_neutrophils',...       2.0     2.0
# 3  ['hemoglobin', 'mcv', 'segmented_neutrophils',...       5.0     7.0
# 4  ['hemoglobin', 'mcv', 'ret_count', 'Hemolytic ...       5.0     5.0

# %%
utils.plot_classification_report(test_df['y_actual'], test_df['y_pred'])

# %%
# def plot_confusion_matrix(y_actual, y_pred, save=False, filename=False):
#     from sklearn.metrics import confusion_matrix
#     cm = confusion_matrix(y_actual, y_pred)
#     cm_df = pd.DataFrame(cm, index = [0, 1, 2, 3, 4, 5, 6], columns = [0, 1, 2, 3, 4, 5, 6], dtype='object')
#     #cm_df = pd.DataFrame(cm, index = constants.CLASS_DICT.keys(), columns = constants.CLASS_DICT.keys())
#     plt.figure(figsize=(8, 6))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Anemia')
#     plt.xlabel('Predicted Anemia')
#     plt.tight_layout()
#     if save:
#         plt.savefig(filename)
#     plt.show()
#     plt.close()

# %%
utils.plot_confusion_matrix(test_df['y_actual'], test_df['y_pred'])
