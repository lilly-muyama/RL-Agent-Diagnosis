# %%
import pandas as pd
import numpy as np
import random
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('../../final/data/train_set_noisy_4.csv')
#df = df.fillna(-1)
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    7.832577  101.919361   3.266163               1.641831  374.916122
# 1   12.434184  314.985398   4.482646               0.000000  391.147780
# 2    6.514719   -1.000000  -1.000000               2.563764   -1.000000
# 3    8.622178  371.236814   3.591647               0.000000  286.629761
# 4   10.725831   14.337773   0.885657               6.654129  471.314535
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0   78.914426   50.159839  2.977622       1    1.905091   84.109029
# 1  103.843580   -1.000000  3.592187       1   -1.000000   -1.000000
# 2  100.710038   -1.000000  1.940636       0   -1.000000   -1.000000
# 3  101.981112   -1.000000  2.536405       1   -1.000000   -1.000000
# 4   77.347657   -1.000000  4.160112       1    0.472443  100.730591
#
#       copper   ethanol    folate     glucose  hematocrit      tsat  label
# 0  70.053478  2.469513  2.258603  111.412414   23.497731  13.37895    3.0
# 1  -1.000000 -1.000000 -1.000000   -1.000000   37.302552  -1.00000    2.0
# 2  -1.000000 -1.000000 -1.000000   -1.000000   19.544156  -1.00000    1.0
# 3  -1.000000 -1.000000 -1.000000   -1.000000   25.866535  -1.00000    2.0
# 4  -1.000000 -1.000000 -1.000000   -1.000000   32.177494  -1.00000    4.0

# %%
df.isna().sum()
# Out:
# hemoglobin               0
# ferritin                 0
# ret_count                0
# segmented_neutrophils    0
# tibc                     0
# mcv                      0
# serum_iron               0
# rbc                      0
# gender                   0
# creatinine               0
# cholestrol               0
# copper                   0
# ethanol                  0
# folate                   0
# glucose                  0
# hematocrit               0
# tsat                     0
# label                    0
# dtype: int64

# %%
df = df.replace(-1, np.nan)
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0    7.832577  101.919361   3.266163               1.641831  374.916122
# 1   12.434184  314.985398   4.482646               0.000000  391.147780
# 2    6.514719         NaN        NaN               2.563764         NaN
# 3    8.622178  371.236814   3.591647               0.000000  286.629761
# 4   10.725831   14.337773   0.885657               6.654129  471.314535
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0   78.914426   50.159839  2.977622       1    1.905091   84.109029
# 1  103.843580         NaN  3.592187       1         NaN         NaN
# 2  100.710038         NaN  1.940636       0         NaN         NaN
# 3  101.981112         NaN  2.536405       1         NaN         NaN
# 4   77.347657         NaN  4.160112       1    0.472443  100.730591
#
#       copper   ethanol    folate     glucose  hematocrit      tsat  label
# 0  70.053478  2.469513  2.258603  111.412414   23.497731  13.37895    3.0
# 1        NaN       NaN       NaN         NaN   37.302552       NaN    2.0
# 2        NaN       NaN       NaN         NaN   19.544156       NaN    1.0
# 3        NaN       NaN       NaN         NaN   25.866535       NaN    2.0
# 4        NaN       NaN       NaN         NaN   32.177494       NaN    4.0

# %%
df.isna().sum()
# Out:
# hemoglobin                   0
# ferritin                 22748
# ret_count                15631
# segmented_neutrophils    17126
# tibc                     21410
# mcv                       4023
# serum_iron               30763
# rbc                       4023
# gender                       0
# creatinine               15546
# cholestrol               15546
# copper                   35749
# ethanol                  30763
# folate                   35749
# glucose                  30763
# hematocrit                   0
# tsat                     40450
# label                        0
# dtype: int64

# %%
def insert_nans(df, col, frac):
    non_null_indices = df[df[col].notna()].index.tolist() #getting not null indices
    to_change_indices = random.sample(non_null_indices, int(frac*len(non_null_indices)))
    df.loc[to_change_indices, col] = np.nan
    return df

# %%
frac = 0.5

# %%
for column in df.columns:
    if column not in ['hemoglobin', 'gender', 'label']:
        df = insert_nans(df, column, frac)
df.head()
# Out:
#    hemoglobin   ferritin  ret_count  segmented_neutrophils  tibc         mcv  \
# 0    7.832577        NaN   3.266163               1.641831   NaN         NaN
# 1   12.434184        NaN   4.482646                    NaN   NaN  103.843580
# 2    6.514719        NaN        NaN               2.563764   NaN         NaN
# 3    8.622178        NaN        NaN               0.000000   NaN  101.981112
# 4   10.725831  14.337773   0.885657               6.654129   NaN   77.347657
#
#    serum_iron  rbc  gender  creatinine  cholestrol     copper  ethanol  \
# 0         NaN  NaN       1         NaN   84.109029  70.053478      NaN
# 1         NaN  NaN       1         NaN         NaN        NaN      NaN
# 2         NaN  NaN       0         NaN         NaN        NaN      NaN
# 3         NaN  NaN       1         NaN         NaN        NaN      NaN
# 4         NaN  NaN       1    0.472443         NaN        NaN      NaN
#
#      folate  glucose  hematocrit  tsat  label
# 0  2.258603      NaN   23.497731   NaN    3.0
# 1       NaN      NaN         NaN   NaN    2.0
# 2       NaN      NaN   19.544156   NaN    1.0
# 3       NaN      NaN   25.866535   NaN    2.0
# 4       NaN      NaN         NaN   NaN    4.0

# %%
df.isna().sum()
# Out:
# hemoglobin                   0
# ferritin                 39374
# ret_count                35815
# segmented_neutrophils    36563
# tibc                     38705
# mcv                      30011
# serum_iron               43381
# rbc                      30011
# gender                       0
# creatinine               35773
# cholestrol               35773
# copper                   45874
# ethanol                  43381
# folate                   45874
# glucose                  43381
# hematocrit               28000
# tsat                     48225
# label                        0
# dtype: int64

# %%
utils.get_dt_performance(df, '')
# Out:
# (0.455,
#  0.4152224277856217,
#  0.6680614676407928,
#  datetime.timedelta(microseconds=4004))

# %%
df.to_csv('../../final/data/train_set_noisy_4_missing_5.csv', index=False)
