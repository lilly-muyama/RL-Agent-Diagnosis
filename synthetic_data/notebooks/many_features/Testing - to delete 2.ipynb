# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random
import os
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %% [markdown]
# #### The Data

# %%
#df = pd.read_csv('../../data/anemia_synth_dataset_some_nans_unspecified_more_feats.csv')
#df = pd.read_csv('../../data/more_feats_0.2.csv')
#df= pd.read_csv('../../data/more_features/more_feats_new_labels_0.1.csv')
#df =pd.read_csv('../../data/more_features/more_feats_new_labels_0.1_noisy_0.6.csv')
df = pd.read_csv('../../data/more_features/more_feats_correlated_0.1.csv')
#df = utils.balance_dataset(df, 8000)
df = df.fillna(-1)
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0   11.183192  187.573466   4.951674               1.661383  316.593436
# 1   14.387445   -1.000000  -1.000000              -1.000000   -1.000000
# 2   12.749357    5.012158   3.502800               6.179371  498.418768
# 3   11.508870  197.180945   1.200125               0.000000  457.033309
# 4    9.456656  427.952052  -1.000000               0.660252   -1.000000
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0   95.006424  181.242992  3.531295       1   -1.000000   28.040619
# 1   -1.000000  125.249617 -1.000000       1   -1.000000   98.357508
# 2   76.759285  159.834784  4.982859       1    1.022939   56.850479
# 3  102.900301  131.177927  3.355346       1   -1.000000  111.220307
# 4  104.543774   -1.000000  2.713693       0   -1.000000   -1.000000
#
#        copper    ethanol     folate    glucose  hematocrit       tsat  \
# 0   96.721542  49.530542  23.186628  -1.000000   33.549575  57.247868
# 1  112.758764  62.464566   7.168920  -1.000000   43.162335  -1.000000
# 2   75.739552  72.072041  20.600875  44.872138   38.248071  32.068372
# 3   66.999185  18.353272  14.132423  -1.000000   34.526609  28.702050
# 4   -1.000000  -1.000000  -1.000000  -1.000000   28.369968  -1.000000
#
#                                   label
# 0                      Hemolytic anemia
# 1                             No anemia
# 2                Iron deficiency anemia
# 3                    Unspecified anemia
# 4  Vitamin B12/Folate deficiency anemia

# %%
df.isna().sum()
# Out:
# hemoglobin               0
# ferritin                 0
# ret_count                0
# segmented_neutrophils    0
# tibc                     0
# mcv                      0
# serum_iron               0
# rbc                      0
# gender                   0
# creatinine               0
# cholestrol               0
# copper                   0
# ethanol                  0
# folate                   0
# glucose                  0
# hematocrit               0
# tsat                     0
# label                    0
# dtype: int64

# %%
utils.get_dt_performance(df)
# Out:
# (0.9996428571428572,
#  0.9996136838530153,
#  0.9997821980021458,
#  datetime.timedelta(microseconds=2998))

# %%
df.label.value_counts()
# Out:
# No anemia                               10000
# Anemia of chronic disease                9756
# Iron deficiency anemia                   9267
# Unspecified anemia                       9033
# Aplastic anemia                          9020
# Vitamin B12/Folate deficiency anemia     9000
# Hemolytic anemia                         8976
# Inconclusive diagnosis                   4948
# Name: label, dtype: int64

# %%
class_dict = constants.CLASS_DICT
df['label'] = df['label'].replace(class_dict)
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=SEED)
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((56000, 17), (14000, 17), (56000,), (14000,))

# %%
action_list = list(class_dict.keys()) + [col  for col in df.columns if col!='label']
action_list
# Out:
# ['No anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Unspecified anemia',
#  'Anemia of chronic disease',
#  'Iron deficiency anemia',
#  'Hemolytic anemia',
#  'Aplastic anemia',
#  'Inconclusive diagnosis',
#  'hemoglobin',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'tibc',
#  'mcv',
#  'serum_iron',
#  'rbc',
#  'gender',
#  'creatinine',
#  'cholestrol',
#  'copper',
#  'ethanol',
#  'folate',
#  'glucose',
#  'hematocrit',
#  'tsat']

# %%
len(action_list)
# Out:
# 25

# %%
df.head()
# Out:
#    hemoglobin    ferritin  ret_count  segmented_neutrophils        tibc  \
# 0   11.183192  187.573466   4.951674               1.661383  316.593436
# 1   14.387445   -1.000000  -1.000000              -1.000000   -1.000000
# 2   12.749357    5.012158   3.502800               6.179371  498.418768
# 3   11.508870  197.180945   1.200125               0.000000  457.033309
# 4    9.456656  427.952052  -1.000000               0.660252   -1.000000
#
#           mcv  serum_iron       rbc  gender  creatinine  cholestrol  \
# 0   95.006424  181.242992  3.531295       1   -1.000000   28.040619
# 1   -1.000000  125.249617 -1.000000       1   -1.000000   98.357508
# 2   76.759285  159.834784  4.982859       1    1.022939   56.850479
# 3  102.900301  131.177927  3.355346       1   -1.000000  111.220307
# 4  104.543774   -1.000000  2.713693       0   -1.000000   -1.000000
#
#        copper    ethanol     folate    glucose  hematocrit       tsat  label
# 0   96.721542  49.530542  23.186628  -1.000000   33.549575  57.247868      5
# 1  112.758764  62.464566   7.168920  -1.000000   43.162335  -1.000000      0
# 2   75.739552  72.072041  20.600875  44.872138   38.248071  32.068372      4
# 3   66.999185  18.353272  14.132423  -1.000000   34.526609  28.702050      2
# 4   -1.000000  -1.000000  -1.000000  -1.000000   28.369968  -1.000000      1

# %% [markdown]
# #### Training

# %%
# %%time
# timesteps = int(2e6)
# dqn_model = utils.stable_dqn3(X_train, y_train, timesteps, True, f'../../models/many_features/stable_dqn3_{timesteps}')
# test_df = utils.evaluate_dqn(dqn_model, X_test, y_test)
# test_df.head()

# %%
#for steps in [int(6e6), int(6.5e6), int(7e6), int(7.5e6), int(8e6), int(8.5e6), int(9e6)]:
for steps in [int(7e6), int(9e6), int(11e6)]:
    #start_time = datetime.now()
    dqn_model = utils.stable_dqn3(X_train, y_train, steps, True, 
                                  f'../../models/many_features/0.1/with_correlated_fts/dqn3_by_type_{steps}')
    #end_time = datetime.now()
    #print(f'The duration for {steps} steps is {end_time-start_time}')
# Out:
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69     |
# |    ep_rew_mean      | -0.8     |
# |    exploration_rate | 0.582    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1402     |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 308008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.45     |
# |    n_updates        | 64501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26     |
# |    ep_rew_mean      | -0.92    |
# |    exploration_rate | 0.0864   |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1123     |
# |    time_elapsed     | 599      |
# |    total_timesteps  | 673181   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.98     |
# |    n_updates        | 155795   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 845      |
# |    time_elapsed     | 1257     |
# |    total_timesteps  | 1063086  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 253271   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3        |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 601      |
# |    time_elapsed     | 2473     |
# |    total_timesteps  | 1488516  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 359628   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.9      |
# |    ep_rew_mean      | -0.36    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 514      |
# |    time_elapsed     | 3696     |
# |    total_timesteps  | 1903231  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 463307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61     |
# |    ep_rew_mean      | -0.5     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.36     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 465      |
# |    time_elapsed     | 5042     |
# |    total_timesteps  | 2348993  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.068    |
# |    n_updates        | 574748   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99     |
# |    ep_rew_mean      | -0.26    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.38     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 440      |
# |    time_elapsed     | 6304     |
# |    total_timesteps  | 2778758  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 682189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | -0.1     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 424      |
# |    time_elapsed     | 7552     |
# |    total_timesteps  | 3207579  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 789394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.68     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.54     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 436      |
# |    time_elapsed     | 8357     |
# |    total_timesteps  | 3646408  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 899101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 462      |
# |    time_elapsed     | 8853     |
# |    total_timesteps  | 4096096  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0427   |
# |    n_updates        | 1011523  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.86     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.7      |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 484      |
# |    time_elapsed     | 9351     |
# |    total_timesteps  | 4529776  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.076    |
# |    n_updates        | 1119943  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.48     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 504      |
# |    time_elapsed     | 9850     |
# |    total_timesteps  | 4969919  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 1229979  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 520      |
# |    time_elapsed     | 10370    |
# |    total_timesteps  | 5402805  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0778   |
# |    n_updates        | 1338201  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 536      |
# |    time_elapsed     | 10902    |
# |    total_timesteps  | 5848490  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 1449622  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.79     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.7      |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 551      |
# |    time_elapsed     | 11420    |
# |    total_timesteps  | 6298556  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0938   |
# |    n_updates        | 1562138  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.58     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 564      |
# |    time_elapsed     | 11947    |
# |    total_timesteps  | 6747939  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 1674484  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36     |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.687    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1403     |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 296795   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.7      |
# |    n_updates        | 61698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5      |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.298    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1191     |
# |    time_elapsed     | 557      |
# |    total_timesteps  | 664966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 32.8     |
# |    n_updates        | 153741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.04     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1090     |
# |    time_elapsed     | 939      |
# |    total_timesteps  | 1024624  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.3     |
# |    n_updates        | 243655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.56     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1037     |
# |    time_elapsed     | 1389     |
# |    total_timesteps  | 1441670  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.636    |
# |    n_updates        | 347917   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1000     |
# |    time_elapsed     | 1921     |
# |    total_timesteps  | 1922617  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 468154   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | -0.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.55     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 970      |
# |    time_elapsed     | 2411     |
# |    total_timesteps  | 2339263  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0639   |
# |    n_updates        | 572315   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.44     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 949      |
# |    time_elapsed     | 2883     |
# |    total_timesteps  | 2737394  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 671848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 929      |
# |    time_elapsed     | 3374     |
# |    total_timesteps  | 3137791  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0661   |
# |    n_updates        | 771947   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.75     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 912      |
# |    time_elapsed     | 3872     |
# |    total_timesteps  | 3534970  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0766   |
# |    n_updates        | 871242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 892      |
# |    time_elapsed     | 4404     |
# |    total_timesteps  | 3931601  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 970400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 872      |
# |    time_elapsed     | 4966     |
# |    total_timesteps  | 4333091  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 1070772  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 861      |
# |    time_elapsed     | 5497     |
# |    total_timesteps  | 4734123  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00645  |
# |    n_updates        | 1171030  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.68     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 859      |
# |    time_elapsed     | 5974     |
# |    total_timesteps  | 5132941  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0445   |
# |    n_updates        | 1270735  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 849      |
# |    time_elapsed     | 6505     |
# |    total_timesteps  | 5528018  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 1369504  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.64     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 844      |
# |    time_elapsed     | 7014     |
# |    total_timesteps  | 5925408  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.051    |
# |    n_updates        | 1468851  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.75     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 837      |
# |    time_elapsed     | 7544     |
# |    total_timesteps  | 6321824  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 1567955  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 835      |
# |    time_elapsed     | 8041     |
# |    total_timesteps  | 6716660  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 1666664  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 837      |
# |    time_elapsed     | 8493     |
# |    total_timesteps  | 7113289  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0878   |
# |    n_updates        | 1765822  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28     |
# |    ep_rew_mean      | 0.72     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.91     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 835      |
# |    time_elapsed     | 8987     |
# |    total_timesteps  | 7511137  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 1865284  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | 0.64     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.89     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 822      |
# |    time_elapsed     | 9616     |
# |    total_timesteps  | 7911018  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0893   |
# |    n_updates        | 1965254  |
# ----------------------------------

# %% [markdown]
# #### Testing

# %%
training_env = utils.create_env(X_train, y_train)
dqn_model = utils.load_dqn3('../../models/many_features/0.1/with_correlated_fts/dqn3_by_type_5000000', training_env)
test_df = utils.evaluate_dqn(dqn_model, X_test, y_test)
test_df.head()
# Out:
# Using stable baselines 3
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Count: 2800
# Count: 5600
# Count: 8400
# Count: 11200
# Count: 14000
# Testing done.....
#    episode_length  index  is_success  reward  terminated  \
# 0             4.0    0.0         1.0     1.0         0.0
# 1             5.0    1.0         1.0     1.0         0.0
# 2             5.0    2.0         1.0     1.0         0.0
# 3             4.0    3.0         1.0     1.0         0.0
# 4             4.0    4.0         1.0     1.0         0.0
#
#                                           trajectory  y_actual  y_pred
# 0      [hemoglobin, mcv, ret_count, Aplastic anemia]       6.0     6.0
# 1  [hemoglobin, mcv, segmented_neutrophils, gende...       2.0     2.0
# 2  [hemoglobin, mcv, segmented_neutrophils, gende...       2.0     2.0
# 3     [hemoglobin, mcv, ret_count, Hemolytic anemia]       5.0     5.0
# 4     [hemoglobin, mcv, ret_count, Hemolytic anemia]       5.0     5.0

# %%
success_rate, success_df = utils.success_rate(test_df)
success_rate
# Out:
# 90.10000000000001

# %%
avg_length, avg_return = utils.get_avg_length_reward(test_df)
avg_length, avg_return
# Out:
# (4.136214285714286, 0.6664285714285715)

# %%
acc, f1, roc_auc = utils.test(test_df['y_actual'], test_df['y_pred'])
acc, f1, roc_auc
# Out:
# (0.901, 0.895271848492234, 0.9457975077860811)

# %%
test_df.y_pred.unique()
# Out:
# array([6., 2., 5., 7., 4., 3., 0., 1.])

# %%
test_df[test_df.y_pred==4]
# Out:
#        episode_length    index  is_success  reward  terminated  \
# 8                 4.0      8.0         1.0     1.0         0.0
# 16                5.0     16.0         1.0     1.0         0.0
# 23                4.0     23.0         1.0     1.0         0.0
# 31                4.0     31.0         1.0     1.0         0.0
# 41                4.0     41.0         1.0     1.0         0.0
# ...               ...      ...         ...     ...         ...
# 13968             4.0  13968.0         1.0     1.0         0.0
# 13989             4.0  13989.0         1.0     1.0         0.0
# 13995             4.0  13995.0         1.0     1.0         0.0
# 13996             4.0  13996.0         1.0     1.0         0.0
# 13999             4.0  13999.0         1.0     1.0         0.0
#
#                                               trajectory  y_actual  y_pred
# 8        [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 16     [hemoglobin, mcv, tibc, gender, Iron deficienc...       4.0     4.0
# 23       [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 31       [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 41       [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# ...                                                  ...       ...     ...
# 13968    [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 13989    [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 13995    [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 13996    [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
# 13999    [hemoglobin, mcv, tibc, Iron deficiency anemia]       4.0     4.0
#
# [1751 rows x 8 columns]

# %% [markdown]
# #### Saving files

# %%
# test_df.to_csv(f'../../test_dfs/many_features/0.1/test_df3_noisy_6_12000000.csv', index=False)
# success_df.to_csv(f'../../test_dfs/many_features/0.1/success_df3_noisy_6_12000000.csv', index=False)

# %% [markdown]
# #### Confusion matrix and classification report

# %%
test_df = pd.read_csv('../../test_dfs/many_features/0.1/test_df3_6500000.csv')
test_df.head()

# %%
utils.plot_classification_report(test_df['y_actual'], test_df['y_pred'])

# %%
# def plot_confusion_matrix(y_actual, y_pred, save=False, filename=False):
#     from sklearn.metrics import confusion_matrix
#     cm = confusion_matrix(y_actual, y_pred)
#     cm_df = pd.DataFrame(cm, index = [0, 1, 2, 3, 4, 5, 6], columns = [0, 1, 2, 3, 4, 5, 6], dtype='object')
#     #cm_df = pd.DataFrame(cm, index = constants.CLASS_DICT.keys(), columns = constants.CLASS_DICT.keys())
#     plt.figure(figsize=(8, 6))
#     sns.heatmap(cm_df, annot=True)
#     plt.title('Confusion Matrix')
#     plt.ylabel('Actual Anemia')
#     plt.xlabel('Predicted Anemia')
#     plt.tight_layout()
#     if save:
#         plt.savefig(filename)
#     plt.show()
#     plt.close()

# %%
utils.plot_confusion_matrix(test_df['y_actual'], test_df['y_pred'])
