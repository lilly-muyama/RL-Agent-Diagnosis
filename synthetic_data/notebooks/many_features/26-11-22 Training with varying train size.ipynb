# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import os
from datetime import datetime
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#SEED = 42
#random.seed(SEED)
#np.random.seed(SEED)
#os.environ['PYTHONHASHSEED']=str(SEED)
#torch.manual_seed(SEED)
#torch.use_deterministic_algorithms(True)

# %%
seeds = [0, 21, 63, 84]
sizes = [0.5, 0.1, 0.05, 0.01]
for size in sizes:
    for seed in seeds:
        random.seed(seed)
        np.random.seed(seed)
        os.environ['PYTHONHASHSEED']=str(seed)
        torch.manual_seed(seed)
        torch.use_deterministic_algorithms(True)
        train_df = pd.read_csv(f'../../final/data/train_set_basic_{size}_seed_{seed}.csv')
        train_df = train_df.fillna(-1)
        X_train = train_df.iloc[:, 0:-1]
        y_train = train_df.iloc[:, -1]
        X_train, y_train = np.array(X_train), np.array(y_train)
        dqn_model = utils.stable_dqn3(X_train, y_train, 6000000, True, 
                                      f'../../final/models/dqn_set_{size}_{seed}_6000000')
# Out:
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54     |
# |    ep_rew_mean      | -0.8     |
# |    exploration_rate | 0.511    |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1522     |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 309087   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.7      |
# |    n_updates        | 64771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1196     |
# |    time_elapsed     | 576      |
# |    total_timesteps  | 690280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.71     |
# |    n_updates        | 160069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1122     |
# |    time_elapsed     | 931      |
# |    total_timesteps  | 1045609  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 248902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.3      |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1109     |
# |    time_elapsed     | 1342     |
# |    total_timesteps  | 1488392  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 359597   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.58     |
# |    ep_rew_mean      | -0.36    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.37     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1111     |
# |    time_elapsed     | 1707     |
# |    total_timesteps  | 1898411  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0523   |
# |    n_updates        | 462102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | -0.18    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.44     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1091     |
# |    time_elapsed     | 2130     |
# |    total_timesteps  | 2324538  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0912   |
# |    n_updates        | 568634   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1078     |
# |    time_elapsed     | 2529     |
# |    total_timesteps  | 2728535  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.145    |
# |    n_updates        | 669633   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1070     |
# |    time_elapsed     | 2942     |
# |    total_timesteps  | 3150798  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0711   |
# |    n_updates        | 775199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1060     |
# |    time_elapsed     | 3370     |
# |    total_timesteps  | 3574384  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.169    |
# |    n_updates        | 881095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.64     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1051     |
# |    time_elapsed     | 3810     |
# |    total_timesteps  | 4005342  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 988835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.57     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1045     |
# |    time_elapsed     | 4244     |
# |    total_timesteps  | 4439857  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0508   |
# |    n_updates        | 1097464  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.85     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1039     |
# |    time_elapsed     | 4691     |
# |    total_timesteps  | 4875291  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00378  |
# |    n_updates        | 1206322  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1032     |
# |    time_elapsed     | 5139     |
# |    total_timesteps  | 5306921  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 1314230  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1028     |
# |    time_elapsed     | 5577     |
# |    total_timesteps  | 5737486  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0499   |
# |    n_updates        | 1421871  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.513    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1508     |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 307341   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.48     |
# |    n_updates        | 64335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1249     |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 673801   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14.9     |
# |    n_updates        | 155950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1102     |
# |    time_elapsed     | 938      |
# |    total_timesteps  | 1034588  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.95     |
# |    n_updates        | 246146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1080     |
# |    time_elapsed     | 1369     |
# |    total_timesteps  | 1480657  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 357664   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.73     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1073     |
# |    time_elapsed     | 1769     |
# |    total_timesteps  | 1899790  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0569   |
# |    n_updates        | 462447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72     |
# |    ep_rew_mean      | -0.38    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1056     |
# |    time_elapsed     | 2185     |
# |    total_timesteps  | 2309972  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0741   |
# |    n_updates        | 564992   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | -0.18    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1052     |
# |    time_elapsed     | 2579     |
# |    total_timesteps  | 2716305  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 666576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1053     |
# |    time_elapsed     | 2998     |
# |    total_timesteps  | 3158555  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0757   |
# |    n_updates        | 777138   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.51     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1040     |
# |    time_elapsed     | 3460     |
# |    total_timesteps  | 3602134  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0592   |
# |    n_updates        | 888033   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.62     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.91     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1034     |
# |    time_elapsed     | 3916     |
# |    total_timesteps  | 4051172  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0513   |
# |    n_updates        | 1000292  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.26     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1037     |
# |    time_elapsed     | 4347     |
# |    total_timesteps  | 4510355  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.098    |
# |    n_updates        | 1115088  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.7      |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1040     |
# |    time_elapsed     | 4776     |
# |    total_timesteps  | 4971202  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0733   |
# |    n_updates        | 1230300  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46     |
# |    ep_rew_mean      | 0.64     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.89     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1041     |
# |    time_elapsed     | 5205     |
# |    total_timesteps  | 5421719  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.133    |
# |    n_updates        | 1342929  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1040     |
# |    time_elapsed     | 5644     |
# |    total_timesteps  | 5870852  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00983  |
# |    n_updates        | 1455212  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5      |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.507    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1540     |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 311433   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.37     |
# |    n_updates        | 65358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.72     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1282     |
# |    time_elapsed     | 553      |
# |    total_timesteps  | 709459   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.27     |
# |    n_updates        | 164864   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.01     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1204     |
# |    time_elapsed     | 884      |
# |    total_timesteps  | 1065018  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2      |
# |    n_updates        | 253754   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.84     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1152     |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 1515744  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 366435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.06     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1132     |
# |    time_elapsed     | 1728     |
# |    total_timesteps  | 1958685  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 477171   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | -0.28    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1112     |
# |    time_elapsed     | 2171     |
# |    total_timesteps  | 2415016  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 591253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.65     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1102     |
# |    time_elapsed     | 2577     |
# |    total_timesteps  | 2841907  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0903   |
# |    n_updates        | 697976   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.4      |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1093     |
# |    time_elapsed     | 2990     |
# |    total_timesteps  | 3270802  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 805200   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1086     |
# |    time_elapsed     | 3408     |
# |    total_timesteps  | 3704572  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 913642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.63     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1072     |
# |    time_elapsed     | 3858     |
# |    total_timesteps  | 4137315  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0448   |
# |    n_updates        | 1021828  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1046     |
# |    time_elapsed     | 4364     |
# |    total_timesteps  | 4566997  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 1129249  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.89     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1045     |
# |    time_elapsed     | 4788     |
# |    total_timesteps  | 5004279  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00984  |
# |    n_updates        | 1238569  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.55     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1040     |
# |    time_elapsed     | 5235     |
# |    total_timesteps  | 5445697  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 1348924  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | 0.6      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.91     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1039     |
# |    time_elapsed     | 5667     |
# |    total_timesteps  | 5889548  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 1459886  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.512    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1512     |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 308178   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.43     |
# |    n_updates        | 64544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8      |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1283     |
# |    time_elapsed     | 537      |
# |    total_timesteps  | 689974   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.1     |
# |    n_updates        | 159993   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1184     |
# |    time_elapsed     | 893      |
# |    total_timesteps  | 1058814  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 252203   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1144     |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 1503892  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 363472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8      |
# |    ep_rew_mean      | -0.4     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1111     |
# |    time_elapsed     | 1751     |
# |    total_timesteps  | 1946371  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 474092   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.49     |
# |    ep_rew_mean      | -0.4     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.32     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1096     |
# |    time_elapsed     | 2172     |
# |    total_timesteps  | 2381721  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 582930   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | -0.28    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.38     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1082     |
# |    time_elapsed     | 2609     |
# |    total_timesteps  | 2825370  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0757   |
# |    n_updates        | 693842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.47     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.63     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1074     |
# |    time_elapsed     | 3060     |
# |    total_timesteps  | 3288691  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0954   |
# |    n_updates        | 809672   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1067     |
# |    time_elapsed     | 3485     |
# |    total_timesteps  | 3721267  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.054    |
# |    n_updates        | 917816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.66     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.76     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1058     |
# |    time_elapsed     | 3911     |
# |    total_timesteps  | 4141120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 1022779  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1058     |
# |    time_elapsed     | 4311     |
# |    total_timesteps  | 4562179  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 1128044  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4        |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1053     |
# |    time_elapsed     | 4732     |
# |    total_timesteps  | 4985812  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0473   |
# |    n_updates        | 1233952  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1050     |
# |    time_elapsed     | 5159     |
# |    total_timesteps  | 5419043  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00525  |
# |    n_updates        | 1342260  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.51     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1045     |
# |    time_elapsed     | 5600     |
# |    total_timesteps  | 5853752  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0855   |
# |    n_updates        | 1450937  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4      |
# |    ep_rew_mean      | -0.92    |
# |    exploration_rate | 0.506    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1454     |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 311859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.8     |
# |    n_updates        | 65464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1255     |
# |    time_elapsed     | 561      |
# |    total_timesteps  | 705252   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10       |
# |    n_updates        | 163812   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1184     |
# |    time_elapsed     | 901      |
# |    total_timesteps  | 1067690  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.57     |
# |    n_updates        | 254422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.94     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1153     |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 1517374  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 366843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.48     |
# |    ep_rew_mean      | -0.34    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.38     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1136     |
# |    time_elapsed     | 1699     |
# |    total_timesteps  | 1931897  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 470474   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43     |
# |    ep_rew_mean      | -0.32    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.37     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1120     |
# |    time_elapsed     | 2084     |
# |    total_timesteps  | 2334818  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 571204   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1100     |
# |    time_elapsed     | 2492     |
# |    total_timesteps  | 2743864  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0664   |
# |    n_updates        | 673465   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1089     |
# |    time_elapsed     | 2892     |
# |    total_timesteps  | 3151297  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.174    |
# |    n_updates        | 775324   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1068     |
# |    time_elapsed     | 3336     |
# |    total_timesteps  | 3564701  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 878675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.75     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1058     |
# |    time_elapsed     | 3757     |
# |    total_timesteps  | 3976736  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 981683   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1052     |
# |    time_elapsed     | 4169     |
# |    total_timesteps  | 4390011  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 1085002  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1046     |
# |    time_elapsed     | 4586     |
# |    total_timesteps  | 4802008  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 1188001  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1043     |
# |    time_elapsed     | 4998     |
# |    total_timesteps  | 5213525  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00591  |
# |    n_updates        | 1290881  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | 0.6      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.93     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1042     |
# |    time_elapsed     | 5399     |
# |    total_timesteps  | 5629825  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 1394956  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.504    |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1551     |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 313503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.6      |
# |    n_updates        | 65875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1291     |
# |    time_elapsed     | 539      |
# |    total_timesteps  | 695910   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 16.3     |
# |    n_updates        | 161477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1189     |
# |    time_elapsed     | 885      |
# |    total_timesteps  | 1053255  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 250813   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.53     |
# |    ep_rew_mean      | -0.76    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1144     |
# |    time_elapsed     | 1319     |
# |    total_timesteps  | 1510372  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 365092   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.4      |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1111     |
# |    time_elapsed     | 1757     |
# |    total_timesteps  | 1953479  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0755   |
# |    n_updates        | 475869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46     |
# |    ep_rew_mean      | -0.38    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1086     |
# |    time_elapsed     | 2196     |
# |    total_timesteps  | 2385620  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0378   |
# |    n_updates        | 583904   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.59     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.56     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1077     |
# |    time_elapsed     | 2645     |
# |    total_timesteps  | 2851527  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0441   |
# |    n_updates        | 700381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.06     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.57     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1065     |
# |    time_elapsed     | 3137     |
# |    total_timesteps  | 3343334  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0861   |
# |    n_updates        | 823333   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.93     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.73     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1062     |
# |    time_elapsed     | 3611     |
# |    total_timesteps  | 3838604  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.126    |
# |    n_updates        | 947150   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.83     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1057     |
# |    time_elapsed     | 4084     |
# |    total_timesteps  | 4321721  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0418   |
# |    n_updates        | 1067930  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.36     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.91     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1054     |
# |    time_elapsed     | 4559     |
# |    total_timesteps  | 4809444  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00869  |
# |    n_updates        | 1189860  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.76     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1054     |
# |    time_elapsed     | 5031     |
# |    total_timesteps  | 5304480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00753  |
# |    n_updates        | 1313619  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.28     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1052     |
# |    time_elapsed     | 5508     |
# |    total_timesteps  | 5799366  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 1437341  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5      |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.508    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1545     |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 310532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.96     |
# |    n_updates        | 65132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99     |
# ...
# |    n_updates        | 160518   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1257     |
# |    time_elapsed     | 840      |
# |    total_timesteps  | 1056809  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.57     |
# |    n_updates        | 251702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.35     |
# |    ep_rew_mean      | -0.72    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1195     |
# |    time_elapsed     | 1255     |
# |    total_timesteps  | 1500404  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 362600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | -0.32    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1140     |
# |    time_elapsed     | 1678     |
# |    total_timesteps  | 1914489  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 466122   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7      |
# |    ep_rew_mean      | -0.12    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.49     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1093     |
# |    time_elapsed     | 2126     |
# |    total_timesteps  | 2324789  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 568697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1093     |
# |    time_elapsed     | 2497     |
# |    total_timesteps  | 2731683  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0793   |
# |    n_updates        | 670420   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1080     |
# |    time_elapsed     | 2913     |
# |    total_timesteps  | 3148243  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 774560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1075     |
# |    time_elapsed     | 3318     |
# |    total_timesteps  | 3570489  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 880122   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28     |
# |    ep_rew_mean      | 0.74     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.9      |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1065     |
# |    time_elapsed     | 3751     |
# |    total_timesteps  | 3997699  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0865   |
# |    n_updates        | 986924   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1063     |
# |    time_elapsed     | 4167     |
# |    total_timesteps  | 4432740  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0541   |
# |    n_updates        | 1095684  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1061     |
# |    time_elapsed     | 4578     |
# |    total_timesteps  | 4860266  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0802   |
# |    n_updates        | 1202566  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1014     |
# |    time_elapsed     | 5208     |
# |    total_timesteps  | 5281976  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 1307993  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 953      |
# |    time_elapsed     | 5977     |
# |    total_timesteps  | 5700490  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0431   |
# |    n_updates        | 1412622  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9      |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.51     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 803      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 309243   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04     |
# |    n_updates        | 64810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 676      |
# |    time_elapsed     | 1026     |
# |    total_timesteps  | 694139   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.05     |
# |    n_updates        | 161034   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 690      |
# |    time_elapsed     | 1516     |
# |    total_timesteps  | 1046771  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 249192   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.4      |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 780      |
# |    time_elapsed     | 1924     |
# |    total_timesteps  | 1503022  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0638   |
# |    n_updates        | 363255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.69     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.29     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 819      |
# |    time_elapsed     | 2342     |
# |    total_timesteps  | 1919780  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 467444   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 838      |
# |    time_elapsed     | 2781     |
# |    total_timesteps  | 2332940  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0642   |
# |    n_updates        | 570734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | -0.1     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.5      |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 837      |
# |    time_elapsed     | 3292     |
# |    total_timesteps  | 2756162  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0672   |
# |    n_updates        | 676540   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 841      |
# |    time_elapsed     | 3770     |
# |    total_timesteps  | 3173127  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 780781   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 839      |
# |    time_elapsed     | 4278     |
# |    total_timesteps  | 3592061  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0732   |
# |    n_updates        | 885515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 833      |
# |    time_elapsed     | 4818     |
# |    total_timesteps  | 4013667  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0521   |
# |    n_updates        | 990916   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.6      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 842      |
# |    time_elapsed     | 5261     |
# |    total_timesteps  | 4433229  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.162    |
# |    n_updates        | 1095807  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.89     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 843      |
# |    time_elapsed     | 5755     |
# |    total_timesteps  | 4854084  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 1201020  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.72     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.92     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 839      |
# |    time_elapsed     | 6284     |
# |    total_timesteps  | 5277051  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0697   |
# |    n_updates        | 1306762  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.89     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 862      |
# |    time_elapsed     | 6610     |
# |    total_timesteps  | 5699170  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0563   |
# |    n_updates        | 1412292  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.505    |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1856     |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 312759   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.82     |
# |    n_updates        | 65689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1486     |
# |    time_elapsed     | 462      |
# |    total_timesteps  | 687468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.98     |
# |    n_updates        | 159366   |
# ----------------------------------
