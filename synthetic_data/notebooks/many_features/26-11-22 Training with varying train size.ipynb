# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import os
from datetime import datetime
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %%
sizes = [0.5, 0.1, 0.05, 0.01]
for size in sizes:
    train_df = pd.read_csv(f'../../final/data/train_set_{size}')
    print(f'Size {size} has {len(train_df)} samples')
    train_df = train_df.fillna(-1)
    X_train = train_df.iloc[:, 0:-1]
    y_train = train_df.iloc[:, -1]
    X_train, y_train = np.array(X_train), np.array(y_train)
    dqn_model = utils.stable_dqn3(X_train, y_train, 6000000, True, f'../../final/models/dqn_set_{size}')
# Out:
# Size 0.5 has 28000 samples
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.506    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1534     |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 312050   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.63     |
# |    n_updates        | 65512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1196     |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 693708   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.6      |
# |    n_updates        | 160926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1137     |
# |    time_elapsed     | 934      |
# |    total_timesteps  | 1063415  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47     |
# |    n_updates        | 253353   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71     |
# |    ep_rew_mean      | -0.48    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.3      |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1070     |
# |    time_elapsed     | 1414     |
# |    total_timesteps  | 1514204  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 366050   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65     |
# |    ep_rew_mean      | -0.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.5      |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1049     |
# |    time_elapsed     | 1802     |
# |    total_timesteps  | 1892876  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 460718   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.8      |
# |    ep_rew_mean      | -0.02    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.53     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1014     |
# |    time_elapsed     | 2241     |
# |    total_timesteps  | 2273010  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0862   |
# |    n_updates        | 555752   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 979      |
# |    time_elapsed     | 2734     |
# |    total_timesteps  | 2679637  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0816   |
# |    n_updates        | 657409   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 961      |
# |    time_elapsed     | 3204     |
# |    total_timesteps  | 3081380  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0467   |
# |    n_updates        | 757844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 966      |
# |    time_elapsed     | 3602     |
# |    total_timesteps  | 3481729  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0473   |
# |    n_updates        | 857932   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.85     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 956      |
# |    time_elapsed     | 4055     |
# |    total_timesteps  | 3879907  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 957476   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9      |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 957      |
# |    time_elapsed     | 4467     |
# |    total_timesteps  | 4277182  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0927   |
# |    n_updates        | 1056795  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4        |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 955      |
# |    time_elapsed     | 4893     |
# |    total_timesteps  | 4674684  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 1156170  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.85     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 957      |
# |    time_elapsed     | 5298     |
# |    total_timesteps  | 5071226  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0366   |
# |    n_updates        | 1255306  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 959      |
# |    time_elapsed     | 5698     |
# |    total_timesteps  | 5469430  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0876   |
# |    n_updates        | 1354857  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | 0.72     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.9      |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 965      |
# |    time_elapsed     | 6082     |
# |    total_timesteps  | 5870097  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0464   |
# |    n_updates        | 1455024  |
# ----------------------------------
# Size 0.1 has 5600 samples
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.511    |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1568     |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 308774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.06     |
# |    n_updates        | 64693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1300     |
# |    time_elapsed     | 526      |
# |    total_timesteps  | 684215   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.5     |
# |    n_updates        | 158553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1129     |
# |    time_elapsed     | 917      |
# |    total_timesteps  | 1036467  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.78     |
# |    n_updates        | 246616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | -0.44    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.32     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1095     |
# |    time_elapsed     | 1335     |
# |    total_timesteps  | 1462625  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 353156   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | -0.26    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1077     |
# |    time_elapsed     | 1737     |
# |    total_timesteps  | 1871822  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0546   |
# |    n_updates        | 455455   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.39     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1062     |
# |    time_elapsed     | 2151     |
# |    total_timesteps  | 2286017  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.147    |
# |    n_updates        | 559004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | -0.14    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.54     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1061     |
# |    time_elapsed     | 2533     |
# |    total_timesteps  | 2688109  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 659527   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.65     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1060     |
# |    time_elapsed     | 2926     |
# |    total_timesteps  | 3104607  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0763   |
# |    n_updates        | 763651   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1061     |
# |    time_elapsed     | 3341     |
# |    total_timesteps  | 3545327  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0765   |
# |    n_updates        | 873831   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1060     |
# |    time_elapsed     | 3750     |
# |    total_timesteps  | 3976957  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0976   |
# |    n_updates        | 981739   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1054     |
# |    time_elapsed     | 4169     |
# |    total_timesteps  | 4395633  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0562   |
# |    n_updates        | 1086408  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27     |
# |    ep_rew_mean      | 0.7      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.9      |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1046     |
# |    time_elapsed     | 4604     |
# |    total_timesteps  | 4820243  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 1192560  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1039     |
# |    time_elapsed     | 5042     |
# |    total_timesteps  | 5242136  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 1298033  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1036     |
# |    time_elapsed     | 5463     |
# |    total_timesteps  | 5661854  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 1402963  |
# ----------------------------------
# Size 0.05 has 2800 samples
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.507    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1382     |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 311102   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.36     |
# |    n_updates        | 65275    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1229     |
# |    time_elapsed     | 575      |
# |    total_timesteps  | 707536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 17.2     |
# |    n_updates        | 164383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1137     |
# |    time_elapsed     | 939      |
# |    total_timesteps  | 1068788  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.33     |
# |    n_updates        | 254696   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.3      |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1097     |
# |    time_elapsed     | 1388     |
# |    total_timesteps  | 1524322  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0673   |
# |    n_updates        | 368580   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1073     |
# |    time_elapsed     | 1855     |
# |    total_timesteps  | 1992819  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0488   |
# |    n_updates        | 485704   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32     |
# |    ep_rew_mean      | -0.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.53     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1063     |
# |    time_elapsed     | 2286     |
# |    total_timesteps  | 2432335  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0958   |
# |    n_updates        | 595583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.65     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1046     |
# |    time_elapsed     | 2726     |
# |    total_timesteps  | 2852837  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0558   |
# |    n_updates        | 700709   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1036     |
# |    time_elapsed     | 3151     |
# |    total_timesteps  | 3266706  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.194    |
# |    n_updates        | 804176   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.85     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1029     |
# |    time_elapsed     | 3576     |
# |    total_timesteps  | 3681887  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0544   |
# |    n_updates        | 907971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4        |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1025     |
# |    time_elapsed     | 3989     |
# |    total_timesteps  | 4090901  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0998   |
# |    n_updates        | 1010225  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1018     |
# |    time_elapsed     | 4421     |
# |    total_timesteps  | 4501255  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0584   |
# |    n_updates        | 1112813  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1016     |
# |    time_elapsed     | 4831     |
# |    total_timesteps  | 4912573  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0547   |
# |    n_updates        | 1215643  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1008     |
# |    time_elapsed     | 5277     |
# |    total_timesteps  | 5322758  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 1318189  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.85     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1003     |
# |    time_elapsed     | 5714     |
# |    total_timesteps  | 5733993  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 1420998  |
# ----------------------------------
# Size 0.01 has 560 samples
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.55     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.504    |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1396     |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 313252   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.44     |
# |    n_updates        | 65812    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1171     |
# |    time_elapsed     | 584      |
# |    total_timesteps  | 684321   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.73     |
# |    n_updates        | 158580   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1114     |
# |    time_elapsed     | 949      |
# |    total_timesteps  | 1057598  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.743    |
# |    n_updates        | 251899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.31     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1061     |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 1481439  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0721   |
# |    n_updates        | 357859   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16     |
# |    ep_rew_mean      | -0.42    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.35     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1048     |
# |    time_elapsed     | 1794     |
# |    total_timesteps  | 1881962  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0653   |
# |    n_updates        | 457990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94     |
# |    ep_rew_mean      | -0.22    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.46     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1034     |
# |    time_elapsed     | 2236     |
# |    total_timesteps  | 2313584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0801   |
# |    n_updates        | 565895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.54     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1029     |
# |    time_elapsed     | 2655     |
# |    total_timesteps  | 2734200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 671049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1014     |
# |    time_elapsed     | 3096     |
# |    total_timesteps  | 3140337  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0457   |
# |    n_updates        | 772584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1015     |
# |    time_elapsed     | 3495     |
# |    total_timesteps  | 3549317  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0749   |
# |    n_updates        | 874829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.75     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1011     |
# |    time_elapsed     | 3909     |
# |    total_timesteps  | 3955445  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 976361   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1008     |
# |    time_elapsed     | 4322     |
# |    total_timesteps  | 4357580  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0572   |
# |    n_updates        | 1076894  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.69     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1004     |
# |    time_elapsed     | 4744     |
# |    total_timesteps  | 4765416  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0408   |
# |    n_updates        | 1178853  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | 0.34     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1006     |
# |    time_elapsed     | 5140     |
# |    total_timesteps  | 5173010  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0657   |
# |    n_updates        | 1280752  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | 0.36     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.73     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 1000     |
# |    time_elapsed     | 5576     |
# |    total_timesteps  | 5580607  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 1382651  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.75     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 1000     |
# |    time_elapsed     | 5984     |
# |    total_timesteps  | 5987896  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.071    |
# |    n_updates        | 1484473  |
# ----------------------------------

# %%
sizes = [0.5, 0.1, 0.05, 0.01]
for size in sizes:
    train_df = pd.read_csv(f'../../final/data/train_set_noisy_6_{size}')
    print(f'Size {size} has {len(train_df)} samples')
    train_df = train_df.fillna(-1)
    X_train = train_df.iloc[:, 0:-1]
    y_train = train_df.iloc[:, -1]
    X_train, y_train = np.array(X_train), np.array(y_train)
    dqn_model = utils.stable_dqn3(X_train, y_train, 12000000, True, f'../../final/models/dqn_set_noisy_6_{size}')
# Out:
# Size 0.5 has 28000 samples
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.771    |
# |    success_rate     | 0.03     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 880      |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 288778   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01     |
# |    n_updates        | 59694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78     |
# |    ep_rew_mean      | -0.92    |
# |    exploration_rate | 0.502    |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 741      |
# |    time_elapsed     | 849      |
# |    total_timesteps  | 629568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 231      |
# |    n_updates        | 144891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.56     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.196    |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 681      |
# |    time_elapsed     | 1492     |
# |    total_timesteps  | 1016114  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01e+03 |
# |    n_updates        | 241528   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 642      |
# |    time_elapsed     | 2205     |
# |    total_timesteps  | 1417311  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 470      |
# |    n_updates        | 341827   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.77     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 619      |
# |    time_elapsed     | 2972     |
# |    total_timesteps  | 1840607  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 255      |
# |    n_updates        | 447651   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.05     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 606      |
# |    time_elapsed     | 3633     |
# |    total_timesteps  | 2203538  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38.3     |
# |    n_updates        | 538384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 592      |
# |    time_elapsed     | 4386     |
# |    total_timesteps  | 2600791  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.08     |
# |    n_updates        | 637697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 583      |
# |    time_elapsed     | 5130     |
# |    total_timesteps  | 2992973  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04     |
# |    n_updates        | 735743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 563      |
# |    time_elapsed     | 6045     |
# |    total_timesteps  | 3404825  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.686    |
# |    n_updates        | 838706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 542      |
# |    time_elapsed     | 7017     |
# |    total_timesteps  | 3805807  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.392    |
# |    n_updates        | 938951   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 532      |
# |    time_elapsed     | 7916     |
# |    total_timesteps  | 4211374  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.47     |
# |    n_updates        | 1040343  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.68     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 529      |
# |    time_elapsed     | 8763     |
# |    total_timesteps  | 4640794  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.214    |
# |    n_updates        | 1147698  |
# ----------------------------------
