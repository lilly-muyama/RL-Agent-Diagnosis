# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import os
from datetime import datetime
import torch
import sys
sys.path.append('../..')
from modules.many_features import utils, constants
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %%
#sizes = [0.5, 0.1, 0.05, 0.01]
sizes = [1]
seeds = [0, 21, 63, 84]
for size in sizes:
    for seed in seeds:
        #train_df = pd.read_csv(f'../../final/data/train_set_basic_{size}_seed_{seed}.csv')
        train_df = pd.read_csv(f'../../final/data/train_set_basic.csv')
        train_df = train_df.fillna(-1)
        X_train = train_df.iloc[:, 0:-1]
        y_train = train_df.iloc[:, -1]
        X_train, y_train = np.array(X_train), np.array(y_train)
        dqn_model = utils.stable_dqn3(X_train, y_train, 5500000, True, 
                                      f'../../final/models/varied_size/dqn_set_{size}_{seed}_5500000')
# Out:
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.46     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 978      |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 312805   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.31     |
# |    n_updates        | 65701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 819      |
# |    time_elapsed     | 831      |
# |    total_timesteps  | 680773   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.66     |
# |    n_updates        | 157693   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.65     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 687      |
# |    time_elapsed     | 1567     |
# |    total_timesteps  | 1077768  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 256941   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | -0.48    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 742      |
# |    time_elapsed     | 2030     |
# |    total_timesteps  | 1507811  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.063    |
# |    n_updates        | 364452   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.42     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 789      |
# |    time_elapsed     | 2481     |
# |    total_timesteps  | 1960142  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 477535   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13     |
# |    ep_rew_mean      | -0.06    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.55     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 811      |
# |    time_elapsed     | 2950     |
# |    total_timesteps  | 2395337  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 586334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.53     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.72     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 819      |
# |    time_elapsed     | 3443     |
# |    total_timesteps  | 2823991  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0922   |
# |    n_updates        | 693497   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.78     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 833      |
# |    time_elapsed     | 3905     |
# |    total_timesteps  | 3256531  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 801632   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 851      |
# |    time_elapsed     | 4330     |
# |    total_timesteps  | 3688996  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0889   |
# |    n_updates        | 909748   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 863      |
# |    time_elapsed     | 4782     |
# |    total_timesteps  | 4128120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0782   |
# |    n_updates        | 1019529  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.53     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 874      |
# |    time_elapsed     | 5213     |
# |    total_timesteps  | 4559746  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 1127436  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 884      |
# |    time_elapsed     | 5645     |
# |    total_timesteps  | 4994089  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 1236022  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 895      |
# |    time_elapsed     | 6057     |
# |    total_timesteps  | 5425504  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 1343875  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.455    |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1543     |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 315471   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.02     |
# |    n_updates        | 66367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1207     |
# |    time_elapsed     | 568      |
# |    total_timesteps  | 686375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.3      |
# |    n_updates        | 159093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.48     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1109     |
# |    time_elapsed     | 975      |
# |    total_timesteps  | 1083128  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.337    |
# |    n_updates        | 258281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1078     |
# |    time_elapsed     | 1438     |
# |    total_timesteps  | 1550895  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0834   |
# |    n_updates        | 375223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1064     |
# |    time_elapsed     | 1876     |
# |    total_timesteps  | 1996521  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0337   |
# |    n_updates        | 486630   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.27     |
# |    ep_rew_mean      | -0.16    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.45     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1046     |
# |    time_elapsed     | 2360     |
# |    total_timesteps  | 2470507  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0779   |
# |    n_updates        | 605126   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 880      |
# |    time_elapsed     | 3348     |
# |    total_timesteps  | 2949080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 724769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.73     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 813      |
# |    time_elapsed     | 4216     |
# |    total_timesteps  | 3430381  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.092    |
# |    n_updates        | 845095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.97     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 830      |
# |    time_elapsed     | 4693     |
# |    total_timesteps  | 3896180  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 961544   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.73     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.76     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 848      |
# |    time_elapsed     | 5139     |
# |    total_timesteps  | 4358754  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0499   |
# |    n_updates        | 1077188  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.57     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 863      |
# |    time_elapsed     | 5574     |
# |    total_timesteps  | 4814083  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0848   |
# |    n_updates        | 1191020  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 873      |
# |    time_elapsed     | 6035     |
# |    total_timesteps  | 5268976  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 1304743  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.86     |
# |    ep_rew_mean      | -0.92    |
# |    exploration_rate | 0.464    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1440     |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 310460   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.7      |
# |    n_updates        | 65114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1211     |
# |    time_elapsed     | 562      |
# |    total_timesteps  | 681299   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.8      |
# |    n_updates        | 157824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1155     |
# |    time_elapsed     | 927      |
# |    total_timesteps  | 1072006  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 255501   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.41     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.28     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1140     |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 1499981  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 362495   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68     |
# |    ep_rew_mean      | -0.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.53     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1097     |
# |    time_elapsed     | 1737     |
# |    total_timesteps  | 1907891  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0898   |
# |    n_updates        | 464472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | -0.12    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.47     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1061     |
# |    time_elapsed     | 2173     |
# |    total_timesteps  | 2307817  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0758   |
# |    n_updates        | 564454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1019     |
# |    time_elapsed     | 2684     |
# |    total_timesteps  | 2737608  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0888   |
# |    n_updates        | 671901   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.41     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 995      |
# |    time_elapsed     | 3171     |
# |    total_timesteps  | 3158624  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0495   |
# |    n_updates        | 777155   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 985      |
# |    time_elapsed     | 3630     |
# |    total_timesteps  | 3579606  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 882401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.8      |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 979      |
# |    time_elapsed     | 4087     |
# |    total_timesteps  | 4005157  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.083    |
# |    n_updates        | 988789   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2      |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 970      |
# |    time_elapsed     | 4563     |
# |    total_timesteps  | 4428106  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 1094526  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.85     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 965      |
# |    time_elapsed     | 5025     |
# |    total_timesteps  | 4853897  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0458   |
# |    n_updates        | 1200974  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 968      |
# |    time_elapsed     | 5453     |
# |    total_timesteps  | 5281202  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00492  |
# |    n_updates        | 1307800  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54     |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.459    |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1424     |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 313475   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.21     |
# |    n_updates        | 65868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1186     |
# |    time_elapsed     | 577      |
# |    total_timesteps  | 684963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.63     |
# |    n_updates        | 158740   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1126     |
# |    time_elapsed     | 941      |
# |    total_timesteps  | 1061097  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.528    |
# |    n_updates        | 252774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.29     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1081     |
# |    time_elapsed     | 1384     |
# |    total_timesteps  | 1497943  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 361985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61     |
# |    ep_rew_mean      | -0.42    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.37     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1035     |
# |    time_elapsed     | 1856     |
# |    total_timesteps  | 1922804  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 468200   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.56     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 979      |
# |    time_elapsed     | 2387     |
# |    total_timesteps  | 2338150  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0761   |
# |    n_updates        | 572037   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 986      |
# |    time_elapsed     | 2808     |
# |    total_timesteps  | 2771931  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0905   |
# |    n_updates        | 680482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.93     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.62     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 995      |
# |    time_elapsed     | 3243     |
# |    total_timesteps  | 3228211  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0594   |
# |    n_updates        | 794552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.55     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 993      |
# |    time_elapsed     | 3712     |
# |    total_timesteps  | 3687323  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0874   |
# |    n_updates        | 909330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 997      |
# |    time_elapsed     | 4157     |
# |    total_timesteps  | 4145444  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 1023860  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.53     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 999      |
# |    time_elapsed     | 4604     |
# |    total_timesteps  | 4601843  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0466   |
# |    n_updates        | 1137960  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.35     |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1001     |
# |    time_elapsed     | 5046     |
# |    total_timesteps  | 5055927  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0725   |
# |    n_updates        | 1251481  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.457    |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1488     |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 314400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.65     |
# |    n_updates        | 66099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.51     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1238     |
# |    time_elapsed     | 553      |
# |    total_timesteps  | 685798   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.63     |
# |    n_updates        | 158949   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1116     |
# |    time_elapsed     | 960      |
# |    total_timesteps  | 1072876  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.603    |
# |    n_updates        | 255718   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1044     |
# |    time_elapsed     | 1466     |
# |    total_timesteps  | 1531716  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 370428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.83     |
# |    ep_rew_mean      | -0.22    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.42     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1004     |
# |    time_elapsed     | 1953     |
# |    total_timesteps  | 1960946  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 477736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81     |
# |    ep_rew_mean      | -0.02    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.52     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 870      |
# |    time_elapsed     | 2724     |
# |    total_timesteps  | 2371187  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 580296   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.58     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 799      |
# |    time_elapsed     | 3469     |
# |    total_timesteps  | 2774073  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 681018   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.77     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 795      |
# |    time_elapsed     | 4014     |
# |    total_timesteps  | 3192001  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.078    |
# |    n_updates        | 785500   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.82     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 804      |
# |    time_elapsed     | 4511     |
# |    total_timesteps  | 3629577  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 894894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 823      |
# |    time_elapsed     | 4926     |
# |    total_timesteps  | 4058707  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 1002176  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3      |
# |    ep_rew_mean      | 0.52     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 837      |
# |    time_elapsed     | 5355     |
# |    total_timesteps  | 4486802  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0536   |
# |    n_updates        | 1109200  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 843      |
# |    time_elapsed     | 5832     |
# |    total_timesteps  | 4918491  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 1217122  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.83     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 847      |
# |    time_elapsed     | 6311     |
# |    total_timesteps  | 5347458  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 1324364  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.455    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1501     |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 315792   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.28     |
# |    n_updates        | 66447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1169     |
# |    time_elapsed     | 585      |
# |    total_timesteps  | 684561   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.98     |
# |    n_updates        | 158640   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1091     |
# |    time_elapsed     | 985      |
# |    total_timesteps  | 1075623  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.146    |
# |    n_updates        | 256405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1024     |
# |    time_elapsed     | 1470     |
# |    total_timesteps  | 1506767  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 364191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97     |
# |    ep_rew_mean      | -0.26    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1027     |
# |    time_elapsed     | 1901     |
# |    total_timesteps  | 1953174  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0374   |
# |    n_updates        | 475793   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.65     |
# |    ep_rew_mean      | -0.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.41     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1020     |
# |    time_elapsed     | 2330     |
# |    total_timesteps  | 2378551  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0929   |
# |    n_updates        | 582137   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34     |
# |    ep_rew_mean      | -0.12    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1023     |
# |    time_elapsed     | 2730     |
# |    total_timesteps  | 2796026  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0567   |
# |    n_updates        | 686506   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43     |
# |    ep_rew_mean      | -0.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.55     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1025     |
# |    time_elapsed     | 3152     |
# |    total_timesteps  | 3233380  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 795844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1035     |
# |    time_elapsed     | 3567     |
# |    total_timesteps  | 3693305  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 910826   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.5      |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1042     |
# |    time_elapsed     | 3989     |
# |    total_timesteps  | 4158027  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 1027006  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.74     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.86     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1047     |
# |    time_elapsed     | 4419     |
# |    total_timesteps  | 4627967  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0632   |
# |    n_updates        | 1144491  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.74     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1051     |
# |    time_elapsed     | 4859     |
# |    total_timesteps  | 5107776  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0478   |
# |    n_updates        | 1264443  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77     |
# |    ep_rew_mean      | -0.86    |
# |    exploration_rate | 0.456    |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1612     |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 315152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.41     |
# |    n_updates        | 66287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1351     |
# |    time_elapsed     | 506      |
# |    total_timesteps  | 684331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.13     |
# |    n_updates        | 158582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1253     |
# |    time_elapsed     | 870      |
# |    total_timesteps  | 1090915  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0388   |
# |    n_updates        | 260228   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.61     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.31     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1209     |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 1496837  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0476   |
# |    n_updates        | 361709   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1151     |
# |    time_elapsed     | 1646     |
# |    total_timesteps  | 1894969  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.062    |
# |    n_updates        | 461242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93     |
# |    ep_rew_mean      | -0.28    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.4      |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1133     |
# |    time_elapsed     | 2032     |
# |    total_timesteps  | 2304610  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 563652   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1111     |
# |    time_elapsed     | 2437     |
# |    total_timesteps  | 2709534  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0912   |
# |    n_updates        | 664883   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1111     |
# |    time_elapsed     | 2814     |
# |    total_timesteps  | 3127912  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.153    |
# |    n_updates        | 769477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.85     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1107     |
# |    time_elapsed     | 3196     |
# |    total_timesteps  | 3541727  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 872931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# ...
# |    n_updates        | 1083399  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1089     |
# |    time_elapsed     | 4394     |
# |    total_timesteps  | 4789082  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0357   |
# |    n_updates        | 1184770  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99     |
# |    ep_rew_mean      | 0.64     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.88     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1085     |
# |    time_elapsed     | 4790     |
# |    total_timesteps  | 5197487  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 1286871  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02     |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.454    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1610     |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 316133   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.75     |
# |    n_updates        | 66533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8      |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1331     |
# |    time_elapsed     | 530      |
# |    total_timesteps  | 706038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.74     |
# |    n_updates        | 164009   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1245     |
# |    time_elapsed     | 861      |
# |    total_timesteps  | 1072750  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.789    |
# |    n_updates        | 255687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.72     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.31     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1205     |
# |    time_elapsed     | 1294     |
# |    total_timesteps  | 1560517  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 377629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1165     |
# |    time_elapsed     | 1747     |
# |    total_timesteps  | 2036167  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0603   |
# |    n_updates        | 496541   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1      |
# |    ep_rew_mean      | -0.34    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.39     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1158     |
# |    time_elapsed     | 2134     |
# |    total_timesteps  | 2471974  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.075    |
# |    n_updates        | 605493   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.64     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1144     |
# |    time_elapsed     | 2540     |
# |    total_timesteps  | 2906666  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 714166   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42     |
# |    ep_rew_mean      | 0.38     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1132     |
# |    time_elapsed     | 2946     |
# |    total_timesteps  | 3336291  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 821572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.9      |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 1129     |
# |    time_elapsed     | 3337     |
# |    total_timesteps  | 3769872  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.078    |
# |    n_updates        | 929967   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.79     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 1126     |
# |    time_elapsed     | 3726     |
# |    total_timesteps  | 4199274  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0828   |
# |    n_updates        | 1037318  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39     |
# |    ep_rew_mean      | 0.48     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.84     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 1125     |
# |    time_elapsed     | 4114     |
# |    total_timesteps  | 4628970  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 1144742  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.87     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 1122     |
# |    time_elapsed     | 4510     |
# |    total_timesteps  | 5061296  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 1252823  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.26     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.81     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 1117     |
# |    time_elapsed     | 4913     |
# |    total_timesteps  | 5492141  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 1360535  |
# ----------------------------------
# using stable baselines 3
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62     |
# |    ep_rew_mean      | -0.84    |
# |    exploration_rate | 0.448    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 1532     |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 319363   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.56     |
# |    n_updates        | 67340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 1217     |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 696405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.56     |
# |    n_updates        | 161601   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.51     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 1161     |
# |    time_elapsed     | 934      |
# |    total_timesteps  | 1085385  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 258846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67     |
# |    ep_rew_mean      | -0.48    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.32     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 1130     |
# |    time_elapsed     | 1337     |
# |    total_timesteps  | 1512057  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 365514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.78     |
# |    ep_rew_mean      | -0.2     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.43     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 1129     |
# |    time_elapsed     | 1696     |
# |    total_timesteps  | 1915941  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 466485   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22     |
# |    ep_rew_mean      | -0.3     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.38     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 1122     |
# |    time_elapsed     | 2088     |
# |    total_timesteps  | 2344690  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0925   |
# |    n_updates        | 573672   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83     |
# |    ep_rew_mean      | -0.1     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.48     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 1103     |
# |    time_elapsed     | 2479     |
# |    total_timesteps  | 2736579  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0947   |
# |    n_updates        | 671644   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 1018     |
# |    time_elapsed     | 3070     |
# |    total_timesteps  | 3125964  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0847   |
# |    n_updates        | 768990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.35     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.68     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 937      |
# |    time_elapsed     | 3760     |
# |    total_timesteps  | 3525204  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0986   |
# |    n_updates        | 868800   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.58     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 937      |
# |    time_elapsed     | 4192     |
# |    total_timesteps  | 3930396  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 970098   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.63     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 941      |
# |    time_elapsed     | 4605     |
# |    total_timesteps  | 4334231  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 1071057  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 941      |
# |    time_elapsed     | 5036     |
# |    total_timesteps  | 4739809  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0761   |
# |    n_updates        | 1172452  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.52     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.76     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 957      |
# |    time_elapsed     | 5382     |
# |    total_timesteps  | 5154580  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.069    |
# |    n_updates        | 1276144  |
# ----------------------------------

# %%
c =  [   94.336,
92.893,
95.029,
88.507,
72.75,


]
np.mean(c), np.std(c)
# Out:
# (88.703, 8.292667725165407)

# %%
print('$I am Weasel $')
# Out:
# $I am Weasel $
