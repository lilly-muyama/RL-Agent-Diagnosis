# %%
import pandas as pd
import numpy as np
import random
import os
import torch
import sys
sys.path.append('../')
from lillian_modules import utils, simple_constants
from lillian_modules.simple_env import SimpleEnv
from stable_baselines3.dqn import DQN
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import ClusterCentroids, RandomUnderSampler
import warnings
warnings.filterwarnings('ignore')

# %%
SEED = simple_constants.SEED
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %%
class_dict = simple_constants.CLASS_DICT

# %%
# frac=0.5

# %% [markdown]
# #### The data

# %%
# def balance_dataframe(df):
#     target_num = df.label.value_counts().min()
#     sample_amounts = {0: target_num, 1:target_num}

#     s = (df.groupby('label').apply(lambda g: g.sample(n=sample_amounts[g.name], 
#                                                       replace=len(g) < sample_amounts[g.name])
#                                   ).reset_index(drop=True))
#     return s

# %%
# df = pd.read_csv('../../RL-Agent-Diagnosis/lupus/data/orig/lupus_dataset.csv')
# df = pd.read_csv('../../RL-Agent-Diagnosis/lupus/data/very_simple_datasets/feats_8.csv')
# df.head()

# %%
# df.label.value_counts()

# %%
# df['label'] = df['label'].replace(class_dict)
# # print(df.label.value_counts())
# X = df.iloc[:, 0:-1]
# y = df.iloc[:, -1]

# X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=SEED)
# X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.10, stratify=y_train_val, random_state=SEED)
# training_df = pd.concat([X_train, y_train], axis=1).reset_index(drop=True)
# validation_df = pd.concat([X_val, y_val], axis=1).reset_index(drop=True)
# testing_df = pd.concat([X_test, y_test], axis=1).reset_index(drop=True)
training_df = pd.read_csv('../../RL-Agent-Diagnosis/lupus/data/missingness/0/training_set.csv')
validation_df = pd.read_csv('../../RL-Agent-Diagnosis/lupus/data/missingness/0/validation_set.csv')
testing_df = pd.read_csv('../../RL-Agent-Diagnosis/lupus/data/missingness/0/testing_set.csv')
# training_df = pd.read_csv(f'../../RL-Agent-Diagnosis/lupus/data/noisiness/{frac}/training_set.csv')
# validation_df = pd.read_csv(f'../../RL-Agent-Diagnosis/lupus/data/noisiness/{frac}/validation_set.csv')
# testing_df = pd.read_csv(f'../../RL-Agent-Diagnosis/lupus/data/noisiness/{frac}/testing_set.csv')
training_df = training_df.fillna(-1)
X_train, y_train = training_df.iloc[:, 0:-1], training_df.iloc[:, -1]
X_val, y_val = validation_df.iloc[:, 0:-1], validation_df.iloc[:, -1]
X_test, y_test = testing_df.iloc[:, 0:-1], testing_df.iloc[:, -1]
# y = df.iloc[:, -1]
X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((50400, 23), (5600, 23), (14000, 23), (50400,), (5600,), (14000,))

# %%
testing_df.isna().sum()
# Out:
# ana                             0
# fever                           0
# leukopenia                      0
# thrombocytopenia                0
# auto_immune_hemolysis           0
# delirium                        0
# psychosis                       0
# seizure                         0
# non_scarring_alopecia           0
# oral_ulcers                     0
# cutaneous_lupus                 0
# pleural_effusion                0
# pericardial_effusion            0
# acute_pericarditis              0
# joint_involvement               0
# proteinuria                     0
# anti_cardioliphin_antibodies    0
# anti_β2gp1_antibodies           0
# lupus_anti_coagulant            0
# low_c3                          0
# low_c4                          0
# anti_dsdna_antibody             0
# anti_smith_antibody             0
# label                           0
# dtype: int64

# %%
unique, counts = np.unique(y_train, return_counts=True)
unique, counts
# Out:
# (array([0, 1]), array([26203, 24197]))

# %%
# len(balanced_training_df[(balanced_training_df.ana==1) & (balanced_training_df.label==0)])

# %%
len(validation_df[(validation_df.ana==1) &(validation_df.label==0)])
# Out:
# 1265

# %%
# len(balanced_training_df)

# %% [markdown]
# #### Training the model

# %%
def stable_dqn3(X_train, y_train, timesteps, validation_times=10, folder_name=None):
    training_env = SimpleEnv(X_train, y_train)
    print(f'ACTION SPACE: {training_env.actions}')
    model = DQN(policy='MlpPolicy', env=training_env, verbose=1, seed=SEED, X_val=X_val, y_val=y_val, 
                to_save_folder=folder_name)
    model.learn(total_timesteps=timesteps, validation_times=validation_times, log_interval=100000)
#     if save:
#         model.save(filename)
    training_env.close()
    return model

# %%
ft_num = 23
steps = 70000000

# for steps in [int(6e6)]:
# for steps in [int()]:
model = stable_dqn3(X_train, y_train, timesteps=steps, validation_times=700,
                    folder_name=f'../models/very_simple_models/negative_step_reward/unbalanced/14_03_23/')
# val_df.to_csv(f'../test_dfs/val_df_ft_{ft_num}_{steps}', index=False)
#     stable_dqn3(X_train, y_train, steps)
# Out:
# ACTION SPACE: ['No lupus', 'Lupus', 'Inconclusive diagnosis', 'ana', 'fever', 'leukopenia', 'thrombocytopenia', 'auto_immune_hemolysis', 'delirium', 'psychosis', 'seizure', 'non_scarring_alopecia', 'oral_ulcers', 'cutaneous_lupus', 'pleural_effusion', 'pericardial_effusion', 'acute_pericarditis', 'joint_involvement', 'proteinuria', 'anti_cardioliphin_antibodies', 'anti_β2gp1_antibodies', 'lupus_anti_coagulant', 'low_c3', 'low_c4', 'anti_dsdna_antibody', 'anti_smith_antibody']
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# setting up model
# Validating at 100000/70000000
# Validating at 200000/70000000
# Validating at 300000/70000000
# Validating at 400000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.64     |
# |    ep_rew_mean      | -3.74    |
# |    exploration_rate | 0.936    |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 2616     |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 473514   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 105878   |
# ----------------------------------
# Validating at 500000/70000000
# Validating at 600000/70000000
# Validating at 700000/70000000
# Validating at 800000/70000000
# Validating at 900000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.44     |
# |    ep_rew_mean      | -3.49    |
# |    exploration_rate | 0.869    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 2396     |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 968089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45     |
# |    n_updates        | 229522   |
# ----------------------------------
# Validating at 1000000/70000000
# Validating at 1100000/70000000
# Validating at 1200000/70000000
# Validating at 1300000/70000000
# Validating at 1400000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.5      |
# |    ep_rew_mean      | -3.58    |
# |    exploration_rate | 0.798    |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 2332     |
# |    time_elapsed     | 638      |
# |    total_timesteps  | 1489055  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.96     |
# |    n_updates        | 359763   |
# ----------------------------------
# Validating at 1500000/70000000
# Validating at 1600000/70000000
# Validating at 1700000/70000000
# Validating at 1800000/70000000
# Validating at 1900000/70000000
# Validating at 2000000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.57     |
# |    ep_rew_mean      | -4.18    |
# |    exploration_rate | 0.723    |
# |    success_rate     | 0.14     |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 2262     |
# |    time_elapsed     | 901      |
# |    total_timesteps  | 2039266  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.59     |
# |    n_updates        | 497316   |
# ----------------------------------
# Validating at 2100000/70000000
# Validating at 2200000/70000000
# Validating at 2300000/70000000
# Validating at 2400000/70000000
# Validating at 2500000/70000000
# Validating at 2600000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.33     |
# |    ep_rew_mean      | -2.48    |
# |    exploration_rate | 0.643    |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 2229     |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 2632165  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56     |
# |    n_updates        | 645541   |
# ----------------------------------
# Validating at 2700000/70000000
# Validating at 2800000/70000000
# Validating at 2900000/70000000
# Validating at 3000000/70000000
# Validating at 3100000/70000000
# Validating at 3200000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.65     |
# |    ep_rew_mean      | -3.29    |
# |    exploration_rate | 0.556    |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 2212     |
# |    time_elapsed     | 1479     |
# |    total_timesteps  | 3272318  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 805579   |
# ----------------------------------
# Validating at 3300000/70000000
# Validating at 3400000/70000000
# Validating at 3500000/70000000
# Validating at 3600000/70000000
# Validating at 3700000/70000000
# Validating at 3800000/70000000
# Validating at 3900000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.79     |
# |    ep_rew_mean      | -3.62    |
# |    exploration_rate | 0.46     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 2185     |
# |    time_elapsed     | 1821     |
# |    total_timesteps  | 3979610  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 982402   |
# ----------------------------------
# Validating at 4000000/70000000
# Validating at 4100000/70000000
# Validating at 4200000/70000000
# Validating at 4300000/70000000
# Validating at 4400000/70000000
# Validating at 4500000/70000000
# Validating at 4600000/70000000
# Validating at 4700000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.59     |
# |    ep_rew_mean      | -2.92    |
# |    exploration_rate | 0.35     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 2158     |
# |    time_elapsed     | 2219     |
# |    total_timesteps  | 4789998  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.668    |
# |    n_updates        | 1184999  |
# ----------------------------------
# Validating at 4800000/70000000
# Validating at 4900000/70000000
# Validating at 5000000/70000000
# Validating at 5100000/70000000
# Validating at 5200000/70000000
# Validating at 5300000/70000000
# Validating at 5400000/70000000
# Validating at 5500000/70000000
# Validating at 5600000/70000000
# Validating at 5700000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | -2.76    |
# |    exploration_rate | 0.217    |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 2132     |
# |    time_elapsed     | 2707     |
# |    total_timesteps  | 5772871  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.064    |
# |    n_updates        | 1430717  |
# ----------------------------------
# Validating at 5800000/70000000
# Validating at 5900000/70000000
# Validating at 6000000/70000000
# Validating at 6100000/70000000
# Validating at 6200000/70000000
# Validating at 6300000/70000000
# Validating at 6400000/70000000
# Validating at 6500000/70000000
# Validating at 6600000/70000000
# Validating at 6700000/70000000
# Validating at 6800000/70000000
# Validating at 6900000/70000000
# Validating at 7000000/70000000
# Validating at 7100000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | -1.97    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.39     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 2098     |
# |    time_elapsed     | 3394     |
# |    total_timesteps  | 7123535  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 1768383  |
# ----------------------------------
# Validating at 7200000/70000000
# Validating at 7300000/70000000
# Validating at 7400000/70000000
# Validating at 7500000/70000000
# Validating at 7600000/70000000
# Validating at 7700000/70000000
# Validating at 7800000/70000000
# Validating at 7900000/70000000
# Validating at 8000000/70000000
# Validating at 8100000/70000000
# Validating at 8200000/70000000
# Validating at 8300000/70000000
# Validating at 8400000/70000000
# Validating at 8500000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | -2.03    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.57     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 2085     |
# |    time_elapsed     | 4107     |
# |    total_timesteps  | 8564977  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 2128744  |
# ----------------------------------
# Validating at 8600000/70000000
# Validating at 8700000/70000000
# Validating at 8800000/70000000
# Validating at 8900000/70000000
# Validating at 9000000/70000000
# Validating at 9100000/70000000
# Validating at 9200000/70000000
# Validating at 9300000/70000000
# Validating at 9400000/70000000
# Validating at 9500000/70000000
# Validating at 9600000/70000000
# Validating at 9700000/70000000
# Validating at 9800000/70000000
# Validating at 9900000/70000000
# Validating at 10000000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | -2.33    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.6      |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 2074     |
# |    time_elapsed     | 4843     |
# |    total_timesteps  | 10049812 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 2499952  |
# ----------------------------------
# Validating at 10100000/70000000
# Validating at 10200000/70000000
# Validating at 10300000/70000000
# Validating at 10400000/70000000
# Validating at 10500000/70000000
# Validating at 10600000/70000000
# Validating at 10700000/70000000
# Validating at 10800000/70000000
# Validating at 10900000/70000000
# Validating at 11000000/70000000
# Validating at 11100000/70000000
# Validating at 11200000/70000000
# Validating at 11300000/70000000
# Validating at 11400000/70000000
# Validating at 11500000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | -1.26    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.69     |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 2065     |
# |    time_elapsed     | 5587     |
# |    total_timesteps  | 11543486 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 2873371  |
# ----------------------------------
# Validating at 11600000/70000000
# Validating at 11700000/70000000
# Validating at 11800000/70000000
# Validating at 11900000/70000000
# Validating at 12000000/70000000
# Validating at 12100000/70000000
# Validating at 12200000/70000000
# Validating at 12300000/70000000
# Validating at 12400000/70000000
# Validating at 12500000/70000000
# Validating at 12600000/70000000
# Validating at 12700000/70000000
# Validating at 12800000/70000000
# Validating at 12900000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | -1.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.59     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 2062     |
# |    time_elapsed     | 6284     |
# |    total_timesteps  | 12959004 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00836  |
# |    n_updates        | 3227250  |
# ----------------------------------
# Validating at 13000000/70000000
# Validating at 13100000/70000000
# Validating at 13200000/70000000
# Validating at 13300000/70000000
# Validating at 13400000/70000000
# Validating at 13500000/70000000
# Validating at 13600000/70000000
# Validating at 13700000/70000000
# Validating at 13800000/70000000
# Validating at 13900000/70000000
# Validating at 14000000/70000000
# Validating at 14100000/70000000
# Validating at 14200000/70000000
# Validating at 14300000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | -1.14    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.69     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 2057     |
# |    time_elapsed     | 6958     |
# |    total_timesteps  | 14319530 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.403    |
# |    n_updates        | 3567382  |
# ----------------------------------
# Validating at 14400000/70000000
# Validating at 14500000/70000000
# Validating at 14600000/70000000
# Validating at 14700000/70000000
# Validating at 14800000/70000000
# Validating at 14900000/70000000
# Validating at 15000000/70000000
# Validating at 15100000/70000000
# Validating at 15200000/70000000
# Validating at 15300000/70000000
# Validating at 15400000/70000000
# Validating at 15500000/70000000
# Validating at 15600000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | -1.25    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.66     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 2056     |
# |    time_elapsed     | 7591     |
# |    total_timesteps  | 15612629 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00459  |
# |    n_updates        | 3890657  |
# ----------------------------------
# Validating at 15700000/70000000
# Validating at 15800000/70000000
# Validating at 15900000/70000000
# Validating at 16000000/70000000
# Validating at 16100000/70000000
# Validating at 16200000/70000000
# Validating at 16300000/70000000
# Validating at 16400000/70000000
# Validating at 16500000/70000000
# Validating at 16600000/70000000
# Validating at 16700000/70000000
# Validating at 16800000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | -0.906   |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.7      |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 2057     |
# |    time_elapsed     | 8187     |
# |    total_timesteps  | 16844716 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00619  |
# |    n_updates        | 4198678  |
# ----------------------------------
# Validating at 16900000/70000000
# Validating at 17000000/70000000
# Validating at 17100000/70000000
# Validating at 17200000/70000000
# Validating at 17300000/70000000
# Validating at 17400000/70000000
# Validating at 17500000/70000000
# Validating at 17600000/70000000
# Validating at 17700000/70000000
# Validating at 17800000/70000000
# Validating at 17900000/70000000
# Validating at 18000000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | -1.04    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.67     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 2058     |
# |    time_elapsed     | 8763     |
# |    total_timesteps  | 18039511 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00733  |
# |    n_updates        | 4497377  |
# ----------------------------------
# Validating at 18100000/70000000
# Validating at 18200000/70000000
# Validating at 18300000/70000000
# Validating at 18400000/70000000
# Validating at 18500000/70000000
# Validating at 18600000/70000000
# Validating at 18700000/70000000
# Validating at 18800000/70000000
# Validating at 18900000/70000000
# Validating at 19000000/70000000
# Validating at 19100000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.73     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 2060     |
# |    time_elapsed     | 9317     |
# |    total_timesteps  | 19196025 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0717   |
# |    n_updates        | 4786506  |
# ----------------------------------
# Validating at 19200000/70000000
# Validating at 19300000/70000000
# Validating at 19400000/70000000
# Validating at 19500000/70000000
# Validating at 19600000/70000000
# Validating at 19700000/70000000
# Validating at 19800000/70000000
# Validating at 19900000/70000000
# Validating at 20000000/70000000
# Validating at 20100000/70000000
# Validating at 20200000/70000000
# Validating at 20300000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | -1.24    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 2058     |
# |    time_elapsed     | 9866     |
# |    total_timesteps  | 20314796 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 5066198  |
# ----------------------------------
# Validating at 20400000/70000000
# Validating at 20500000/70000000
# Validating at 20600000/70000000
# Validating at 20700000/70000000
# Validating at 20800000/70000000
# Validating at 20900000/70000000
# Validating at 21000000/70000000
# Validating at 21100000/70000000
# Validating at 21200000/70000000
# Validating at 21300000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | -1.08    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.72     |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 2061     |
# |    time_elapsed     | 10370    |
# |    total_timesteps  | 21382104 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.306    |
# |    n_updates        | 5333025  |
# ----------------------------------
# Validating at 21400000/70000000
# Validating at 21500000/70000000
# Validating at 21600000/70000000
# Validating at 21700000/70000000
# Validating at 21800000/70000000
# Validating at 21900000/70000000
# Validating at 22000000/70000000
# Validating at 22100000/70000000
# Validating at 22200000/70000000
# Validating at 22300000/70000000
# Validating at 22400000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | -1.15    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.73     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 2061     |
# |    time_elapsed     | 10885    |
# |    total_timesteps  | 22434798 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 5596199  |
# ----------------------------------
# Validating at 22500000/70000000
# Validating at 22600000/70000000
# Validating at 22700000/70000000
# Validating at 22800000/70000000
# Validating at 22900000/70000000
# Validating at 23000000/70000000
# Validating at 23100000/70000000
# Validating at 23200000/70000000
# Validating at 23300000/70000000
# Validating at 23400000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | -1.35    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.71     |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 2063     |
# |    time_elapsed     | 11375    |
# |    total_timesteps  | 23470359 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00622  |
# |    n_updates        | 5855089  |
# ----------------------------------
# Validating at 23500000/70000000
# Validating at 23600000/70000000
# Validating at 23700000/70000000
# Validating at 23800000/70000000
# Validating at 23900000/70000000
# Validating at 24000000/70000000
# Validating at 24100000/70000000
# Validating at 24200000/70000000
# Validating at 24300000/70000000
# Validating at 24400000/70000000
# Validating at 24500000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | -0.799   |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.73     |
# | time/               |          |
# |    episodes         | 2400000  |
# |    fps              | 2063     |
# |    time_elapsed     | 11890    |
# |    total_timesteps  | 24534645 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00814  |
# |    n_updates        | 6121161  |
# ----------------------------------
# Validating at 24600000/70000000
# Validating at 24700000/70000000
# Validating at 24800000/70000000
# Validating at 24900000/70000000
# Validating at 25000000/70000000
# Validating at 25100000/70000000
# Validating at 25200000/70000000
# Validating at 25300000/70000000
# Validating at 25400000/70000000
# Validating at 25500000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | -0.722   |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.76     |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 2057     |
# |    time_elapsed     | 12437    |
# |    total_timesteps  | 25585090 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0061   |
# |    n_updates        | 6383772  |
# ----------------------------------
# Validating at 25600000/70000000
# Validating at 25700000/70000000
# Validating at 25800000/70000000
# Validating at 25900000/70000000
# Validating at 26000000/70000000
# Validating at 26100000/70000000
# Validating at 26200000/70000000
# Validating at 26300000/70000000
# Validating at 26400000/70000000
# Validating at 26500000/70000000
# Validating at 26600000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.22     |
# |    ep_rew_mean      | -1.47    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.69     |
# | time/               |          |
# |    episodes         | 2600000  |
# |    fps              | 2036     |
# |    time_elapsed     | 13080    |
# |    total_timesteps  | 26638862 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 6647215  |
# ----------------------------------
# Validating at 26700000/70000000
# Validating at 26800000/70000000
# Validating at 26900000/70000000
# Validating at 27000000/70000000
# Validating at 27100000/70000000
# Validating at 27200000/70000000
# Validating at 27300000/70000000
# Validating at 27400000/70000000
# Validating at 27500000/70000000
# Validating at 27600000/70000000
# Validating at 27700000/70000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | -1.42    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.74     |
# | time/               |          |
# |    episodes         | 2700000  |
# |    fps              | 1988     |
# |    time_elapsed     | 13936    |
# |    total_timesteps  | 27713594 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00305  |
# |    n_updates        | 6915898  |
# ----------------------------------
# Validating at 27800000/70000000
# Validating at 27900000/70000000
# Validating at 28000000/70000000

# %%
# model = utils.load_dqn3('../models/very_simple_models/negative_step_reward/unbalanced/23_ft_incorr_0_corr_100/best_roc_auc_model.zip')

# %%
# timesteps = 1000000
# ft_num = 8
# training_env = SimpleEnv(X_train, y_train)
# # training_env = LupusEnv(X_train, y_train)
# # model = DQN('MlpPolicy', training_env, verbose=1, seed=SEED, learning_rate=0.00001)
# model = DQN('MlpPolicy', training_env, verbose=1, seed=simple_constants.SEED)
# model.learn(total_timesteps=timesteps, log_interval=100000)
# # model.save(f'../models/very_simple_models/reward_shaping/dqn_fts_{ft_num}_{timesteps}')
# training_env.close()

# %% [markdown]
# #### Testing the model

# %%
# test_df = pd.DataFrame()
# testing_env = SimpleEnv(X_test, y_test, random=False)
# # testing_env = LupusEnv(X_test, y_test, random=False)
# count = 0
# try:
#     while True:
#         count += 1
#         if count %(len(X_test)/5)==0:
#             print(f'Count: {count}')
#         obs, done = testing_env.reset(), False
#         while not done:
#             action, states = model.predict(obs, deterministic=True)
#             obs, rew, done, info = testing_env.step(action)
#             if done==True:
#                 test_df = test_df.append(info, ignore_index=True)
# except StopIteration:
#     print('Testing done ....')
# test_df.head()

# %% [markdown]
# ## test_df.episode_length.min(), test_df.episode_length.max()

# %%
success_rate, success_df = utils.success_rate(test_df)
success_rate

# %%
avg_length, avg_return = utils.get_avg_length_reward(test_df)
avg_length, avg_return

# %%
acc, f1, roc_auc = utils.test(test_df['y_actual'], test_df['y_pred'])
acc, f1, roc_auc

# %%
# test_df.to_csv('../../RL-Agent-Diagnosis/lupus/test_dfs/noisiness/0.5.csv', index=False)

# %%
a = -1
b = np.nan

# %%
if b > a:
    print('yes')
else:
    print('no')

# %%
c = b*100
c
