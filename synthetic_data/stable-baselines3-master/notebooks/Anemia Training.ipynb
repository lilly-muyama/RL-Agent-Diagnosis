# %%
import pandas as pd
import numpy as np
from datetime import datetime
import random
import os
import torch
import sys
sys.path.append('../')
from lillian_modules import utils, constants
from lillian_modules.env import AnemiaEnv
from stable_baselines3.dqn import DQN
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
SEED = constants.SEED
random.seed(SEED)
np.random.seed(SEED)
os.environ['PYTHONHASHSEED']=str(SEED)
torch.manual_seed(SEED)
torch.use_deterministic_algorithms(True)

# %% [markdown]
# #### The data

# %%
training_df = pd.read_csv('../data/training_noisiness_0.1.csv')
validation_df = pd.read_csv('../data/validation_set.csv')
testing_df = pd.read_csv('../data/testing_set.csv')
training_df = training_df.fillna(-1)
X_train, y_train = training_df.iloc[:, 0:-1], training_df.iloc[:, -1]
X_val, y_val = validation_df.iloc[:, 0:-1], validation_df.iloc[:, -1]
X_test, y_test = testing_df.iloc[:, 0:-1], testing_df.iloc[:, -1]
X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((50400, 17), (5600, 17), (14000, 17), (50400,), (5600,), (14000,))

# %%
action_list = list(constants.CLASS_DICT.keys()) + [col  for col in training_df.columns if col!='label']
action_list
# Out:
# ['No anemia',
#  'Vitamin B12/Folate deficiency anemia',
#  'Unspecified anemia',
#  'Anemia of chronic disease',
#  'Iron deficiency anemia',
#  'Hemolytic anemia',
#  'Aplastic anemia',
#  'Inconclusive diagnosis',
#  'hemoglobin',
#  'ferritin',
#  'ret_count',
#  'segmented_neutrophils',
#  'tibc',
#  'mcv',
#  'serum_iron',
#  'rbc',
#  'gender',
#  'creatinine',
#  'cholestrol',
#  'copper',
#  'ethanol',
#  'folate',
#  'glucose',
#  'hematocrit',
#  'tsat']

# %% [markdown]
# #### Training

# %%
def stable_dqn3(X_train, y_train, timesteps, validation_times=10, folder_name=None):
    training_env = AnemiaEnv(X_train, y_train)
    print(f'ACTION SPACE: {training_env.actions}')
    model = DQN(policy='MlpPolicy', env=training_env, verbose=1, seed=SEED, X_val=X_val, y_val=y_val, 
                to_save_folder=folder_name)
    model.learn(total_timesteps=timesteps, validation_times=validation_times, log_interval=100000)
#     if save:
#         model.save(filename)
    training_env.close()
    return model

# %%
ft_num = 17
steps = 30000000

# for steps in [int(6e6)]:
# for steps in [int()]:
model = stable_dqn3(X_train, y_train, timesteps=steps, validation_times=300, folder_name=f'../models/noisiness_0.1')
# val_df.to_csv(f'../test_dfs/val_df_ft_{ft_num}_{steps}', index=False)
#     stable_dqn3(X_train, y_train, steps)
# Out:
# ACTION SPACE: ['No anemia', 'Vitamin B12/Folate deficiency anemia', 'Unspecified anemia', 'Anemia of chronic disease', 'Iron deficiency anemia', 'Hemolytic anemia', 'Aplastic anemia', 'Inconclusive diagnosis', 'hemoglobin', 'ferritin', 'ret_count', 'segmented_neutrophils', 'tibc', 'mcv', 'serum_iron', 'rbc', 'gender', 'creatinine', 'cholestrol', 'copper', 'ethanol', 'folate', 'glucose', 'hematocrit', 'tsat']
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# setting up model
# Validating at 100000/30000000
# Validating at 200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1      |
# |    ep_rew_mean      | -0.82    |
# |    exploration_rate | 0.913    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 2721     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 274696   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.7     |
# |    n_updates        | 56173    |
# ----------------------------------
# Validating at 300000/30000000
# Validating at 400000/30000000
# Validating at 500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09     |
# |    ep_rew_mean      | -0.78    |
# |    exploration_rate | 0.82     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 200000   |
# |    fps              | 2483     |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 569235   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 134      |
# |    n_updates        | 129808   |
# ----------------------------------
# Validating at 600000/30000000
# Validating at 700000/30000000
# Validating at 800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.722    |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 300000   |
# |    fps              | 2429     |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 876484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.3e+04  |
# |    n_updates        | 206620   |
# ----------------------------------
# Validating at 900000/30000000
# Validating at 1000000/30000000
# Validating at 1100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.42     |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.628    |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 400000   |
# |    fps              | 2395     |
# |    time_elapsed     | 490      |
# |    total_timesteps  | 1174765  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27e+06 |
# |    n_updates        | 281191   |
# ----------------------------------
# Validating at 1200000/30000000
# Validating at 1300000/30000000
# Validating at 1400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.88     |
# |    ep_rew_mean      | -0.9     |
# |    exploration_rate | 0.536    |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 500000   |
# |    fps              | 2322     |
# |    time_elapsed     | 631      |
# |    total_timesteps  | 1465795  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.49e+06 |
# |    n_updates        | 353948   |
# ----------------------------------
# Validating at 1500000/30000000
# Validating at 1600000/30000000
# Validating at 1700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09     |
# |    ep_rew_mean      | -0.88    |
# |    exploration_rate | 0.45     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 600000   |
# |    fps              | 2268     |
# |    time_elapsed     | 765      |
# |    total_timesteps  | 1736989  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39e+07 |
# |    n_updates        | 421747   |
# ----------------------------------
# Validating at 1800000/30000000
# Validating at 1900000/30000000
# Validating at 2000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.53     |
# |    ep_rew_mean      | -0.92    |
# |    exploration_rate | 0.363    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 700000   |
# |    fps              | 2222     |
# |    time_elapsed     | 905      |
# |    total_timesteps  | 2011242  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56e+07 |
# |    n_updates        | 490310   |
# ----------------------------------
# Validating at 2100000/30000000
# Validating at 2200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.282    |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 800000   |
# |    fps              | 2189     |
# |    time_elapsed     | 1035     |
# |    total_timesteps  | 2266754  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.58e+05 |
# |    n_updates        | 554188   |
# ----------------------------------
# Validating at 2300000/30000000
# Validating at 2400000/30000000
# Validating at 2500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.2      |
# |    success_rate     | 0.03     |
# | time/               |          |
# |    episodes         | 900000   |
# |    fps              | 2146     |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 2527722  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03e+07 |
# |    n_updates        | 619430   |
# ----------------------------------
# Validating at 2600000/30000000
# Validating at 2700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.61     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.118    |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 1000000  |
# |    fps              | 2124     |
# |    time_elapsed     | 1310     |
# |    total_timesteps  | 2785600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1e+07  |
# |    n_updates        | 683899   |
# ----------------------------------
# Validating at 2800000/30000000
# Validating at 2900000/30000000
# Validating at 3000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 1100000  |
# |    fps              | 2086     |
# |    time_elapsed     | 1456     |
# |    total_timesteps  | 3039743  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39e+07 |
# |    n_updates        | 747435   |
# ----------------------------------
# Validating at 3100000/30000000
# Validating at 3200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.3      |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 1200000  |
# |    fps              | 2068     |
# |    time_elapsed     | 1593     |
# |    total_timesteps  | 3294851  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.94e+06 |
# |    n_updates        | 811212   |
# ----------------------------------
# Validating at 3300000/30000000
# Validating at 3400000/30000000
# Validating at 3500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5      |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 1300000  |
# |    fps              | 2042     |
# |    time_elapsed     | 1745     |
# |    total_timesteps  | 3564210  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.38e+06 |
# |    n_updates        | 878552   |
# ----------------------------------
# Validating at 3600000/30000000
# Validating at 3700000/30000000
# Validating at 3800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 1400000  |
# |    fps              | 2024     |
# |    time_elapsed     | 1896     |
# |    total_timesteps  | 3839107  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.83e+05 |
# |    n_updates        | 947276   |
# ----------------------------------
# Validating at 3900000/30000000
# Validating at 4000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.07     |
# | time/               |          |
# |    episodes         | 1500000  |
# |    fps              | 2011     |
# |    time_elapsed     | 2035     |
# |    total_timesteps  | 4093012  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.58e+05 |
# |    n_updates        | 1010752  |
# ----------------------------------
# Validating at 4100000/30000000
# Validating at 4200000/30000000
# Validating at 4300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.55     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 1600000  |
# |    fps              | 1991     |
# |    time_elapsed     | 2184     |
# |    total_timesteps  | 4350564  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34e+06 |
# |    n_updates        | 1075140  |
# ----------------------------------
# Validating at 4400000/30000000
# Validating at 4500000/30000000
# Validating at 4600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.06     |
# | time/               |          |
# |    episodes         | 1700000  |
# |    fps              | 1979     |
# |    time_elapsed     | 2324     |
# |    total_timesteps  | 4600876  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.65e+06 |
# |    n_updates        | 1137718  |
# ----------------------------------
# Validating at 4700000/30000000
# Validating at 4800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41     |
# |    ep_rew_mean      | -0.96    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.11     |
# | time/               |          |
# |    episodes         | 1800000  |
# |    fps              | 1979     |
# |    time_elapsed     | 2450     |
# |    total_timesteps  | 4850787  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49e+06 |
# |    n_updates        | 1200196  |
# ----------------------------------
# Validating at 4900000/30000000
# Validating at 5000000/30000000
# Validating at 5100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 1900000  |
# |    fps              | 1972     |
# |    time_elapsed     | 2591     |
# |    total_timesteps  | 5112993  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.52e+04 |
# |    n_updates        | 1265748  |
# ----------------------------------
# Validating at 5200000/30000000
# Validating at 5300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 2000000  |
# |    fps              | 1967     |
# |    time_elapsed     | 2712     |
# |    total_timesteps  | 5337168  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 20.2     |
# |    n_updates        | 1321791  |
# ----------------------------------
# Validating at 5400000/30000000
# Validating at 5500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.47     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 2100000  |
# |    fps              | 1964     |
# |    time_elapsed     | 2822     |
# |    total_timesteps  | 5544330  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.03     |
# |    n_updates        | 1373582  |
# ----------------------------------
# Validating at 5600000/30000000
# Validating at 5700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.08     |
# | time/               |          |
# |    episodes         | 2200000  |
# |    fps              | 1956     |
# |    time_elapsed     | 2956     |
# |    total_timesteps  | 5785212  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.82     |
# |    n_updates        | 1433802  |
# ----------------------------------
# Validating at 5800000/30000000
# Validating at 5900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1      |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 2300000  |
# |    fps              | 1947     |
# |    time_elapsed     | 3076     |
# |    total_timesteps  | 5990120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 1485029  |
# ----------------------------------
# Validating at 6000000/30000000
# Validating at 6100000/30000000
# Validating at 6200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02     |
# |    ep_rew_mean      | -0.98    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 2400000  |
# |    fps              | 1935     |
# |    time_elapsed     | 3204     |
# |    total_timesteps  | 6201762  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 1537940  |
# ----------------------------------
# Validating at 6300000/30000000
# Validating at 6400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.12     |
# | time/               |          |
# |    episodes         | 2500000  |
# |    fps              | 1925     |
# |    time_elapsed     | 3327     |
# |    total_timesteps  | 6406779  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 1589194  |
# ----------------------------------
# Validating at 6500000/30000000
# Validating at 6600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07     |
# |    ep_rew_mean      | -1       |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 2600000  |
# |    fps              | 1918     |
# |    time_elapsed     | 3446     |
# |    total_timesteps  | 6611889  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.168    |
# |    n_updates        | 1640472  |
# ----------------------------------
# Validating at 6700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -0.44    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.28     |
# | time/               |          |
# |    episodes         | 2700000  |
# |    fps              | 1913     |
# |    time_elapsed     | 3536     |
# |    total_timesteps  | 6767153  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0771   |
# |    n_updates        | 1679288  |
# ----------------------------------
# Validating at 6800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.32    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.34     |
# | time/               |          |
# |    episodes         | 2800000  |
# |    fps              | 1909     |
# |    time_elapsed     | 3601     |
# |    total_timesteps  | 6877609  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0878   |
# |    n_updates        | 1706902  |
# ----------------------------------
# Validating at 6900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.48    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.26     |
# | time/               |          |
# |    episodes         | 2900000  |
# |    fps              | 1905     |
# |    time_elapsed     | 3663     |
# |    total_timesteps  | 6981409  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0598   |
# |    n_updates        | 1732852  |
# ----------------------------------
# Validating at 7000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 3000000  |
# |    fps              | 1901     |
# |    time_elapsed     | 3725     |
# |    total_timesteps  | 7085033  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 1758758  |
# ----------------------------------
# Validating at 7100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 3100000  |
# |    fps              | 1899     |
# |    time_elapsed     | 3785     |
# |    total_timesteps  | 7189075  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.322    |
# |    n_updates        | 1784768  |
# ----------------------------------
# Validating at 7200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 3200000  |
# |    fps              | 1896     |
# |    time_elapsed     | 3846     |
# |    total_timesteps  | 7294052  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 1811012  |
# ----------------------------------
# Validating at 7300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.12     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 3300000  |
# |    fps              | 1894     |
# |    time_elapsed     | 3905     |
# |    total_timesteps  | 7398258  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.396    |
# |    n_updates        | 1837064  |
# ----------------------------------
# Validating at 7400000/30000000
# Validating at 7500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 3400000  |
# |    fps              | 1888     |
# |    time_elapsed     | 3973     |
# |    total_timesteps  | 7502935  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.218    |
# |    n_updates        | 1863233  |
# ----------------------------------
# Validating at 7600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 3500000  |
# |    fps              | 1886     |
# |    time_elapsed     | 4032     |
# |    total_timesteps  | 7607354  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.182    |
# |    n_updates        | 1889338  |
# ----------------------------------
# Validating at 7700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 3600000  |
# |    fps              | 1885     |
# |    time_elapsed     | 4091     |
# |    total_timesteps  | 7712733  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.3      |
# |    n_updates        | 1915683  |
# ----------------------------------
# Validating at 7800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 3700000  |
# |    fps              | 1883     |
# |    time_elapsed     | 4151     |
# |    total_timesteps  | 7816994  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.223    |
# |    n_updates        | 1941748  |
# ----------------------------------
# Validating at 7900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 3800000  |
# |    fps              | 1882     |
# |    time_elapsed     | 4208     |
# |    total_timesteps  | 7921230  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 1967807  |
# ----------------------------------
# Validating at 8000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 3900000  |
# |    fps              | 1881     |
# |    time_elapsed     | 4266     |
# |    total_timesteps  | 8024968  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 1993741  |
# ----------------------------------
# Validating at 8100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 4000000  |
# |    fps              | 1879     |
# |    time_elapsed     | 4324     |
# |    total_timesteps  | 8128422  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.405    |
# |    n_updates        | 2019605  |
# ----------------------------------
# Validating at 8200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 4100000  |
# |    fps              | 1878     |
# |    time_elapsed     | 4383     |
# |    total_timesteps  | 8233441  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.405    |
# |    n_updates        | 2045860  |
# ----------------------------------
# Validating at 8300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 4200000  |
# |    fps              | 1870     |
# |    time_elapsed     | 4456     |
# |    total_timesteps  | 8337214  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 2071803  |
# ----------------------------------
# Validating at 8400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 4300000  |
# |    fps              | 1860     |
# |    time_elapsed     | 4536     |
# |    total_timesteps  | 8441724  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 2097930  |
# ----------------------------------
# Validating at 8500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 4400000  |
# |    fps              | 1851     |
# |    time_elapsed     | 4614     |
# |    total_timesteps  | 8545848  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.479    |
# |    n_updates        | 2123961  |
# ----------------------------------
# Validating at 8600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 4500000  |
# |    fps              | 1843     |
# |    time_elapsed     | 4693     |
# |    total_timesteps  | 8650282  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 2150070  |
# ----------------------------------
# Validating at 8700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77     |
# |    ep_rew_mean      | -0.94    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.09     |
# | time/               |          |
# |    episodes         | 4600000  |
# |    fps              | 1835     |
# |    time_elapsed     | 4770     |
# |    total_timesteps  | 8755056  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 2176263  |
# ----------------------------------
# Validating at 8800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 4700000  |
# |    fps              | 1826     |
# |    time_elapsed     | 4850     |
# |    total_timesteps  | 8859353  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.334    |
# |    n_updates        | 2202338  |
# ----------------------------------
# Validating at 8900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 4800000  |
# |    fps              | 1818     |
# |    time_elapsed     | 4929     |
# |    total_timesteps  | 8963601  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.441    |
# |    n_updates        | 2228400  |
# ----------------------------------
# Validating at 9000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 4900000  |
# |    fps              | 1810     |
# |    time_elapsed     | 5008     |
# |    total_timesteps  | 9067119  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 2254279  |
# ----------------------------------
# Validating at 9100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 5000000  |
# |    fps              | 1802     |
# |    time_elapsed     | 5087     |
# |    total_timesteps  | 9171021  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.363    |
# |    n_updates        | 2280255  |
# ----------------------------------
# Validating at 9200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 5100000  |
# |    fps              | 1796     |
# |    time_elapsed     | 5163     |
# |    total_timesteps  | 9275601  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.477    |
# |    n_updates        | 2306400  |
# ----------------------------------
# Validating at 9300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 5200000  |
# |    fps              | 1791     |
# |    time_elapsed     | 5235     |
# |    total_timesteps  | 9379280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 2332319  |
# ----------------------------------
# Validating at 9400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 5300000  |
# |    fps              | 1790     |
# |    time_elapsed     | 5297     |
# |    total_timesteps  | 9483512  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 2358377  |
# ----------------------------------
# Validating at 9500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 5400000  |
# |    fps              | 1790     |
# |    time_elapsed     | 5355     |
# |    total_timesteps  | 9587561  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.15     |
# |    n_updates        | 2384390  |
# ----------------------------------
# Validating at 9600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 5500000  |
# |    fps              | 1790     |
# |    time_elapsed     | 5413     |
# |    total_timesteps  | 9692397  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.402    |
# |    n_updates        | 2410599  |
# ----------------------------------
# Validating at 9700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 5600000  |
# |    fps              | 1790     |
# |    time_elapsed     | 5472     |
# |    total_timesteps  | 9796947  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.256    |
# |    n_updates        | 2436736  |
# ----------------------------------
# Validating at 9800000/30000000
# Validating at 9900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 5700000  |
# |    fps              | 1788     |
# |    time_elapsed     | 5537     |
# |    total_timesteps  | 9900798  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 2462699  |
# ----------------------------------
# Validating at 10000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 5800000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5595     |
# |    total_timesteps  | 10005146 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.368    |
# |    n_updates        | 2488786  |
# ----------------------------------
# Validating at 10100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 5900000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5654     |
# |    total_timesteps  | 10108674 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 2514668  |
# ----------------------------------
# Validating at 10200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 6000000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5712     |
# |    total_timesteps  | 10212749 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.293    |
# |    n_updates        | 2540687  |
# ----------------------------------
# Validating at 10300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.44    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.28     |
# | time/               |          |
# |    episodes         | 6100000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5771     |
# |    total_timesteps  | 10317437 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.257    |
# |    n_updates        | 2566859  |
# ----------------------------------
# Validating at 10400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 6200000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5829     |
# |    total_timesteps  | 10421365 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.264    |
# |    n_updates        | 2592841  |
# ----------------------------------
# Validating at 10500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 6300000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5888     |
# |    total_timesteps  | 10525056 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 2618763  |
# ----------------------------------
# Validating at 10600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 6400000  |
# |    fps              | 1787     |
# |    time_elapsed     | 5946     |
# |    total_timesteps  | 10629680 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.257    |
# |    n_updates        | 2644919  |
# ----------------------------------
# Validating at 10700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 6500000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6004     |
# |    total_timesteps  | 10733349 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 2670837  |
# ----------------------------------
# Validating at 10800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 6600000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6063     |
# |    total_timesteps  | 10837853 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.331    |
# |    n_updates        | 2696963  |
# ----------------------------------
# Validating at 10900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.74    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.13     |
# | time/               |          |
# |    episodes         | 6700000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6121     |
# |    total_timesteps  | 10941962 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 2722990  |
# ----------------------------------
# Validating at 11000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 6800000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6179     |
# |    total_timesteps  | 11045864 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.185    |
# |    n_updates        | 2748965  |
# ----------------------------------
# Validating at 11100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.68    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.16     |
# | time/               |          |
# |    episodes         | 6900000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6237     |
# |    total_timesteps  | 11150104 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.333    |
# |    n_updates        | 2775025  |
# ----------------------------------
# Validating at 11200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 7000000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6295     |
# |    total_timesteps  | 11254930 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.222    |
# |    n_updates        | 2801232  |
# ----------------------------------
# Validating at 11300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 7100000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6354     |
# |    total_timesteps  | 11359564 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.405    |
# |    n_updates        | 2827390  |
# ----------------------------------
# Validating at 11400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.5     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.25     |
# | time/               |          |
# |    episodes         | 7200000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6413     |
# |    total_timesteps  | 11463933 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.369    |
# |    n_updates        | 2853483  |
# ----------------------------------
# Validating at 11500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 7300000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6472     |
# |    total_timesteps  | 11567780 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 2879444  |
# ----------------------------------
# Validating at 11600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 7400000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6530     |
# |    total_timesteps  | 11672305 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.183    |
# |    n_updates        | 2905576  |
# ----------------------------------
# Validating at 11700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 7500000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6588     |
# |    total_timesteps  | 11775778 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.226    |
# |    n_updates        | 2931444  |
# ----------------------------------
# Validating at 11800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 7600000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6646     |
# |    total_timesteps  | 11881140 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.257    |
# |    n_updates        | 2957784  |
# ----------------------------------
# Validating at 11900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 7700000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6705     |
# |    total_timesteps  | 11985031 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 2983757  |
# ----------------------------------
# Validating at 12000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 7800000  |
# |    fps              | 1787     |
# |    time_elapsed     | 6763     |
# |    total_timesteps  | 12089129 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.334    |
# |    n_updates        | 3009782  |
# ----------------------------------
# Validating at 12100000/30000000
# ...
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | -0.64    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.18     |
# | time/               |          |
# |    episodes         | 22300000 |
# |    fps              | 1435     |
# |    time_elapsed     | 18951    |
# |    total_timesteps  | 27210358 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 6790089  |
# ----------------------------------
# Validating at 27300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 22400000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19023    |
# |    total_timesteps  | 27313884 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 6815970  |
# ----------------------------------
# Validating at 27400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 22500000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19095    |
# |    total_timesteps  | 27417421 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 6841855  |
# ----------------------------------
# Validating at 27500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.42    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.29     |
# | time/               |          |
# |    episodes         | 22600000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19167    |
# |    total_timesteps  | 27521609 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.186    |
# |    n_updates        | 6867902  |
# ----------------------------------
# Validating at 27600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 22700000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19241    |
# |    total_timesteps  | 27626105 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.369    |
# |    n_updates        | 6894026  |
# ----------------------------------
# Validating at 27700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 22800000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19312    |
# |    total_timesteps  | 27730283 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.188    |
# |    n_updates        | 6920070  |
# ----------------------------------
# Validating at 27800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 22900000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19384    |
# |    total_timesteps  | 27836351 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 6946587  |
# ----------------------------------
# Validating at 27900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 23000000 |
# |    fps              | 1436     |
# |    time_elapsed     | 19455    |
# |    total_timesteps  | 27940655 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.296    |
# |    n_updates        | 6972663  |
# ----------------------------------
# Validating at 28000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.46    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.27     |
# | time/               |          |
# |    episodes         | 23100000 |
# |    fps              | 1436     |
# |    time_elapsed     | 19527    |
# |    total_timesteps  | 28044412 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 6998602  |
# ----------------------------------
# Validating at 28100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.62    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.19     |
# | time/               |          |
# |    episodes         | 23200000 |
# |    fps              | 1435     |
# |    time_elapsed     | 19610    |
# |    total_timesteps  | 28149445 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.441    |
# |    n_updates        | 7024861  |
# ----------------------------------
# Validating at 28200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 23300000 |
# |    fps              | 1434     |
# |    time_elapsed     | 19690    |
# |    total_timesteps  | 28253771 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.266    |
# |    n_updates        | 7050942  |
# ----------------------------------
# Validating at 28300000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 23400000 |
# |    fps              | 1434     |
# |    time_elapsed     | 19770    |
# |    total_timesteps  | 28357342 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.368    |
# |    n_updates        | 7076835  |
# ----------------------------------
# Validating at 28400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.5     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.25     |
# | time/               |          |
# |    episodes         | 23500000 |
# |    fps              | 1433     |
# |    time_elapsed     | 19847    |
# |    total_timesteps  | 28460824 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.368    |
# |    n_updates        | 7102705  |
# ----------------------------------
# Validating at 28500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.66    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.17     |
# | time/               |          |
# |    episodes         | 23600000 |
# |    fps              | 1434     |
# |    time_elapsed     | 19919    |
# |    total_timesteps  | 28564995 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.259    |
# |    n_updates        | 7128748  |
# ----------------------------------
# Validating at 28600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.38    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.31     |
# | time/               |          |
# |    episodes         | 23700000 |
# |    fps              | 1433     |
# |    time_elapsed     | 19994    |
# |    total_timesteps  | 28669811 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 7154952  |
# ----------------------------------
# Validating at 28700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | -0.56    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.22     |
# | time/               |          |
# |    episodes         | 23800000 |
# |    fps              | 1433     |
# |    time_elapsed     | 20068    |
# |    total_timesteps  | 28774001 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.26     |
# |    n_updates        | 7181000  |
# ----------------------------------
# Validating at 28800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | -0.44    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.28     |
# | time/               |          |
# |    episodes         | 23900000 |
# |    fps              | 1433     |
# |    time_elapsed     | 20141    |
# |    total_timesteps  | 28879512 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.147    |
# |    n_updates        | 7207377  |
# ----------------------------------
# Validating at 28900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.44    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.28     |
# | time/               |          |
# |    episodes         | 24000000 |
# |    fps              | 1433     |
# |    time_elapsed     | 20217    |
# |    total_timesteps  | 28984778 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.37     |
# |    n_updates        | 7233694  |
# ----------------------------------
# Validating at 29000000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | -0.7     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 24100000 |
# |    fps              | 1433     |
# |    time_elapsed     | 20296    |
# |    total_timesteps  | 29088151 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 7259537  |
# ----------------------------------
# Validating at 29100000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 24200000 |
# |    fps              | 1432     |
# |    time_elapsed     | 20380    |
# |    total_timesteps  | 29193004 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 7285750  |
# ----------------------------------
# Validating at 29200000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 24300000 |
# |    fps              | 1432     |
# |    time_elapsed     | 20456    |
# |    total_timesteps  | 29297843 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.188    |
# |    n_updates        | 7311960  |
# ----------------------------------
# Validating at 29300000/30000000
# Validating at 29400000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.8     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.1      |
# | time/               |          |
# |    episodes         | 24400000 |
# |    fps              | 1431     |
# |    time_elapsed     | 20535    |
# |    total_timesteps  | 29401525 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.261    |
# |    n_updates        | 7337881  |
# ----------------------------------
# Validating at 29500000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.54    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.23     |
# | time/               |          |
# |    episodes         | 24500000 |
# |    fps              | 1431     |
# |    time_elapsed     | 20611    |
# |    total_timesteps  | 29505094 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.33     |
# |    n_updates        | 7363773  |
# ----------------------------------
# Validating at 29600000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.58    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.21     |
# | time/               |          |
# |    episodes         | 24600000 |
# |    fps              | 1431     |
# |    time_elapsed     | 20688    |
# |    total_timesteps  | 29608885 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.406    |
# |    n_updates        | 7389721  |
# ----------------------------------
# Validating at 29700000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04     |
# |    ep_rew_mean      | -0.48    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.26     |
# | time/               |          |
# |    episodes         | 24700000 |
# |    fps              | 1431     |
# |    time_elapsed     | 20758    |
# |    total_timesteps  | 29712884 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.369    |
# |    n_updates        | 7415720  |
# ----------------------------------
# Validating at 29800000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | -0.6     |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.2      |
# | time/               |          |
# |    episodes         | 24800000 |
# |    fps              | 1431     |
# |    time_elapsed     | 20831    |
# |    total_timesteps  | 29817774 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 7441943  |
# ----------------------------------
# Validating at 29900000/30000000
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | -0.52    |
# |    exploration_rate | 0.05     |
# |    success_rate     | 0.24     |
# | time/               |          |
# |    episodes         | 24900000 |
# |    fps              | 1431     |
# |    time_elapsed     | 20901    |
# |    total_timesteps  | 29922689 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.365    |
# |    n_updates        | 7468172  |
# ----------------------------------
# Validating at 30000000/30000000
