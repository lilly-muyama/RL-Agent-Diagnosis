# %%
# !python '../scripts/dqn_robustness.py' --noisiness 0.1 --seed 63
# Out:
# Seed being used: 63
# Number of steps: 100000000
# Beta being used: 9
# The environment seed is [63]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.65     |
# |    ep_rew_mean      | -0.752   |
# |    exploration_rate | 0.954    |
# |    success_rate     | 0.15     |
# | time/               |          |
# |    episodes         | 100000   |
# |    fps              | 2466     |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 480080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 107519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.05     |
# |    ep_rew_mean      | -0.711   |
# |    exploration_rate | 0.907    |
# ...
